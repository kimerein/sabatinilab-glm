# %%
import pandas as pd
import pickle

# %%
import sys
import os
dir_path = '/'.join(os.path.realpath('.').split('/')[:-1])
sys.path.append(f'{dir_path}/sabatinilab-glm/backend')
sys.path.append(f'{dir_path}/..')
sys.path.append(f'{dir_path}/backend')
sys.path.append(f'{dir_path}/../backend')

import sglm
import sglm_cv
import sglm_pp
import sglm_ez
import sglm_plt as splt
import sglm_save as ssave
import lynne_pp as lpp
from tqdm import tqdm, trange

gdat = pickle.load(open('../../model_outputs/ssave/55_Ach_rDAh_WT63_11082021.pkl', 'rb'))

# %%
gdat.data.keys()
# Out:
# dict_keys(['fit_results', 'uid', 'filename', 'negorder', 'posorder', 'X_cols', 'gss_info', 'basedata'])

# %%
bd = gdat.data['basedata']
# bd['wi_trial_keep']
# bd

# %%
# bd[bd['wi_trial_keep']]

# %%
# gdat.data.keys()

# %%
col_names = ['fn', 'response', 'dropped', 'alpha', 'l1_ratio', 'gss_witi', 'gss_noiti', 'holdout_witi', 'holdout_noiti']
df = pd.DataFrame(columns=col_names)

for fr in gdat.data['fit_results']:
    print(fr.keys())
    dc = fr['dropped_cols']
    rc = fr['response_col']
    hp = fr['hyperparams']
    scores = fr['scores']
    # print(fr.keys())
    print('response_col:', rc, '— dropped_cols', dc, '— hyperparams', hp)
    for sc in scores:
        if scores[sc] is not None:
            print('>', sc, scores[sc])
    
    df = df.append(pd.DataFrame([[gdat.data['filename'], rc, dc, hp['alpha'], hp['l1_ratio'], scores['gss_witi'], scores['gss_noiti'], scores['holdout_witi'], scores['holdout_noiti']]], columns=col_names))
# Out:
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsrdFF — dropped_cols [] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.01, 'l1_ratio': 0.0}
# > gss_witi 0.18038705003066247
# > holdout_witi 0.197927001407594
# > holdout_noiti 0.364952577443732
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsrdFF — dropped_cols [] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.001, 'l1_ratio': 0.0}
# > gss_witi 0.18038085278992522
# > holdout_witi 0.19791630963899454
# > holdout_noiti 0.3649593504921109
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsrdFF — dropped_cols [] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.01, 'l1_ratio': 0.001}
# > gss_witi 0.1532531570503699
# > holdout_witi 0.15486724486736914
# > holdout_noiti 0.2666869151008815
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsrdFF — dropped_cols [] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.001, 'l1_ratio': 0.001}
# > gss_witi 0.1785888890321694
# > holdout_witi 0.19401253963225373
# > holdout_noiti 0.34745379852603786
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsrdFF — dropped_cols [] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.5, 'l1_ratio': 0.0}
# > gss_witi 0.18059903153227885
# > holdout_witi 0.19836861019106933
# > holdout_noiti 0.3645681841682137
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsrdFF — dropped_cols [] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.1, 'l1_ratio': 0.0}
# > gss_witi 0.18044315857424875
# > holdout_witi 0.19802787199681648
# > holdout_noiti 0.3648840834464985
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsrdFF — dropped_cols [] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.5, 'l1_ratio': 0.001}
# > gss_witi 0.04241773206393529
# > holdout_witi 0.03842478887479983
# > holdout_noiti 0.05780188709025991
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsrdFF — dropped_cols [] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.1, 'l1_ratio': 0.001}
# > gss_witi 0.08398235226191186
# > holdout_witi 0.0785147707997379
# > holdout_noiti 0.12722873866019246
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsrdFF — dropped_cols [] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.9, 'l1_ratio': 0.0}
# > gss_witi 0.18066594510286083
# > holdout_witi 0.19858659076737817
# > holdout_noiti 0.3642439662195588
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsrdFF — dropped_cols [] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 1.0, 'l1_ratio': 0.0}
# > gss_witi 0.1806746695069239
# > holdout_witi 0.19862766840162238
# > holdout_noiti 0.3641626591080884
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsrdFF — dropped_cols [] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 1.0, 'l1_ratio': 0.001}
# > gss_witi 0.027335960755791144
# > holdout_witi 0.0249292068430107
# > holdout_noiti 0.03539775517766386
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsrdFF — dropped_cols [] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.9, 'l1_ratio': 0.001}
# > gss_witi 0.02951797778570453
# > holdout_witi 0.02684897238116446
# > holdout_noiti 0.03854560652131667
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsrdFF — dropped_cols ['nTrial'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.001, 'l1_ratio': 0.0}
# > gss_witi 0.17183479273991764
# > holdout_witi 0.2026586724367191
# > holdout_noiti 0.3004115129095394
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsrdFF — dropped_cols ['nTrial'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.01, 'l1_ratio': 0.0}
# > gss_witi 0.17184513632332
# > holdout_witi 0.202659753620254
# > holdout_noiti 0.3004117784582362
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsrdFF — dropped_cols ['nTrial'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.01, 'l1_ratio': 0.001}
# > gss_witi 0.14342841052495936
# > holdout_witi 0.15770295381421606
# > holdout_noiti 0.21872140447234778
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsrdFF — dropped_cols ['nTrial'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.001, 'l1_ratio': 0.001}
# > gss_witi 0
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsrdFF — dropped_cols ['spnnr'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.9, 'l1_ratio': 0.0}
# > gss_witi 0.17001604948425286
# > holdout_witi 0.156311487102346
# > holdout_noiti 0.32315103138590073
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsrdFF — dropped_cols ['spnnr'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 1.0, 'l1_ratio': 0.001}
# > gss_witi 0.02734411196397979
# > holdout_witi 0.025060513291103037
# > holdout_noiti 0.03669792545076189
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsrdFF — dropped_cols ['spnnr'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.9, 'l1_ratio': 0.001}
# > gss_witi 0.029488466950360337
# > holdout_witi 0.02691901457552759
# > holdout_noiti 0.03996207612529845
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsrdFF — dropped_cols ['spxnr'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.01, 'l1_ratio': 0.0}
# > gss_witi 0.1757427419254679
# > holdout_witi 0.20122403294748537
# > holdout_noiti 0.31948044057586955
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsrdFF — dropped_cols ['spxnr'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.001, 'l1_ratio': 0.0}
# > gss_witi 0.17573895057402877
# > holdout_witi 0.20122387830104105
# > holdout_noiti 0.31948364625235093
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsrdFF — dropped_cols ['spxnr'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.01, 'l1_ratio': 0.001}
# > gss_witi 0.14509133893022563
# > holdout_witi 0.1490239669669462
# > holdout_noiti 0.23255311177858617
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsrdFF — dropped_cols ['spxnr'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.001, 'l1_ratio': 0.001}
# > gss_witi 0.1749892324035821
# > holdout_witi 0.19465462495688024
# > holdout_noiti 0.3047160459602023
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsrdFF — dropped_cols ['spxnr'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.5, 'l1_ratio': 0.0}
# > gss_witi 0.17591950850870397
# > holdout_witi 0.20122470591371944
# > holdout_noiti 0.3192969973690378
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsrdFF — dropped_cols ['spxnr'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.1, 'l1_ratio': 0.0}
# > gss_witi 0.17577936926819393
# > holdout_witi 0.20122527541183666
# > holdout_noiti 0.3194480177353983
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsrdFF — dropped_cols ['spxnr'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.5, 'l1_ratio': 0.001}
# > gss_witi 0.04152108470824156
# > holdout_witi 0.03970646415886958
# > holdout_noiti 0.05495810581108396
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsrdFF — dropped_cols ['spxnr'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.1, 'l1_ratio': 0.001}
# > gss_witi 0.08128156084747362
# > holdout_witi 0.07722299075153904
# > holdout_noiti 0.11542711520572091
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsrdFF — dropped_cols ['spxnr'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 1.0, 'l1_ratio': 0.0}
# > gss_witi 0.1760583070584293
# > holdout_witi 0.20121202857685971
# > holdout_noiti 0.3190961446209801
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsrdFF — dropped_cols ['spxnr'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.9, 'l1_ratio': 0.0}
# > gss_witi 0.17603304776557105
# > holdout_witi 0.2012155142302653
# > holdout_noiti 0.3191371802711829
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsrdFF — dropped_cols ['spxnr'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 1.0, 'l1_ratio': 0.001}
# > gss_witi 0.026727622154545827
# > holdout_witi 0.025840478810262524
# > holdout_noiti 0.03341136425889635
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsrdFF — dropped_cols ['spxnr'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.9, 'l1_ratio': 0.001}
# > gss_witi 0.028857843099720615
# > holdout_witi 0.02785760409367455
# > holdout_noiti 0.03651291761597175
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsrdFF — dropped_cols ['sl'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.001, 'l1_ratio': 0.0}
# > gss_witi 0.14508679252545098
# > holdout_witi 0.14403913438130111
# > holdout_noiti 0.3046299013792789
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsrdFF — dropped_cols ['sl'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.01, 'l1_ratio': 0.0}
# > gss_witi 0.1451000466518939
# > holdout_witi 0.14404592021156215
# > holdout_noiti 0.30463197683523013
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsrdFF — dropped_cols ['sl'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.01, 'l1_ratio': 0.001}
# > gss_witi 0.10080589167562659
# > holdout_witi 0.10217625035956557
# > holdout_noiti 0.1720119029491548
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsrdFF — dropped_cols ['sl'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.001, 'l1_ratio': 0.001}
# > gss_witi 0.14411304303332306
# > holdout_witi 0.1453165994863379
# > holdout_noiti 0.28931992666166795
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsrdFF — dropped_cols ['sl'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.5, 'l1_ratio': 0.0}
# > gss_witi 0.14561965846209923
# > holdout_witi 0.14436544965779163
# > holdout_noiti 0.30469386136453813
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsrdFF — dropped_cols ['sl'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.1, 'l1_ratio': 0.0}
# > gss_witi 0.1452234143499569
# > holdout_witi 0.1441117050616828
# > holdout_noiti 0.3046506303721366
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsrdFF — dropped_cols ['sl'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.5, 'l1_ratio': 0.001}
# > gss_witi 0.002119266637932604
# > holdout_witi -0.00017603101487284611
# > holdout_noiti -0.02106485051096385
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsrdFF — dropped_cols ['sl'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.1, 'l1_ratio': 0.001}
# > gss_witi 0.022892933023883066
# > holdout_witi 0.021165905287848896
# > holdout_noiti 0.015456761117474516
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsrdFF — dropped_cols ['sl'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 1.0, 'l1_ratio': 0.0}
# > gss_witi 0.14590403013289543
# > holdout_witi 0.14461692945249893
# > holdout_noiti 0.3046788914440778
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsrdFF — dropped_cols ['sl'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.9, 'l1_ratio': 0.0}
# > gss_witi 0.14585955672993267
# > holdout_witi 0.14457123704573405
# > holdout_noiti 0.30468680551739036
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsrdFF — dropped_cols ['sl'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 1.0, 'l1_ratio': 0.001}
# > gss_witi -0.0007993792272151801
# > holdout_witi -0.003147203758842476
# > holdout_noiti -0.026143663821855734
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsrdFF — dropped_cols ['sl'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.9, 'l1_ratio': 0.001}
# > gss_witi -0.0005007822532883122
# > holdout_witi -0.0028426822310578803
# > holdout_noiti -0.02561278285706381
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsgdFF — dropped_cols [] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.01, 'l1_ratio': 0.0}
# > gss_witi 0.22764688387478926
# > holdout_witi 0.1720928099640926
# > holdout_noiti 0.3460612191039385
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsgdFF — dropped_cols [] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.001, 'l1_ratio': 0.0}
# > gss_witi 0.22763618062158053
# > holdout_witi 0.1720778566883664
# > holdout_noiti 0.34607447225702914
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsgdFF — dropped_cols [] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.01, 'l1_ratio': 0.001}
# > gss_witi 0.19383326149035895
# > holdout_witi 0.14357389881461158
# > holdout_noiti 0.26077960212577245
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsgdFF — dropped_cols [] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.001, 'l1_ratio': 0.001}
# > gss_witi 0.22625612171589216
# > holdout_witi 0.17470266565303805
# > holdout_noiti 0.3256010644658385
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsgdFF — dropped_cols [] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.5, 'l1_ratio': 0.0}
# > gss_witi 0.2280852611601044
# > holdout_witi 0.1728395013177917
# > holdout_noiti 0.34536446865000847
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsgdFF — dropped_cols [] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.1, 'l1_ratio': 0.0}
# > gss_witi 0
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsgdFF — dropped_cols ['spnnr'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.01, 'l1_ratio': 0.001}
# > gss_witi 0.1824265107640587
# > holdout_witi 0.15066642949043174
# > holdout_noiti 0.28402336187881205
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsgdFF — dropped_cols ['spnnr'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.001, 'l1_ratio': 0.001}
# > gss_witi 0.2131569300353623
# > holdout_witi 0.17601009921047617
# > holdout_noiti 0.3360529130166928
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsgdFF — dropped_cols ['spnnr'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.5, 'l1_ratio': 0.0}
# > gss_witi 0.2139622324941477
# > holdout_witi 0.17289969023206542
# > holdout_noiti 0.34437226225837403
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsgdFF — dropped_cols ['spnnr'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.1, 'l1_ratio': 0.0}
# > gss_witi 0.21378815257966632
# > holdout_witi 0.1721939819723064
# > holdout_noiti 0.34441875149817036
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsgdFF — dropped_cols ['spnnr'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.5, 'l1_ratio': 0.001}
# > gss_witi 0.027672878142298574
# > holdout_witi 0.02606300778234827
# > holdout_noiti 0.046984477641824895
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsgdFF — dropped_cols ['spnnr'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.1, 'l1_ratio': 0.001}
# > gss_witi 0.08901417156174263
# > holdout_witi 0.07845607319882875
# > holdout_noiti 0.1429533141830409
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsgdFF — dropped_cols ['spnnr'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.9, 'l1_ratio': 0.0}
# > gss_witi 0.2140926779045481
# > holdout_witi 0.173494696778983
# > holdout_noiti 0.3443061745469338
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsgdFF — dropped_cols ['spnnr'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 1.0, 'l1_ratio': 0.0}
# > gss_witi 0.21412063488457433
# > holdout_witi 0.17362900624978683
# > holdout_noiti 0.3442872904925094
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsgdFF — dropped_cols ['spnnr'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 1.0, 'l1_ratio': 0.001}
# > gss_witi 0.01358661365612801
# > holdout_witi 0.013345495688312559
# > holdout_noiti 0.023697739664492845
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsgdFF — dropped_cols ['spnnr'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.9, 'l1_ratio': 0.001}
# > gss_witi 0.015291696324247983
# > holdout_witi 0.01490481093864926
# > holdout_noiti 0.02656826703267756
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsgdFF — dropped_cols ['spxnr'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.001, 'l1_ratio': 0.0}
# > gss_witi 0.20388938897365005
# > holdout_witi 0.23091895053449973
# > holdout_noiti 0.40474698364228234
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsgdFF — dropped_cols ['spxnr'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.01, 'l1_ratio': 0.0}
# > gss_witi 0.20389644260509054
# > holdout_witi 0.23092100450736353
# > holdout_noiti 0.40474625079457127
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsgdFF — dropped_cols ['spxnr'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.01, 'l1_ratio': 0.001}
# > gss_witi 0.17078183002904013
# > holdout_witi 0.19761553545213506
# > holdout_noiti 0.33422886199641255
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsgdFF — dropped_cols ['spxnr'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.001, 'l1_ratio': 0.001}
# > gss_witi 0.20419686189239394
# > holdout_witi 0.23206871720084932
# > holdout_noiti 0.39738298467992494
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsgdFF — dropped_cols ['spxnr'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.5, 'l1_ratio': 0.0}
# > gss_witi 0.20423701425451868
# > holdout_witi 0.23103085548559887
# > holdout_noiti 0.40470305590714317
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsgdFF — dropped_cols ['spxnr'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.1, 'l1_ratio': 0.0}
# > gss_witi 0.203965193140766
# > holdout_witi 0.23094147533481424
# > holdout_noiti 0.4047387985684945
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsgdFF — dropped_cols ['spxnr'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.5, 'l1_ratio': 0.001}
# > gss_witi 0.026337880691413296
# > holdout_witi 0.02884098985867023
# > holdout_noiti 0.05185045669487298
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsgdFF — dropped_cols ['spxnr'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.1, 'l1_ratio': 0.001}
# > gss_witi 0.08327838053452774
# > holdout_witi 0.09344073465635039
# > holdout_noiti 0.16449335897204276
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsgdFF — dropped_cols ['spxnr'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 1.0, 'l1_ratio': 0.0}
# > gss_witi 0.20451691093415825
# > holdout_witi 0.23113863518956157
# > holdout_noiti 0.4046527538446628
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsgdFF — dropped_cols ['spxnr'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.9, 'l1_ratio': 0.0}
# > gss_witi 0.20446532709374765
# > holdout_witi 0.2311174431922154
# > holdout_noiti 0.4046632890047368
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsgdFF — dropped_cols ['spxnr'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 1.0, 'l1_ratio': 0.001}
# > gss_witi 0.01307139130959556
# > holdout_witi 0.014306662249960245
# > holdout_noiti 0.02539419137696164
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsgdFF — dropped_cols ['spxnr'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.9, 'l1_ratio': 0.001}
# > gss_witi 0.014690822453773178
# > holdout_witi 0.016055528631573335
# > holdout_noiti 0.028627817260375554
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsgdFF — dropped_cols ['sl'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.001, 'l1_ratio': 0.0}
# > gss_witi 0.2126810683843111
# > holdout_witi 0.19039392553016388
# > holdout_noiti 0.3824453759026676
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsgdFF — dropped_cols ['sl'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.01, 'l1_ratio': 0.0}
# > gss_witi 0.2126873262864596
# > holdout_witi 0.19042038913959958
# > holdout_noiti 0.38244680146755083
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsgdFF — dropped_cols ['sl'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.01, 'l1_ratio': 0.001}
# > gss_witi 0.13421445944025012
# > holdout_witi 0.12180587962156963
# > holdout_noiti 0.22175002028614443
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsgdFF — dropped_cols ['sl'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.001, 'l1_ratio': 0.001}
# > gss_witi 0.20647504437184716
# > holdout_witi 0.19032413119883296
# > holdout_noiti 0.36100082469801
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsgdFF — dropped_cols ['sl'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.1, 'l1_ratio': 0.0}
# > gss_witi 0.21274403329074842
# > holdout_witi 0.19067426888735928
# > holdout_noiti 0.38245711144542616
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsgdFF — dropped_cols ['sl'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.5, 'l1_ratio': 0.0}
# > gss_witi 0.21290114610926558
# > holdout_witi 0.19160687850287617
# > holdout_noiti 0.3824324232708395
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsgdFF — dropped_cols ['sl'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.5, 'l1_ratio': 0.001}
# > gss_witi 0.00404129102203421
# > holdout_witi 0.003184353764021708
# > holdout_noiti 0.0027477482454981716
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsgdFF — dropped_cols ['sl'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.1, 'l1_ratio': 0.001}
# > gss_witi 0.02785773166313077
# > holdout_witi 0.024673383075400346
# > holdout_noiti 0.041876046908303155
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsgdFF — dropped_cols ['sl'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 1.0, 'l1_ratio': 0.0}
# > gss_witi 0.21297029773097698
# > holdout_witi 0.19245365207584175
# > holdout_noiti 0.38229033434389914
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsgdFF — dropped_cols ['sl'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.9, 'l1_ratio': 0.0}
# > gss_witi 0.2129638138945643
# > holdout_witi 0.19230586235846003
# > holdout_noiti 0.38232606587789275
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsgdFF — dropped_cols ['sl'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 1.0, 'l1_ratio': 0.001}
# > gss_witi 0.0008474508096143474
# > holdout_witi 0.0003696518068361243
# > holdout_noiti -0.0024523507860227944
# dict_keys(['response_col', 'hyperparams', 'glm_model_gss', 'dropped_cols', 'scores', 'gss_mse', 'refit_mse', 'gssids'])
# response_col: zsgdFF — dropped_cols ['sl'] — hyperparams {'max_iter': 1000, 'fit_intercept': True, 'alpha': 0.9, 'l1_ratio': 0.001}
# > gss_witi 0.001182410515872978
# > holdout_witi 0.00066022908971064
# > holdout_noiti -0.0019127483716272486

# %%
num_view = 5
display(df.query("response == 'zsgdFF'").sort_values('holdout_noiti').iloc[-num_view:])
display(df.query("response == 'zsgdFF'").sort_values('holdout_witi').iloc[-num_view:])
display(df.query("response == 'zsgdFF'").sort_values('gss_witi').iloc[-num_view:])

display(df.query("response == 'zsrdFF'").sort_values('holdout_noiti').iloc[-num_view:])
display(df.query("response == 'zsrdFF'").sort_values('holdout_witi').iloc[-num_view:])
display(df.query("response == 'zsrdFF'").sort_values('gss_witi').iloc[-num_view:])
# Out:
#                            fn response  dropped  alpha  l1_ratio  gss_witi  \
# 0  Ach_rDAh_WT63_11082021.csv   zsgdFF  [spxnr]  0.900       0.0  0.204465
# 0  Ach_rDAh_WT63_11082021.csv   zsgdFF  [spxnr]  0.500       0.0  0.204237
# 0  Ach_rDAh_WT63_11082021.csv   zsgdFF  [spxnr]  0.100       0.0  0.203965
# 0  Ach_rDAh_WT63_11082021.csv   zsgdFF  [spxnr]  0.010       0.0  0.203896
# 0  Ach_rDAh_WT63_11082021.csv   zsgdFF  [spxnr]  0.001       0.0  0.203889
#
#   gss_noiti  holdout_witi  holdout_noiti
# 0      None      0.231117       0.404663
# 0      None      0.231031       0.404703
# 0      None      0.230941       0.404739
# 0      None      0.230921       0.404746
# 0      None      0.230919       0.404747
#                            fn response dropped  alpha  l1_ratio  gss_witi  \
# 0  Ach_rDAh_WT63_11082021.csv   zsgdFF  [spnr]  0.900       0.0  0.175735
# 0  Ach_rDAh_WT63_11082021.csv   zsgdFF  [spnr]  0.500       0.0  0.175639
# 0  Ach_rDAh_WT63_11082021.csv   zsgdFF  [spnr]  0.100       0.0  0.175507
# 0  Ach_rDAh_WT63_11082021.csv   zsgdFF  [spnr]  0.010       0.0  0.175470
# 0  Ach_rDAh_WT63_11082021.csv   zsgdFF  [spnr]  0.001       0.0  0.175466
#
#   gss_noiti  holdout_witi  holdout_noiti
# 0      None      0.259744       0.324669
# 0      None      0.259995       0.324981
# 0      None      0.260256       0.325306
# 0      None      0.260316       0.325381
# 0      None      0.260322       0.325389
#                            fn response dropped  alpha  l1_ratio  gss_witi  \
# 0  Ach_rDAh_WT63_11082021.csv   zsgdFF      []   0.01       0.0  0.227647
# 0  Ach_rDAh_WT63_11082021.csv   zsgdFF      []   0.10       0.0  0.227747
# 0  Ach_rDAh_WT63_11082021.csv   zsgdFF      []   0.50       0.0  0.228085
# 0  Ach_rDAh_WT63_11082021.csv   zsgdFF      []   0.90       0.0  0.228310
# 0  Ach_rDAh_WT63_11082021.csv   zsgdFF      []   1.00       0.0  0.228355
#
#   gss_noiti  holdout_witi  holdout_noiti
# 0      None      0.172093       0.346061
# 0      None      0.172240       0.345930
# 0      None      0.172840       0.345364
# 0      None      0.173363       0.344827
# 0      None      0.173483       0.344697
#                            fn response dropped  alpha  l1_ratio  gss_witi  \
# 0  Ach_rDAh_WT63_11082021.csv   zsrdFF      []  0.900       0.0  0.180666
# 0  Ach_rDAh_WT63_11082021.csv   zsrdFF      []  0.500       0.0  0.180599
# 0  Ach_rDAh_WT63_11082021.csv   zsrdFF      []  0.100       0.0  0.180443
# 0  Ach_rDAh_WT63_11082021.csv   zsrdFF      []  0.010       0.0  0.180387
# 0  Ach_rDAh_WT63_11082021.csv   zsrdFF      []  0.001       0.0  0.180381
#
#   gss_noiti  holdout_witi  holdout_noiti
# 0      None      0.198587       0.364244
# 0      None      0.198369       0.364568
# 0      None      0.198028       0.364884
# 0      None      0.197927       0.364953
# 0      None      0.197916       0.364959
#                            fn response   dropped  alpha  l1_ratio  gss_witi  \
# 0  Ach_rDAh_WT63_11082021.csv   zsrdFF  [nTrial]   0.01       0.0  0.171845
# 0  Ach_rDAh_WT63_11082021.csv   zsrdFF  [nTrial]   0.10       0.0  0.171941
# 0  Ach_rDAh_WT63_11082021.csv   zsrdFF  [nTrial]   0.50       0.0  0.172238
# 0  Ach_rDAh_WT63_11082021.csv   zsrdFF  [nTrial]   0.90       0.0  0.172406
# 0  Ach_rDAh_WT63_11082021.csv   zsrdFF  [nTrial]   1.00       0.0  0.172435
#
#   gss_noiti  holdout_witi  holdout_noiti
# 0      None      0.202660       0.300412
# 0      None      0.202670       0.300413
# 0      None      0.202703       0.300395
# 0      None      0.202721       0.300346
# 0      None      0.202723       0.300330
#                            fn response dropped  alpha  l1_ratio  gss_witi  \
# 0  Ach_rDAh_WT63_11082021.csv   zsrdFF   [cpx]   0.01       0.0  0.194784
# 0  Ach_rDAh_WT63_11082021.csv   zsrdFF   [cpx]   0.10       0.0  0.194852
# 0  Ach_rDAh_WT63_11082021.csv   zsrdFF   [cpx]   0.50       0.0  0.195070
# 0  Ach_rDAh_WT63_11082021.csv   zsrdFF   [cpx]   0.90       0.0  0.195198
# 0  Ach_rDAh_WT63_11082021.csv   zsrdFF   [cpx]   1.00       0.0  0.195221
#
#   gss_noiti  holdout_witi  holdout_noiti
# 0      None      0.152087       0.300677
# 0      None      0.152094       0.300676
# 0      None      0.152120       0.300658
# 0      None      0.152144       0.300621
# 0      None      0.152150       0.300610

# %%
# import matplotlib.pyplot as plt
# # for x_val in ['alpha', 'l1_ratio']:
# #     plt.figure()
# #     plt.scatter(df[x_val], df['holdout_witi'], alpha=0.2)
# #     plt.scatter(df[x_val], df['holdout_noiti'], alpha=0.2)
# #     plt.scatter(df[x_val], df['gss_witi'], alpha=0.2)
# #     plt.title(x_val)

# for q in ['zsgdFF', 'zsrdFF']:
#     dfq = df.query(f"response == '{q}'")
#     for x_val in ['alpha', 'l1_ratio']:
#         for y_val in ['alpha', 'l1_ratio']:
#             if x_val == y_val:
#                 continue
#             plt.figure()
#             plt.scatter(dfq[x_val], dfq[y_val], c=dfq['holdout_witi'], alpha=0.2)
#             plt.colorbar()
#             plt.title(q + ' - ' + x_val + '/' + y_val + ' - ' + 'holdout_witi')
#             plt.figure()
#             plt.scatter(dfq[x_val], dfq[y_val], c=dfq['holdout_noiti'], alpha=0.2)
#             plt.colorbar()
#             plt.title(q + ' - ' + x_val + '/' + y_val + ' - ' + 'holdout_noiti')
#             plt.figure()
#             plt.scatter(dfq[x_val], dfq[y_val], c=dfq['gss_witi'], alpha=0.2)
#             plt.colorbar()
#             plt.title(q + ' - ' + x_val + '/' + y_val + ' - ' + 'gss_witi')

# %%
# for x_val in ['alpha', 'l1_ratio']:
#     plt.figure()
#     plt.scatter(df[x_val], df['holdout_witi'], alpha=0.2)
#     plt.scatter(df[x_val], df['holdout_noiti'], alpha=0.2)
#     plt.scatter(df[x_val], df['gss_witi'], alpha=0.2)
#     plt.title(x_val)

# %%
# [(_['glm_model_gss'].coef_, _['glm_model_gss'].intercept_) for _ in gdat.data['fit_results']]
