# %%
# %load_ext autoreload
# %autoreload 2
import glob
import numpy as np
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm, trange
from sglm.models import sglm
from sglm.features import gen_signal_df as gsd
from sglm.features import build_features as bf
from sglm.features import gen_signal_df as gsd
from sglm.features import build_features as bf

import itertools

signal_files = []
out_files = None

# %%
y_col_lst_all = ['gACH', 'rDA', 'gDA',              
                 'gACH_flx_drd', 'rDA_flx_drd', 'gDA_flx_drd',
                 'gACH_flx_cht', 'rDA_flx_cht', 'gDA_flx_cht',
                 'gACH_flx_drdcht', 'rDA_flx_drdcht', 'gDA_flx_drdcht',
                 'Ch5', 'Ch6', 'GP_1', 'GP_2', 'GP_5', 'GP_6', 'SGP_1', 'SGP_2', 'SGP_5', 'SGP_6']

# %%
# from logging.config import _RootLoggerConfiguration

import os
from pathlib import Path

def create_folder_if_not_exists(dr):
    dr = Path(dr)
    constructed_dir = str(Path('/').resolve())
    made = False
    
    print('constructed_dir', constructed_dir)
    for fold in dr.parts:
        if len(fold) == 0:
            continue
        constructed_dir = str((Path(constructed_dir) / fold).resolve())
#         print('constructed_dir', constructed_dir)
        if os.path.isdir(constructed_dir):
            # print(f'Directory already exists:', constructed_dir)
            pass
        else:
            # print(f'Creating directory:', constructed_dir)
            os.mkdir(constructed_dir)
            made = True
    if made:
        print(f'Created directory:', constructed_dir)
    return

# create_folder_if_not_exists((Path.home() / 'Desktop/nada/folder2').resolve())

# %%
# ### Figure 1: Single side recording
figure = 'fig1'

# # Load Signal Data

# signal_files = glob.glob(f'../../data/raw/GLM_SIGNALS_WT61_*')
# signal_files += glob.glob(f'../../data/raw/GLM_SIGNALS_WT63_*')
# signal_files += glob.glob(f'../../data/raw/GLM_SIGNALS_WT64_*')

ignore_files = [
                'WT61_10152021',
                'WT61_10082021'
                ]
# for ign in ignore_files:
#     signal_files = [_ for _ in signal_files if ign not in _]

# table_files = [_.replace('GLM_SIGNALS', 'GLM_TABLE') for _ in signal_files]

# channel_definitions = {
#         ('WT61',): {'Ch1': 'gACH', 'Ch2': 'rDA'},
#         ('WT64',): {'Ch1': 'gACH', 'Ch2': 'empty'},
#         ('WT63',): {'Ch1': 'gDA', 'Ch2': 'empty'},
#     }

group_1_mice = ['WT63', 'WT64', 'WT65']
# group_1_sess = ['11082021', '11102021', '11122021', '11182021']
group_1_sess = ['11082021', '11102021', '11122021', '11162021', '11182021']
group_1_combo = ['_'.join(_) for _ in list(itertools.product(group_1_mice, group_1_sess))]

group_2_mice = ['WT66', 'WT67', 'WT68', 'WT69']
group_2_sess = ['12132021', '12152021', '12172021', '12192021']
group_2_combo = ['_'.join(_) for _ in list(itertools.product(group_2_mice, group_2_sess))]

group_3_mice = ['WT58', 'WT60', 'WT61']
group_3_sess = ['10042021', '10062021', '10082021', '10112021', '10132021', '10152021']
group_3_combo = ['_'.join(_) for _ in list(itertools.product(group_3_mice, group_3_sess))]

group_4_mice = ['WT53', 'WT54', 'WT55', 'WT56']
group_4_sess = ['09012021', '09032021', '09062021']
group_4_combo = ['_'.join(_) for _ in list(itertools.product(group_4_mice, group_4_sess))]

group_5_mice = ['WT57', 'WT59']
group_5_sess = ['10042021', '10062021', '10082021', '10112021', '10132021', '10152021']
group_5_combo = ['_'.join(_) for _ in list(itertools.product(group_5_mice, group_5_sess))]

group_6_mice = []#['WT62']
group_6_sess = []#['11082021', '11102021', '11122021', '11182021']
group_6_combo = ['_'.join(_) for _ in list(itertools.product(group_6_mice, group_6_sess))]


channel_definitions = {}
# channel_definitions = {(file_combo,): {'Ch1': 'gACH', 'Ch2': 'rDA'} for file_combo in group_1_combo}
channel_definitions.update({(file_combo,): {'Ch1': 'gDA', 'Ch5': 'gACH'} for file_combo in group_1_combo})
channel_definitions.update({(file_combo,): {'Ch1': 'gDA'} for file_combo in group_2_combo})
channel_definitions.update({(file_combo,): {'Ch1': 'gACH'} for file_combo in group_3_combo})
channel_definitions.update({(file_combo,): {'Ch1': 'gACH'} for file_combo in group_4_combo})
channel_definitions.update({(file_combo,): {'Ch5': 'gACH'} for file_combo in group_5_combo})
channel_definitions.update({(file_combo,): {'Ch1': 'gDA'} for file_combo in group_6_combo})




fig_1_signal_files_setup = group_1_combo + group_2_combo + group_3_combo + group_4_combo + group_5_combo + group_6_combo

for f in fig_1_signal_files_setup:
    glob_file = glob.glob(str(Path(f'../../data/raw/{figure}/GLM_SIGNALS_{f}*').resolve()))
    if len(glob_file) != 1:
        print('Missing file!!! ', f)
    signal_files += glob_file
# Out:
# Missing file!!!  WT63_11082021
# Missing file!!!  WT56_09062021
# Missing file!!!  WT59_10062021

# %%
### Figure 3: Dual side recording
figure = 'fig3'

# 'WT61', 'WT63', 'WT64', '', 'WT44', 'WT51' # Excluding 'WT43

# ['03162021','03192021','03232021','03262021','07282021','07302021','08012021', '08042021', '08062021', '08102021', '10042021',
# '10082021', '10112021', '10132021', '10182021', '11082021', '11102021', '11122021', '11162021', '11182021']

group_1_mice = ['WT63', 'WT64', 'WT44', 'WT51']
group_1_sess = ['03162021','03192021','03232021','03262021','07282021','07302021','08012021', '08042021', '08062021', '08102021', '10042021',
                '10082021', '10112021', '10132021', '10182021', '11082021', '11102021', '11122021', '11162021', '11182021']
group_1_combo = ['_'.join(_) for _ in list(itertools.product(group_1_mice, group_1_sess))]

group_2_mice = ['WT61']
group_2_sess = ['03162021','03192021','03232021','03262021','07282021','07302021','08012021', '08042021', '08062021', '08102021', '10042021',
                '10082021', '10112021', '10132021', '11082021', '11102021', '11122021', '11162021', '11182021']
group_2_combo = ['_'.join(_) for _ in list(itertools.product(group_2_mice, group_2_sess))]

# group_3_mice = ['WT58', 'WT60', 'WT61']
# group_3_sess = ['10042021', '10062021', '10082021', '10112021', '10132021', '10152021']
# group_3_combo = ['_'.join(_) for _ in list(itertools.product(group_3_mice, group_3_sess))]

# group_4_mice = ['WT53', 'WT54', 'WT55', 'WT56']
# group_4_sess = ['09012021', '09032021', '09062021']
# group_4_combo = ['_'.join(_) for _ in list(itertools.product(group_4_mice, group_4_sess))]

# group_5_mice = ['WT61']
# group_5_sess = ['10042021', '10062021', '10082021', '10112021', '10132021', '10152021']
# group_5_combo = ['_'.join(_) for _ in list(itertools.product(group_5_mice, group_5_sess))]

group_6_mice = ['WT43']
group_6_sess = []
group_6_combo = ['_'.join(_) for _ in list(itertools.product(group_6_mice, group_6_sess))]


# channel_definitions = {}
# channel_definitions = {(file_combo,): {'Ch1': 'gACH', 'Ch2': 'rDA'} for file_combo in group_1_combo}
channel_definitions.update({(file_combo,): {'Ch5': 'gACH', 'Ch6': 'rDA'} for file_combo in group_1_combo})
channel_definitions.update({(file_combo,): {'Ch5': 'gACH', 'Ch6': 'rDA'} for file_combo in group_2_combo})
# channel_definitions.update({(file_combo,): {'Ch1': 'gACH'} for file_combo in group_3_combo})
# channel_definitions.update({(file_combo,): {'Ch1': 'gACH'} for file_combo in group_4_combo})
# channel_definitions.update({(file_combo,): {'Ch5': 'gACH', 'Ch6': 'rDA'} for file_combo in group_5_combo})
channel_definitions.update({(file_combo,): {'Ch5': 'gACH', 'Ch6': 'rDA'} for file_combo in group_6_combo})


fig_3_signal_files_setup = group_1_combo + group_2_combo #+ group_3_combo + group_4_combo + group_5_combo + group_6_combo
for f in fig_3_signal_files_setup:
    glob_file = glob.glob(str(Path(f'../../data/raw/{figure}/GLM_SIGNALS_{f}*').resolve()))
    if len(glob_file) != 1:
        print('Missing file!!! ', f)
    signal_files += glob_file
# Out:
# Missing file!!!  WT63_03162021
# Missing file!!!  WT63_03192021
# Missing file!!!  WT63_03232021
# Missing file!!!  WT63_03262021
# Missing file!!!  WT63_07282021
# Missing file!!!  WT63_07302021
# Missing file!!!  WT63_08012021
# Missing file!!!  WT63_08042021
# Missing file!!!  WT63_08062021
# Missing file!!!  WT63_08102021
# Missing file!!!  WT63_10042021
# Missing file!!!  WT63_10082021
# Missing file!!!  WT63_10112021
# Missing file!!!  WT63_10132021
# Missing file!!!  WT63_10182021
# Missing file!!!  WT64_03162021
# Missing file!!!  WT64_03192021
# Missing file!!!  WT64_03232021
# Missing file!!!  WT64_03262021
# Missing file!!!  WT64_07282021
# Missing file!!!  WT64_07302021
# Missing file!!!  WT64_08012021
# Missing file!!!  WT64_08042021
# Missing file!!!  WT64_08062021
# Missing file!!!  WT64_08102021
# Missing file!!!  WT64_10042021
# Missing file!!!  WT64_10082021
# Missing file!!!  WT64_10112021
# Missing file!!!  WT64_10132021
# Missing file!!!  WT64_10182021
# Missing file!!!  WT44_07282021
# Missing file!!!  WT44_07302021
# Missing file!!!  WT44_08012021
# Missing file!!!  WT44_08042021
# Missing file!!!  WT44_08062021
# Missing file!!!  WT44_08102021
# Missing file!!!  WT44_10042021
# Missing file!!!  WT44_10082021
# Missing file!!!  WT44_10112021
# Missing file!!!  WT44_10132021
# Missing file!!!  WT44_10182021
# Missing file!!!  WT44_11082021
# Missing file!!!  WT44_11102021
# Missing file!!!  WT44_11122021
# Missing file!!!  WT44_11162021
# Missing file!!!  WT44_11182021
# Missing file!!!  WT51_03162021
# Missing file!!!  WT51_03192021
# Missing file!!!  WT51_03232021
# Missing file!!!  WT51_03262021
# Missing file!!!  WT51_10042021
# Missing file!!!  WT51_10082021
# Missing file!!!  WT51_10112021
# Missing file!!!  WT51_10132021
# Missing file!!!  WT51_10182021
# Missing file!!!  WT51_11082021
# Missing file!!!  WT51_11102021
# Missing file!!!  WT51_11122021
# Missing file!!!  WT51_11162021
# Missing file!!!  WT51_11182021
# Missing file!!!  WT61_03162021
# Missing file!!!  WT61_03192021
# Missing file!!!  WT61_03232021
# Missing file!!!  WT61_03262021
# Missing file!!!  WT61_07282021
# Missing file!!!  WT61_07302021
# Missing file!!!  WT61_08012021
# Missing file!!!  WT61_08042021
# Missing file!!!  WT61_08062021
# Missing file!!!  WT61_08102021
# Missing file!!!  WT61_11082021
# Missing file!!!  WT61_11102021
# Missing file!!!  WT61_11122021
# Missing file!!!  WT61_11162021
# Missing file!!!  WT61_11182021

# %%
### Figure 3 dualhem
figure = 'fig3-dualhem'

group_1_mice = ['WT62', 'WT63', 'WT64', 'WT65']
group_1_sess = ['10042021', '10082021', '10112021', '10132021',
                '10182021', '11082021', '11102021', '11122021', '11162021', '11182021']
group_1_combo = ['_'.join(_) for _ in list(itertools.product(group_1_mice, group_1_sess))]

group_2_mice = []
group_2_sess = []
group_2_combo = ['_'.join(_) for _ in list(itertools.product(group_2_mice, group_2_sess))]

group_3_mice = []
group_3_sess = []
group_3_combo = ['_'.join(_) for _ in list(itertools.product(group_3_mice, group_3_sess))]

group_4_mice = []
group_4_sess = []
group_4_combo = ['_'.join(_) for _ in list(itertools.product(group_4_mice, group_4_sess))]

group_5_mice = []
group_5_sess = []
group_5_combo = ['_'.join(_) for _ in list(itertools.product(group_5_mice, group_5_sess))]

group_6_mice = []
group_6_sess = []
group_6_combo = ['_'.join(_) for _ in list(itertools.product(group_6_mice, group_6_sess))]


# channel_definitions = {}
# channel_definitions = {(file_combo,): {'Ch1': 'gACH', 'Ch2': 'rDA'} for file_combo in group_1_combo}
channel_definitions.update({(file_combo,): {'Ch5': 'gACH', 'Ch6': 'rDA', 'Ch1':'gDA'} for file_combo in group_1_combo})
channel_definitions.update({(file_combo,): {'Ch5': 'gACH', 'Ch6': 'rDA', 'Ch1':'gDA'} for file_combo in group_2_combo})
channel_definitions.update({(file_combo,): {'Ch5': 'gACH', 'Ch6': 'rDA', 'Ch1':'gDA'} for file_combo in group_3_combo})
channel_definitions.update({(file_combo,): {'Ch5': 'gACH', 'Ch6': 'rDA'} for file_combo in group_4_combo})
channel_definitions.update({(file_combo,): {'Ch5': 'gACH', 'Ch6': 'rDA'} for file_combo in group_5_combo})
channel_definitions.update({(file_combo,): {'Ch5': 'gACH', 'Ch6': 'rDA'} for file_combo in group_6_combo})


fig_3dh_signal_files_setup = [group_1_combo, group_2_combo, group_3_combo, group_4_combo, group_5_combo, group_6_combo]
for g_num in range(0, len(fig_3dh_signal_files_setup)):
    fig_3dh_basis = fig_3dh_signal_files_setup[g_num]
    for f in fig_3dh_basis:
        glob_file = glob.glob(str(Path(f'../../data/raw/{figure}/GLM_SIGNALS_{f}*').resolve()))
        if len(glob_file) != 1:
            print('Missing file!!! ', f)
        else:
            signal_files += glob_file
# Out:
# Missing file!!!  WT62_10042021
# Missing file!!!  WT62_10082021
# Missing file!!!  WT62_10112021
# Missing file!!!  WT62_10132021
# Missing file!!!  WT62_10182021
# Missing file!!!  WT62_11162021
# Missing file!!!  WT63_10042021
# Missing file!!!  WT63_10082021
# Missing file!!!  WT63_10112021
# Missing file!!!  WT63_10132021
# Missing file!!!  WT63_10182021
# Missing file!!!  WT63_11082021
# Missing file!!!  WT64_10042021
# Missing file!!!  WT64_10082021
# Missing file!!!  WT64_10112021
# Missing file!!!  WT64_10132021
# Missing file!!!  WT64_10182021
# Missing file!!!  WT65_10042021
# Missing file!!!  WT65_10082021
# Missing file!!!  WT65_10112021
# Missing file!!!  WT65_10132021
# Missing file!!!  WT65_10182021

# %%
### Figure 5: Flox Mice
figure = 'fig5'

# all_session_nums = [
#                     '03172022', '03212022', '03232022', '03252022', '03292022', '03312022', '04032022', '04052022',
#                     '04072022', '04082022', '04112022', '04132022', '04152022', '04202022', '04222022', '05022022',
#                     '05102022', '05162022', '05182022', '05222022', '05232022', '05242022', '05252022', '05262022',
#                     '05272022', '05292022', '05302022', '05312022',
#                     ]
all_session_nums = [
                    '03172022', '03212022', '03232022', '03252022', '03282022',
                    '03292022', '03302022', '03312022', '04012022', '04032022',
                    '04052022', '04072022', '04082022', '04112022', '04132022',
                    '04152022', '04202022', '04222022', '05022022', '05102022',
                    '05162022', '05182022', '05222022', '05232022', '05242022',
                    '05252022', '05262022', '05272022', '05292022', '05302022',
                    '05312022', '06022022', '06062022', '06082022', '06102022',
                    '06132022', '06152022', '06182022', '07072022', '07082022',
                    '07092022', '07112022', '07122022', '07132022', '07142022',
                    '07152022', '07162022', '07172022', '07182022', '07192022'
                   ]

# Drd2f/f control: S1417, 1419, 1421
# group_1_mice = ['S1417', 'S1419', 'S1421']
group_1_mice = ['S1417', 'S1419', 'S1421', 'S1460', 'S1462', 'S1473', 'S1474']
group_1_sess = all_session_nums
group_1_combo = ['_'.join(_) for _ in list(itertools.product(group_1_mice, group_1_sess))]

# Chat Cre X Drd2f/f: S1416, 1418, 1420, 1422
# group_2_mice = ['S1416', 'S1418', 'S1420', 'S1422']
group_2_mice = ['S1416', 'S1418', 'S1420', 'S1459', 'S1461', 'S1470', 'S1471', 'S1472'] # 'S1422', 
group_2_sess = all_session_nums
group_2_combo = ['_'.join(_) for _ in list(itertools.product(group_2_mice, group_2_sess))]

# Chat Cre control: S1355-1358, S1376
# group_3_mice = ['S1355', 'S1356', 'S1357', 'S1358', 'S1374', 'S1376']
group_3_mice = ['S1355', 'S1356', 'S1357', 'S1358', 'S1376',
                'S1448', 'S1449', 'S1450', 'S1451']
group_3_sess = all_session_nums
group_3_combo = ['_'.join(_) for _ in list(itertools.product(group_3_mice, group_3_sess))]

# Chat Cre control: S1399-1401
group_4_mice = ['S1399', 'S1400', 'S1401']
group_4_sess = all_session_nums
group_4_combo = ['_'.join(_) for _ in list(itertools.product(group_4_mice, group_4_sess))]

# group_5_mice = ['S1355', 'S1356', 'S1357', 'S1358', 'S1374', 'S1376',
#                'S1448', 'S1449', 'S1450', 'S1451'
#                'S1399', 'S1400', 'S1401']
group_5_mice = []
group_5_sess = all_session_nums
group_5_combo = ['_'.join(_) for _ in list(itertools.product(group_5_mice, group_5_sess))]

group_6_mice = []
group_6_sess = []
group_6_combo = ['_'.join(_) for _ in list(itertools.product(group_6_mice, group_6_sess))]


# channel_definitions = {}
# channel_definitions = {(file_combo,): {'Ch1': 'gACH', 'Ch2': 'rDA'} for file_combo in group_1_combo}
channel_definitions.update({(file_combo,): {'Ch5': 'gACH', 'Ch6': 'rDA', 'Ch1':'gDA'} for file_combo in group_1_combo})
channel_definitions.update({(file_combo,): {'Ch5': 'gACH', 'Ch6': 'rDA', 'Ch1':'gDA'} for file_combo in group_2_combo})
channel_definitions.update({(file_combo,): {'Ch5': 'gACH', 'Ch6': 'rDA', 'Ch1':'gDA'} for file_combo in group_3_combo})
channel_definitions.update({(file_combo,): {'Ch5': 'gACH', 'Ch6': 'rDA'} for file_combo in group_4_combo})
# channel_definitions.update({(file_combo,): {'Ch5': 'gACH', 'Ch6': 'rDA'} for file_combo in group_5_combo})
# channel_definitions.update({(file_combo,): {'Ch5': 'gACH', 'Ch6': 'rDA'} for file_combo in group_6_combo})


out_files = {}

fig_5_signal_files_setup = [group_1_combo, group_2_combo, group_3_combo, group_4_combo, group_5_combo, group_6_combo]
for g_num in range(0, len(fig_5_signal_files_setup)):
    fig_5_basis = fig_5_signal_files_setup[g_num]
    for f in fig_5_basis:
        glob_file = glob.glob(str(Path(f'../../data/raw/{figure}/GLM_SIGNALS_{f}*').resolve()))
        if len(glob_file) != 1:
            print('Missing file!!! ', f)
        else:
            signal_files += glob_file
            out_files[glob_file[0]] = (figure, figure + '/g' + str(g_num+1))
# Out:
# Missing file!!!  S1417_03172022
# Missing file!!!  S1417_03212022
# Missing file!!!  S1417_03232022
# Missing file!!!  S1417_03252022
# Missing file!!!  S1417_03282022
# Missing file!!!  S1417_03292022
# Missing file!!!  S1417_03302022
# Missing file!!!  S1417_03312022
# Missing file!!!  S1417_04012022
# Missing file!!!  S1417_04032022
# Missing file!!!  S1417_04052022
# Missing file!!!  S1417_04072022
# Missing file!!!  S1417_04082022
# Missing file!!!  S1417_04112022
# Missing file!!!  S1417_04132022
# Missing file!!!  S1417_04152022
# Missing file!!!  S1417_04202022
# Missing file!!!  S1417_04222022
# Missing file!!!  S1417_05022022
# Missing file!!!  S1417_05102022
# Missing file!!!  S1417_05162022
# Missing file!!!  S1417_05182022
# Missing file!!!  S1417_05222022
# Missing file!!!  S1417_05242022
# Missing file!!!  S1417_05252022
# Missing file!!!  S1417_05262022
# Missing file!!!  S1417_05292022
# Missing file!!!  S1417_05312022
# Missing file!!!  S1417_06022022
# Missing file!!!  S1417_06062022
# Missing file!!!  S1417_06082022
# Missing file!!!  S1417_06102022
# Missing file!!!  S1417_06132022
# Missing file!!!  S1417_06152022
# Missing file!!!  S1417_06182022
# Missing file!!!  S1417_07072022
# Missing file!!!  S1417_07082022
# Missing file!!!  S1417_07092022
# Missing file!!!  S1417_07112022
# Missing file!!!  S1417_07122022
# Missing file!!!  S1417_07132022
# Missing file!!!  S1417_07142022
# Missing file!!!  S1417_07152022
# Missing file!!!  S1417_07162022
# Missing file!!!  S1417_07172022
# Missing file!!!  S1417_07182022
# Missing file!!!  S1417_07192022
# Missing file!!!  S1419_03172022
# Missing file!!!  S1419_03212022
# Missing file!!!  S1419_03232022
# Missing file!!!  S1419_03252022
# Missing file!!!  S1419_03282022
# Missing file!!!  S1419_03292022
# Missing file!!!  S1419_03302022
# Missing file!!!  S1419_03312022
# Missing file!!!  S1419_04012022
# Missing file!!!  S1419_04032022
# Missing file!!!  S1419_04052022
# Missing file!!!  S1419_04072022
# Missing file!!!  S1419_04082022
# Missing file!!!  S1419_04112022
# Missing file!!!  S1419_04132022
# Missing file!!!  S1419_04152022
# Missing file!!!  S1419_04202022
# Missing file!!!  S1419_04222022
# Missing file!!!  S1419_05022022
# Missing file!!!  S1419_05102022
# Missing file!!!  S1419_05162022
# Missing file!!!  S1419_05182022
# Missing file!!!  S1419_05222022
# Missing file!!!  S1419_05242022
# Missing file!!!  S1419_05262022
# Missing file!!!  S1419_05292022
# Missing file!!!  S1419_05312022
# Missing file!!!  S1419_06022022
# Missing file!!!  S1419_06062022
# Missing file!!!  S1419_06082022
# Missing file!!!  S1419_06102022
# Missing file!!!  S1419_06132022
# Missing file!!!  S1419_06152022
# Missing file!!!  S1419_06182022
# Missing file!!!  S1419_07072022
# Missing file!!!  S1419_07082022
# Missing file!!!  S1419_07092022
# Missing file!!!  S1419_07112022
# Missing file!!!  S1419_07122022
# Missing file!!!  S1419_07132022
# Missing file!!!  S1419_07142022
# Missing file!!!  S1419_07152022
# Missing file!!!  S1419_07162022
# Missing file!!!  S1419_07172022
# Missing file!!!  S1419_07182022
# Missing file!!!  S1419_07192022
# Missing file!!!  S1421_03172022
# Missing file!!!  S1421_03212022
# Missing file!!!  S1421_03232022
# Missing file!!!  S1421_03252022
# Missing file!!!  S1421_03282022
# Missing file!!!  S1421_03292022
# Missing file!!!  S1421_03302022
# Missing file!!!  S1421_03312022
# Missing file!!!  S1421_04012022
# Missing file!!!  S1421_04032022
# Missing file!!!  S1421_04052022
# Missing file!!!  S1421_04072022
# Missing file!!!  S1421_04082022
# Missing file!!!  S1421_04112022
# Missing file!!!  S1421_04132022
# Missing file!!!  S1421_04152022
# Missing file!!!  S1421_04202022
# Missing file!!!  S1421_04222022
# Missing file!!!  S1421_05022022
# Missing file!!!  S1421_05102022
# Missing file!!!  S1421_05162022
# Missing file!!!  S1421_05182022
# Missing file!!!  S1421_05232022
# Missing file!!!  S1421_05252022
# Missing file!!!  S1421_05272022
# Missing file!!!  S1421_05302022
# Missing file!!!  S1421_06022022
# Missing file!!!  S1421_06062022
# Missing file!!!  S1421_06082022
# Missing file!!!  S1421_06102022
# Missing file!!!  S1421_06132022
# Missing file!!!  S1421_06152022
# Missing file!!!  S1421_06182022
# Missing file!!!  S1421_07072022
# Missing file!!!  S1421_07082022
# Missing file!!!  S1421_07092022
# Missing file!!!  S1421_07112022
# Missing file!!!  S1421_07122022
# Missing file!!!  S1421_07132022
# Missing file!!!  S1421_07142022
# Missing file!!!  S1421_07152022
# Missing file!!!  S1421_07162022
# Missing file!!!  S1421_07172022
# Missing file!!!  S1421_07182022
# Missing file!!!  S1421_07192022
# Missing file!!!  S1460_03172022
# Missing file!!!  S1460_03212022
# Missing file!!!  S1460_03232022
# Missing file!!!  S1460_03252022
# Missing file!!!  S1460_03282022
# Missing file!!!  S1460_03292022
# Missing file!!!  S1460_03302022
# Missing file!!!  S1460_03312022
# Missing file!!!  S1460_04012022
# Missing file!!!  S1460_04032022
# Missing file!!!  S1460_04052022
# Missing file!!!  S1460_04072022
# Missing file!!!  S1460_04082022
# Missing file!!!  S1460_04112022
# Missing file!!!  S1460_04132022
# Missing file!!!  S1460_04152022
# Missing file!!!  S1460_04202022
# Missing file!!!  S1460_04222022
# Missing file!!!  S1460_05022022
# Missing file!!!  S1460_05102022
# Missing file!!!  S1460_05162022
# Missing file!!!  S1460_05182022
# Missing file!!!  S1460_05222022
# Missing file!!!  S1460_05232022
# Missing file!!!  S1460_05242022
# Missing file!!!  S1460_05252022
# Missing file!!!  S1460_05262022
# Missing file!!!  S1460_05272022
# Missing file!!!  S1460_05292022
# Missing file!!!  S1460_05302022
# Missing file!!!  S1460_05312022
# Missing file!!!  S1460_06022022
# Missing file!!!  S1460_06062022
# Missing file!!!  S1460_06082022
# Missing file!!!  S1460_06102022
# Missing file!!!  S1460_06132022
# Missing file!!!  S1460_06152022
# Missing file!!!  S1460_06182022
# Missing file!!!  S1460_07072022
# Missing file!!!  S1460_07092022
# Missing file!!!  S1460_07112022
# Missing file!!!  S1460_07132022
# Missing file!!!  S1460_07152022
# Missing file!!!  S1460_07162022
# Missing file!!!  S1460_07172022
# Missing file!!!  S1460_07182022
# Missing file!!!  S1460_07192022
# Missing file!!!  S1462_03172022
# Missing file!!!  S1462_03212022
# Missing file!!!  S1462_03232022
# Missing file!!!  S1462_03252022
# Missing file!!!  S1462_03282022
# Missing file!!!  S1462_03292022
# Missing file!!!  S1462_03302022
# Missing file!!!  S1462_03312022
# Missing file!!!  S1462_04012022
# Missing file!!!  S1462_04032022
# Missing file!!!  S1462_04052022
# Missing file!!!  S1462_04072022
# Missing file!!!  S1462_04082022
# Missing file!!!  S1462_04112022
# Missing file!!!  S1462_04132022
# Missing file!!!  S1462_04152022
# Missing file!!!  S1462_04202022
# Missing file!!!  S1462_04222022
# Missing file!!!  S1462_05022022
# Missing file!!!  S1462_05102022
# Missing file!!!  S1462_05162022
# Missing file!!!  S1462_05182022
# Missing file!!!  S1462_05222022
# Missing file!!!  S1462_05232022
# Missing file!!!  S1462_05242022
# Missing file!!!  S1462_05252022
# Missing file!!!  S1462_05262022
# Missing file!!!  S1462_05272022
# Missing file!!!  S1462_05292022
# Missing file!!!  S1462_05302022
# Missing file!!!  S1462_05312022
# Missing file!!!  S1462_06022022
# Missing file!!!  S1462_06062022
# Missing file!!!  S1462_06082022
# Missing file!!!  S1462_06102022
# Missing file!!!  S1462_06132022
# Missing file!!!  S1462_06152022
# Missing file!!!  S1462_06182022
# Missing file!!!  S1462_07072022
# Missing file!!!  S1462_07092022
# Missing file!!!  S1462_07112022
# Missing file!!!  S1462_07132022
# Missing file!!!  S1462_07152022
# Missing file!!!  S1462_07172022
# Missing file!!!  S1462_07182022
# Missing file!!!  S1473_03172022
# Missing file!!!  S1473_03212022
# Missing file!!!  S1473_03232022
# Missing file!!!  S1473_03252022
# Missing file!!!  S1473_03282022
# Missing file!!!  S1473_03292022
# Missing file!!!  S1473_03302022
# Missing file!!!  S1473_03312022
# Missing file!!!  S1473_04012022
# Missing file!!!  S1473_04032022
# Missing file!!!  S1473_04052022
# Missing file!!!  S1473_04072022
# Missing file!!!  S1473_04082022
# Missing file!!!  S1473_04112022
# Missing file!!!  S1473_04132022
# Missing file!!!  S1473_04152022
# Missing file!!!  S1473_04202022
# Missing file!!!  S1473_04222022
# Missing file!!!  S1473_05022022
# Missing file!!!  S1473_05102022
# Missing file!!!  S1473_05162022
# Missing file!!!  S1473_05182022
# Missing file!!!  S1473_05222022
# Missing file!!!  S1473_05232022
# Missing file!!!  S1473_05242022
# Missing file!!!  S1473_05252022
# Missing file!!!  S1473_05262022
# Missing file!!!  S1473_05272022
# Missing file!!!  S1473_05292022
# Missing file!!!  S1473_05302022
# Missing file!!!  S1473_05312022
# Missing file!!!  S1473_06022022
# Missing file!!!  S1473_06062022
# Missing file!!!  S1473_06082022
# Missing file!!!  S1473_06102022
# Missing file!!!  S1473_06132022
# Missing file!!!  S1473_06152022
# Missing file!!!  S1473_06182022
# Missing file!!!  S1473_07082022
# Missing file!!!  S1473_07122022
# Missing file!!!  S1473_07142022
# Missing file!!!  S1473_07162022
# Missing file!!!  S1473_07182022
# Missing file!!!  S1473_07192022
# Missing file!!!  S1474_03172022
# Missing file!!!  S1474_03212022
# Missing file!!!  S1474_03232022
# Missing file!!!  S1474_03252022
# Missing file!!!  S1474_03282022
# Missing file!!!  S1474_03292022
# Missing file!!!  S1474_03302022
# Missing file!!!  S1474_03312022
# Missing file!!!  S1474_04012022
# Missing file!!!  S1474_04032022
# Missing file!!!  S1474_04052022
# Missing file!!!  S1474_04072022
# Missing file!!!  S1474_04082022
# Missing file!!!  S1474_04112022
# Missing file!!!  S1474_04132022
# Missing file!!!  S1474_04152022
# Missing file!!!  S1474_04202022
# Missing file!!!  S1474_04222022
# Missing file!!!  S1474_05022022
# Missing file!!!  S1474_05102022
# Missing file!!!  S1474_05162022
# Missing file!!!  S1474_05182022
# Missing file!!!  S1474_05222022
# Missing file!!!  S1474_05232022
# Missing file!!!  S1474_05242022
# Missing file!!!  S1474_05252022
# Missing file!!!  S1474_05262022
# Missing file!!!  S1474_05272022
# Missing file!!!  S1474_05292022
# Missing file!!!  S1474_05302022
# Missing file!!!  S1474_05312022
# Missing file!!!  S1474_06022022
# Missing file!!!  S1474_06062022
# Missing file!!!  S1474_06082022
# Missing file!!!  S1474_06102022
# Missing file!!!  S1474_06132022
# Missing file!!!  S1474_06152022
# Missing file!!!  S1474_06182022
# Missing file!!!  S1474_07072022
# Missing file!!!  S1474_07082022
# Missing file!!!  S1474_07092022
# Missing file!!!  S1474_07112022
# Missing file!!!  S1474_07122022
# Missing file!!!  S1474_07132022
# Missing file!!!  S1474_07152022
# Missing file!!!  S1474_07162022
# Missing file!!!  S1474_07172022
# Missing file!!!  S1474_07192022
# Missing file!!!  S1416_03172022
# Missing file!!!  S1416_03212022
# Missing file!!!  S1416_03232022
# Missing file!!!  S1416_03252022
# Missing file!!!  S1416_03282022
# Missing file!!!  S1416_03292022
# Missing file!!!  S1416_03302022
# Missing file!!!  S1416_03312022
# Missing file!!!  S1416_04012022
# Missing file!!!  S1416_04032022
# Missing file!!!  S1416_04052022
# Missing file!!!  S1416_04072022
# Missing file!!!  S1416_04082022
# Missing file!!!  S1416_04112022
# Missing file!!!  S1416_04132022
# Missing file!!!  S1416_04152022
# Missing file!!!  S1416_04202022
# Missing file!!!  S1416_04222022
# Missing file!!!  S1416_05022022
# Missing file!!!  S1416_05102022
# Missing file!!!  S1416_05162022
# Missing file!!!  S1416_05182022
# Missing file!!!  S1416_05222022
# Missing file!!!  S1416_05242022
# Missing file!!!  S1416_05262022
# Missing file!!!  S1416_05292022
# Missing file!!!  S1416_05312022
# Missing file!!!  S1416_06022022
# Missing file!!!  S1416_06062022
# Missing file!!!  S1416_06082022
# Missing file!!!  S1416_06102022
# Missing file!!!  S1416_06132022
# Missing file!!!  S1416_06152022
# Missing file!!!  S1416_06182022
# Missing file!!!  S1416_07072022
# Missing file!!!  S1416_07082022
# Missing file!!!  S1416_07092022
# Missing file!!!  S1416_07112022
# Missing file!!!  S1416_07122022
# Missing file!!!  S1416_07132022
# Missing file!!!  S1416_07142022
# Missing file!!!  S1416_07152022
# Missing file!!!  S1416_07162022
# Missing file!!!  S1416_07172022
# Missing file!!!  S1416_07182022
# Missing file!!!  S1416_07192022
# Missing file!!!  S1418_03172022
# Missing file!!!  S1418_03212022
# Missing file!!!  S1418_03232022
# Missing file!!!  S1418_03252022
# Missing file!!!  S1418_03282022
# Missing file!!!  S1418_03292022
# Missing file!!!  S1418_03302022
# Missing file!!!  S1418_03312022
# Missing file!!!  S1418_04012022
# Missing file!!!  S1418_04032022
# Missing file!!!  S1418_04052022
# Missing file!!!  S1418_04072022
# Missing file!!!  S1418_04082022
# Missing file!!!  S1418_04112022
# Missing file!!!  S1418_04132022
# Missing file!!!  S1418_04152022
# Missing file!!!  S1418_04202022
# Missing file!!!  S1418_04222022
# Missing file!!!  S1418_05022022
# Missing file!!!  S1418_05102022
# Missing file!!!  S1418_05162022
# Missing file!!!  S1418_05182022
# Missing file!!!  S1418_05222022
# Missing file!!!  S1418_05242022
# Missing file!!!  S1418_05252022
# Missing file!!!  S1418_05262022
# Missing file!!!  S1418_05302022
# Missing file!!!  S1418_06022022
# Missing file!!!  S1418_06062022
# Missing file!!!  S1418_06082022
# Missing file!!!  S1418_06102022
# Missing file!!!  S1418_06132022
# Missing file!!!  S1418_06152022
# Missing file!!!  S1418_06182022
# Missing file!!!  S1418_07072022
# Missing file!!!  S1418_07082022
# Missing file!!!  S1418_07092022
# Missing file!!!  S1418_07112022
# Missing file!!!  S1418_07122022
# Missing file!!!  S1418_07132022
# Missing file!!!  S1418_07142022
# Missing file!!!  S1418_07152022
# Missing file!!!  S1418_07162022
# Missing file!!!  S1418_07172022
# Missing file!!!  S1418_07182022
# Missing file!!!  S1418_07192022
# Missing file!!!  S1420_03172022
# Missing file!!!  S1420_03212022
# Missing file!!!  S1420_03232022
# Missing file!!!  S1420_03252022
# Missing file!!!  S1420_03282022
# Missing file!!!  S1420_03292022
# Missing file!!!  S1420_03302022
# Missing file!!!  S1420_03312022
# Missing file!!!  S1420_04012022
# Missing file!!!  S1420_04032022
# Missing file!!!  S1420_04052022
# Missing file!!!  S1420_04072022
# Missing file!!!  S1420_04082022
# Missing file!!!  S1420_04112022
# Missing file!!!  S1420_04132022
# Missing file!!!  S1420_04152022
# Missing file!!!  S1420_04202022
# Missing file!!!  S1420_04222022
# Missing file!!!  S1420_05022022
# Missing file!!!  S1420_05102022
# Missing file!!!  S1420_05162022
# Missing file!!!  S1420_05182022
# Missing file!!!  S1420_05232022
# Missing file!!!  S1420_05252022
# Missing file!!!  S1420_05272022
# Missing file!!!  S1420_05302022
# Missing file!!!  S1420_06022022
# Missing file!!!  S1420_06062022
# Missing file!!!  S1420_06082022
# Missing file!!!  S1420_06102022
# Missing file!!!  S1420_06132022
# Missing file!!!  S1420_06152022
# Missing file!!!  S1420_06182022
# Missing file!!!  S1420_07072022
# Missing file!!!  S1420_07082022
# Missing file!!!  S1420_07092022
# Missing file!!!  S1420_07112022
# Missing file!!!  S1420_07122022
# Missing file!!!  S1420_07132022
# Missing file!!!  S1420_07142022
# Missing file!!!  S1420_07152022
# Missing file!!!  S1420_07162022
# Missing file!!!  S1420_07172022
# Missing file!!!  S1420_07182022
# Missing file!!!  S1420_07192022
# Missing file!!!  S1459_03172022
# Missing file!!!  S1459_03212022
# Missing file!!!  S1459_03232022
# Missing file!!!  S1459_03252022
# Missing file!!!  S1459_03282022
# Missing file!!!  S1459_03292022
# Missing file!!!  S1459_03302022
# Missing file!!!  S1459_03312022
# Missing file!!!  S1459_04012022
# Missing file!!!  S1459_04032022
# Missing file!!!  S1459_04052022
# Missing file!!!  S1459_04072022
# Missing file!!!  S1459_04082022
# Missing file!!!  S1459_04112022
# Missing file!!!  S1459_04132022
# Missing file!!!  S1459_04152022
# Missing file!!!  S1459_04202022
# Missing file!!!  S1459_04222022
# Missing file!!!  S1459_05022022
# Missing file!!!  S1459_05102022
# Missing file!!!  S1459_05162022
# Missing file!!!  S1459_05182022
# Missing file!!!  S1459_05222022
# Missing file!!!  S1459_05232022
# Missing file!!!  S1459_05242022
# Missing file!!!  S1459_05252022
# Missing file!!!  S1459_05262022
# Missing file!!!  S1459_05272022
# Missing file!!!  S1459_05292022
# Missing file!!!  S1459_05302022
# Missing file!!!  S1459_05312022
# Missing file!!!  S1459_06022022
# Missing file!!!  S1459_06062022
# Missing file!!!  S1459_06082022
# Missing file!!!  S1459_06102022
# Missing file!!!  S1459_06132022
# Missing file!!!  S1459_06152022
# Missing file!!!  S1459_06182022
# Missing file!!!  S1459_07072022
# Missing file!!!  S1459_07092022
# Missing file!!!  S1459_07112022
# Missing file!!!  S1459_07132022
# Missing file!!!  S1459_07142022
# Missing file!!!  S1459_07152022
# Missing file!!!  S1459_07172022
# Missing file!!!  S1459_07182022
# Missing file!!!  S1461_03172022
# Missing file!!!  S1461_03212022
# Missing file!!!  S1461_03232022
# Missing file!!!  S1461_03252022
# Missing file!!!  S1461_03282022
# Missing file!!!  S1461_03292022
# Missing file!!!  S1461_03302022
# Missing file!!!  S1461_03312022
# Missing file!!!  S1461_04012022
# Missing file!!!  S1461_04032022
# Missing file!!!  S1461_04052022
# Missing file!!!  S1461_04072022
# Missing file!!!  S1461_04082022
# Missing file!!!  S1461_04112022
# Missing file!!!  S1461_04132022
# Missing file!!!  S1461_04152022
# Missing file!!!  S1461_04202022
# Missing file!!!  S1461_04222022
# Missing file!!!  S1461_05022022
# Missing file!!!  S1461_05102022
# Missing file!!!  S1461_05162022
# Missing file!!!  S1461_05182022
# Missing file!!!  S1461_05222022
# Missing file!!!  S1461_05232022
# Missing file!!!  S1461_05242022
# Missing file!!!  S1461_05252022
# Missing file!!!  S1461_05262022
# Missing file!!!  S1461_05272022
# Missing file!!!  S1461_05292022
# Missing file!!!  S1461_05302022
# Missing file!!!  S1461_05312022
# Missing file!!!  S1461_06022022
# Missing file!!!  S1461_06062022
# Missing file!!!  S1461_06082022
# Missing file!!!  S1461_06102022
# Missing file!!!  S1461_06132022
# Missing file!!!  S1461_06152022
# Missing file!!!  S1461_06182022
# Missing file!!!  S1461_07072022
# Missing file!!!  S1461_07092022
# Missing file!!!  S1461_07112022
# Missing file!!!  S1461_07132022
# Missing file!!!  S1461_07142022
# Missing file!!!  S1461_07152022
# Missing file!!!  S1461_07162022
# Missing file!!!  S1461_07172022
# Missing file!!!  S1461_07182022
# Missing file!!!  S1461_07192022
# Missing file!!!  S1470_03172022
# Missing file!!!  S1470_03212022
# Missing file!!!  S1470_03232022
# Missing file!!!  S1470_03252022
# Missing file!!!  S1470_03282022
# Missing file!!!  S1470_03292022
# Missing file!!!  S1470_03302022
# Missing file!!!  S1470_03312022
# Missing file!!!  S1470_04012022
# Missing file!!!  S1470_04032022
# Missing file!!!  S1470_04052022
# Missing file!!!  S1470_04072022
# Missing file!!!  S1470_04082022
# Missing file!!!  S1470_04112022
# Missing file!!!  S1470_04132022
# Missing file!!!  S1470_04152022
# Missing file!!!  S1470_04202022
# Missing file!!!  S1470_04222022
# Missing file!!!  S1470_05022022
# Missing file!!!  S1470_05102022
# Missing file!!!  S1470_05162022
# Missing file!!!  S1470_05182022
# Missing file!!!  S1470_05222022
# Missing file!!!  S1470_05232022
# Missing file!!!  S1470_05242022
# Missing file!!!  S1470_05252022
# Missing file!!!  S1470_05262022
# Missing file!!!  S1470_05272022
# Missing file!!!  S1470_05292022
# Missing file!!!  S1470_05302022
# Missing file!!!  S1470_05312022
# Missing file!!!  S1470_06022022
# Missing file!!!  S1470_06062022
# Missing file!!!  S1470_06082022
# Missing file!!!  S1470_06102022
# Missing file!!!  S1470_06132022
# Missing file!!!  S1470_06152022
# Missing file!!!  S1470_06182022
# Missing file!!!  S1470_07072022
# Missing file!!!  S1470_07082022
# Missing file!!!  S1470_07092022
# Missing file!!!  S1470_07112022
# Missing file!!!  S1470_07122022
# Missing file!!!  S1470_07132022
# Missing file!!!  S1470_07152022
# Missing file!!!  S1470_07162022
# Missing file!!!  S1470_07172022
# Missing file!!!  S1470_07192022
# Missing file!!!  S1471_03172022
# Missing file!!!  S1471_03212022
# Missing file!!!  S1471_03232022
# Missing file!!!  S1471_03252022
# Missing file!!!  S1471_03282022
# Missing file!!!  S1471_03292022
# Missing file!!!  S1471_03302022
# Missing file!!!  S1471_03312022
# Missing file!!!  S1471_04012022
# Missing file!!!  S1471_04032022
# Missing file!!!  S1471_04052022
# Missing file!!!  S1471_04072022
# Missing file!!!  S1471_04082022
# Missing file!!!  S1471_04112022
# Missing file!!!  S1471_04132022
# Missing file!!!  S1471_04152022
# Missing file!!!  S1471_04202022
# Missing file!!!  S1471_04222022
# Missing file!!!  S1471_05022022
# Missing file!!!  S1471_05102022
# Missing file!!!  S1471_05162022
# Missing file!!!  S1471_05182022
# Missing file!!!  S1471_05222022
# Missing file!!!  S1471_05232022
# Missing file!!!  S1471_05242022
# Missing file!!!  S1471_05252022
# Missing file!!!  S1471_05262022
# Missing file!!!  S1471_05272022
# Missing file!!!  S1471_05292022
# Missing file!!!  S1471_05302022
# Missing file!!!  S1471_05312022
# Missing file!!!  S1471_06022022
# Missing file!!!  S1471_06062022
# Missing file!!!  S1471_06082022
# Missing file!!!  S1471_06102022
# Missing file!!!  S1471_06132022
# Missing file!!!  S1471_06152022
# Missing file!!!  S1471_06182022
# Missing file!!!  S1471_07072022
# Missing file!!!  S1471_07082022
# Missing file!!!  S1471_07092022
# Missing file!!!  S1471_07112022
# Missing file!!!  S1471_07122022
# Missing file!!!  S1471_07142022
# Missing file!!!  S1471_07162022
# Missing file!!!  S1471_07182022
# Missing file!!!  S1471_07192022
# Missing file!!!  S1472_03172022
# Missing file!!!  S1472_03212022
# Missing file!!!  S1472_03232022
# Missing file!!!  S1472_03252022
# Missing file!!!  S1472_03282022
# Missing file!!!  S1472_03292022
# Missing file!!!  S1472_03302022
# Missing file!!!  S1472_03312022
# Missing file!!!  S1472_04012022
# Missing file!!!  S1472_04032022
# Missing file!!!  S1472_04052022
# Missing file!!!  S1472_04072022
# Missing file!!!  S1472_04082022
# Missing file!!!  S1472_04112022
# Missing file!!!  S1472_04132022
# Missing file!!!  S1472_04152022
# Missing file!!!  S1472_04202022
# Missing file!!!  S1472_04222022
# Missing file!!!  S1472_05022022
# Missing file!!!  S1472_05102022
# Missing file!!!  S1472_05162022
# Missing file!!!  S1472_05182022
# Missing file!!!  S1472_05222022
# Missing file!!!  S1472_05232022
# Missing file!!!  S1472_05242022
# Missing file!!!  S1472_05252022
# Missing file!!!  S1472_05262022
# Missing file!!!  S1472_05272022
# Missing file!!!  S1472_05292022
# Missing file!!!  S1472_05302022
# Missing file!!!  S1472_05312022
# Missing file!!!  S1472_06022022
# Missing file!!!  S1472_06062022
# Missing file!!!  S1472_06082022
# Missing file!!!  S1472_06102022
# Missing file!!!  S1472_06132022
# Missing file!!!  S1472_06152022
# Missing file!!!  S1472_06182022
# Missing file!!!  S1472_07082022
# Missing file!!!  S1472_07112022
# Missing file!!!  S1472_07122022
# Missing file!!!  S1472_07142022
# Missing file!!!  S1472_07152022
# Missing file!!!  S1472_07162022
# Missing file!!!  S1472_07182022
# Missing file!!!  S1472_07192022
# Missing file!!!  S1355_03232022
# Missing file!!!  S1355_03282022
# Missing file!!!  S1355_03292022
# Missing file!!!  S1355_03302022
# Missing file!!!  S1355_04012022
# Missing file!!!  S1355_04032022
# Missing file!!!  S1355_04052022
# Missing file!!!  S1355_04072022
# Missing file!!!  S1355_04082022
# Missing file!!!  S1355_04112022
# Missing file!!!  S1355_04132022
# Missing file!!!  S1355_04152022
# Missing file!!!  S1355_04202022
# Missing file!!!  S1355_04222022
# Missing file!!!  S1355_05022022
# Missing file!!!  S1355_05102022
# Missing file!!!  S1355_05162022
# Missing file!!!  S1355_05182022
# Missing file!!!  S1355_05222022
# Missing file!!!  S1355_05232022
# Missing file!!!  S1355_05242022
# Missing file!!!  S1355_05252022
# Missing file!!!  S1355_05262022
# Missing file!!!  S1355_05272022
# Missing file!!!  S1355_05292022
# Missing file!!!  S1355_05302022
# Missing file!!!  S1355_05312022
# Missing file!!!  S1355_06022022
# Missing file!!!  S1355_06062022
# Missing file!!!  S1355_06082022
# Missing file!!!  S1355_06102022
# Missing file!!!  S1355_06132022
# Missing file!!!  S1355_06152022
# Missing file!!!  S1355_06182022
# Missing file!!!  S1355_07072022
# Missing file!!!  S1355_07082022
# Missing file!!!  S1355_07092022
# Missing file!!!  S1355_07112022
# Missing file!!!  S1355_07122022
# Missing file!!!  S1355_07132022
# Missing file!!!  S1355_07142022
# Missing file!!!  S1355_07152022
# Missing file!!!  S1355_07162022
# Missing file!!!  S1355_07172022
# Missing file!!!  S1355_07182022
# Missing file!!!  S1355_07192022
# Missing file!!!  S1356_03232022
# Missing file!!!  S1356_03282022
# Missing file!!!  S1356_03302022
# Missing file!!!  S1356_04012022
# Missing file!!!  S1356_04032022
# Missing file!!!  S1356_04052022
# Missing file!!!  S1356_04072022
# Missing file!!!  S1356_04082022
# Missing file!!!  S1356_04112022
# Missing file!!!  S1356_04132022
# Missing file!!!  S1356_04152022
# Missing file!!!  S1356_04202022
# Missing file!!!  S1356_04222022
# Missing file!!!  S1356_05022022
# Missing file!!!  S1356_05102022
# Missing file!!!  S1356_05162022
# Missing file!!!  S1356_05182022
# Missing file!!!  S1356_05222022
# Missing file!!!  S1356_05232022
# Missing file!!!  S1356_05242022
# Missing file!!!  S1356_05252022
# Missing file!!!  S1356_05262022
# Missing file!!!  S1356_05272022
# Missing file!!!  S1356_05292022
# Missing file!!!  S1356_05302022
# Missing file!!!  S1356_05312022
# Missing file!!!  S1356_06022022
# Missing file!!!  S1356_06062022
# Missing file!!!  S1356_06082022
# Missing file!!!  S1356_06102022
# Missing file!!!  S1356_06132022
# Missing file!!!  S1356_06152022
# Missing file!!!  S1356_06182022
# Missing file!!!  S1356_07072022
# Missing file!!!  S1356_07082022
# Missing file!!!  S1356_07092022
# Missing file!!!  S1356_07112022
# Missing file!!!  S1356_07122022
# Missing file!!!  S1356_07132022
# Missing file!!!  S1356_07142022
# Missing file!!!  S1356_07152022
# Missing file!!!  S1356_07162022
# Missing file!!!  S1356_07172022
# Missing file!!!  S1356_07182022
# Missing file!!!  S1356_07192022
# Missing file!!!  S1357_03282022
# Missing file!!!  S1357_03302022
# Missing file!!!  S1357_04012022
# Missing file!!!  S1357_04032022
# Missing file!!!  S1357_04052022
# Missing file!!!  S1357_04072022
# Missing file!!!  S1357_04082022
# Missing file!!!  S1357_04112022
# Missing file!!!  S1357_04132022
# Missing file!!!  S1357_04152022
# Missing file!!!  S1357_04202022
# Missing file!!!  S1357_04222022
# Missing file!!!  S1357_05022022
# Missing file!!!  S1357_05102022
# Missing file!!!  S1357_05162022
# Missing file!!!  S1357_05182022
# Missing file!!!  S1357_05222022
# Missing file!!!  S1357_05232022
# Missing file!!!  S1357_05242022
# Missing file!!!  S1357_05252022
# Missing file!!!  S1357_05262022
# Missing file!!!  S1357_05272022
# Missing file!!!  S1357_05292022
# Missing file!!!  S1357_05302022
# Missing file!!!  S1357_05312022
# Missing file!!!  S1357_06022022
# Missing file!!!  S1357_06062022
# Missing file!!!  S1357_06082022
# Missing file!!!  S1357_06102022
# Missing file!!!  S1357_06132022
# Missing file!!!  S1357_06152022
# Missing file!!!  S1357_06182022
# Missing file!!!  S1357_07072022
# Missing file!!!  S1357_07082022
# Missing file!!!  S1357_07092022
# Missing file!!!  S1357_07112022
# Missing file!!!  S1357_07122022
# Missing file!!!  S1357_07132022
# Missing file!!!  S1357_07142022
# Missing file!!!  S1357_07152022
# Missing file!!!  S1357_07162022
# Missing file!!!  S1357_07172022
# Missing file!!!  S1357_07182022
# Missing file!!!  S1357_07192022
# Missing file!!!  S1358_03282022
# Missing file!!!  S1358_03302022
# Missing file!!!  S1358_03312022
# Missing file!!!  S1358_04012022
# Missing file!!!  S1358_04032022
# Missing file!!!  S1358_04052022
# Missing file!!!  S1358_04072022
# Missing file!!!  S1358_04082022
# Missing file!!!  S1358_04112022
# Missing file!!!  S1358_04132022
# Missing file!!!  S1358_04152022
# Missing file!!!  S1358_04202022
# Missing file!!!  S1358_04222022
# Missing file!!!  S1358_05022022
# Missing file!!!  S1358_05102022
# Missing file!!!  S1358_05162022
# Missing file!!!  S1358_05182022
# Missing file!!!  S1358_05222022
# Missing file!!!  S1358_05232022
# Missing file!!!  S1358_05242022
# Missing file!!!  S1358_05252022
# Missing file!!!  S1358_05262022
# Missing file!!!  S1358_05272022
# Missing file!!!  S1358_05292022
# Missing file!!!  S1358_05302022
# Missing file!!!  S1358_05312022
# Missing file!!!  S1358_06022022
# Missing file!!!  S1358_06062022
# Missing file!!!  S1358_06082022
# Missing file!!!  S1358_06102022
# Missing file!!!  S1358_06132022
# Missing file!!!  S1358_06152022
# Missing file!!!  S1358_06182022
# Missing file!!!  S1358_07072022
# Missing file!!!  S1358_07082022
# Missing file!!!  S1358_07092022
# Missing file!!!  S1358_07112022
# Missing file!!!  S1358_07122022
# Missing file!!!  S1358_07132022
# Missing file!!!  S1358_07142022
# Missing file!!!  S1358_07152022
# Missing file!!!  S1358_07162022
# Missing file!!!  S1358_07172022
# Missing file!!!  S1358_07182022
# Missing file!!!  S1358_07192022
# Missing file!!!  S1376_03172022
# Missing file!!!  S1376_03212022
# Missing file!!!  S1376_03232022
# Missing file!!!  S1376_03252022
# Missing file!!!  S1376_03292022
# Missing file!!!  S1376_03312022
# Missing file!!!  S1376_04082022
# Missing file!!!  S1376_04112022
# Missing file!!!  S1376_04132022
# Missing file!!!  S1376_04152022
# Missing file!!!  S1376_04202022
# Missing file!!!  S1376_04222022
# Missing file!!!  S1376_05022022
# Missing file!!!  S1376_05102022
# Missing file!!!  S1376_05162022
# Missing file!!!  S1376_05182022
# Missing file!!!  S1376_05222022
# Missing file!!!  S1376_05232022
# Missing file!!!  S1376_05242022
# Missing file!!!  S1376_05252022
# Missing file!!!  S1376_05262022
# Missing file!!!  S1376_05272022
# Missing file!!!  S1376_05292022
# Missing file!!!  S1376_05302022
# Missing file!!!  S1376_05312022
# Missing file!!!  S1376_06022022
# Missing file!!!  S1376_06062022
# Missing file!!!  S1376_06082022
# Missing file!!!  S1376_06102022
# Missing file!!!  S1376_06132022
# Missing file!!!  S1376_06152022
# Missing file!!!  S1376_06182022
# Missing file!!!  S1376_07072022
# Missing file!!!  S1376_07082022
# Missing file!!!  S1376_07092022
# Missing file!!!  S1376_07112022
# Missing file!!!  S1376_07122022
# Missing file!!!  S1376_07132022
# Missing file!!!  S1376_07142022
# Missing file!!!  S1376_07152022
# Missing file!!!  S1376_07162022
# Missing file!!!  S1376_07172022
# Missing file!!!  S1376_07182022
# Missing file!!!  S1376_07192022
# Missing file!!!  S1448_03172022
# Missing file!!!  S1448_03212022
# Missing file!!!  S1448_03232022
# Missing file!!!  S1448_03252022
# Missing file!!!  S1448_03282022
# Missing file!!!  S1448_03292022
# Missing file!!!  S1448_03302022
# Missing file!!!  S1448_03312022
# Missing file!!!  S1448_04012022
# Missing file!!!  S1448_04032022
# Missing file!!!  S1448_04052022
# Missing file!!!  S1448_04072022
# Missing file!!!  S1448_04082022
# Missing file!!!  S1448_04112022
# Missing file!!!  S1448_04132022
# Missing file!!!  S1448_04152022
# Missing file!!!  S1448_04202022
# Missing file!!!  S1448_04222022
# Missing file!!!  S1448_05022022
# Missing file!!!  S1448_05102022
# Missing file!!!  S1448_05162022
# Missing file!!!  S1448_05182022
# Missing file!!!  S1448_05222022
# Missing file!!!  S1448_05232022
# Missing file!!!  S1448_05242022
# Missing file!!!  S1448_05252022
# Missing file!!!  S1448_05262022
# Missing file!!!  S1448_05272022
# Missing file!!!  S1448_05292022
# Missing file!!!  S1448_05302022
# Missing file!!!  S1448_05312022
# Missing file!!!  S1448_07072022
# Missing file!!!  S1448_07082022
# Missing file!!!  S1448_07092022
# Missing file!!!  S1448_07112022
# Missing file!!!  S1448_07122022
# Missing file!!!  S1448_07132022
# Missing file!!!  S1448_07142022
# Missing file!!!  S1448_07152022
# Missing file!!!  S1448_07162022
# Missing file!!!  S1448_07172022
# Missing file!!!  S1448_07182022
# Missing file!!!  S1448_07192022
# Missing file!!!  S1449_03172022
# Missing file!!!  S1449_03212022
# Missing file!!!  S1449_03232022
# Missing file!!!  S1449_03252022
# Missing file!!!  S1449_03282022
# Missing file!!!  S1449_03292022
# Missing file!!!  S1449_03302022
# Missing file!!!  S1449_03312022
# Missing file!!!  S1449_04012022
# Missing file!!!  S1449_04032022
# Missing file!!!  S1449_04052022
# Missing file!!!  S1449_04072022
# Missing file!!!  S1449_04082022
# Missing file!!!  S1449_04112022
# Missing file!!!  S1449_04132022
# Missing file!!!  S1449_04152022
# Missing file!!!  S1449_04202022
# Missing file!!!  S1449_04222022
# Missing file!!!  S1449_05022022
# Missing file!!!  S1449_05102022
# Missing file!!!  S1449_05162022
# Missing file!!!  S1449_05182022
# Missing file!!!  S1449_05222022
# Missing file!!!  S1449_05232022
# Missing file!!!  S1449_05242022
# Missing file!!!  S1449_05252022
# Missing file!!!  S1449_05262022
# Missing file!!!  S1449_05272022
# Missing file!!!  S1449_05292022
# Missing file!!!  S1449_05302022
# Missing file!!!  S1449_05312022
# Missing file!!!  S1449_07072022
# Missing file!!!  S1449_07082022
# Missing file!!!  S1449_07092022
# Missing file!!!  S1449_07112022
# Missing file!!!  S1449_07122022
# Missing file!!!  S1449_07132022
# Missing file!!!  S1449_07142022
# Missing file!!!  S1449_07152022
# Missing file!!!  S1449_07162022
# Missing file!!!  S1449_07172022
# Missing file!!!  S1449_07182022
# Missing file!!!  S1449_07192022
# Missing file!!!  S1450_03172022
# Missing file!!!  S1450_03212022
# Missing file!!!  S1450_03232022
# Missing file!!!  S1450_03252022
# Missing file!!!  S1450_03282022
# Missing file!!!  S1450_03292022
# Missing file!!!  S1450_03302022
# Missing file!!!  S1450_03312022
# Missing file!!!  S1450_04012022
# Missing file!!!  S1450_04032022
# Missing file!!!  S1450_04052022
# Missing file!!!  S1450_04072022
# Missing file!!!  S1450_04082022
# Missing file!!!  S1450_04112022
# Missing file!!!  S1450_04132022
# Missing file!!!  S1450_04152022
# Missing file!!!  S1450_04202022
# Missing file!!!  S1450_04222022
# Missing file!!!  S1450_05022022
# Missing file!!!  S1450_05102022
# Missing file!!!  S1450_05162022
# Missing file!!!  S1450_05182022
# Missing file!!!  S1450_05222022
# Missing file!!!  S1450_05232022
# Missing file!!!  S1450_05242022
# Missing file!!!  S1450_05252022
# Missing file!!!  S1450_05262022
# Missing file!!!  S1450_05272022
# Missing file!!!  S1450_05292022
# Missing file!!!  S1450_05302022
# Missing file!!!  S1450_05312022
# Missing file!!!  S1450_07072022
# Missing file!!!  S1450_07082022
# Missing file!!!  S1450_07092022
# Missing file!!!  S1450_07112022
# Missing file!!!  S1450_07122022
# Missing file!!!  S1450_07132022
# Missing file!!!  S1450_07142022
# Missing file!!!  S1450_07152022
# Missing file!!!  S1450_07162022
# Missing file!!!  S1450_07172022
# Missing file!!!  S1450_07182022
# Missing file!!!  S1450_07192022
# Missing file!!!  S1451_03172022
# Missing file!!!  S1451_03212022
# Missing file!!!  S1451_03232022
# Missing file!!!  S1451_03252022
# Missing file!!!  S1451_03282022
# Missing file!!!  S1451_03292022
# Missing file!!!  S1451_03302022
# Missing file!!!  S1451_03312022
# Missing file!!!  S1451_04012022
# Missing file!!!  S1451_04032022
# Missing file!!!  S1451_04052022
# Missing file!!!  S1451_04072022
# Missing file!!!  S1451_04082022
# Missing file!!!  S1451_04112022
# Missing file!!!  S1451_04132022
# Missing file!!!  S1451_04152022
# Missing file!!!  S1451_04202022
# Missing file!!!  S1451_04222022
# Missing file!!!  S1451_05022022
# Missing file!!!  S1451_05102022
# Missing file!!!  S1451_05162022
# Missing file!!!  S1451_05182022
# Missing file!!!  S1451_05222022
# Missing file!!!  S1451_05232022
# Missing file!!!  S1451_05242022
# Missing file!!!  S1451_05252022
# Missing file!!!  S1451_05262022
# Missing file!!!  S1451_05272022
# Missing file!!!  S1451_05292022
# Missing file!!!  S1451_05302022
# Missing file!!!  S1451_05312022
# Missing file!!!  S1451_07072022
# Missing file!!!  S1451_07082022
# Missing file!!!  S1451_07092022
# Missing file!!!  S1451_07112022
# Missing file!!!  S1451_07122022
# Missing file!!!  S1451_07132022
# Missing file!!!  S1451_07142022
# Missing file!!!  S1451_07152022
# Missing file!!!  S1451_07162022
# Missing file!!!  S1451_07172022
# Missing file!!!  S1451_07182022
# Missing file!!!  S1451_07192022
# Missing file!!!  S1399_03172022
# Missing file!!!  S1399_03212022
# Missing file!!!  S1399_03232022
# Missing file!!!  S1399_03252022
# Missing file!!!  S1399_03282022
# Missing file!!!  S1399_03292022
# Missing file!!!  S1399_03302022
# Missing file!!!  S1399_03312022
# Missing file!!!  S1399_04012022
# Missing file!!!  S1399_04032022
# Missing file!!!  S1399_04052022
# Missing file!!!  S1399_04072022
# Missing file!!!  S1399_04082022
# Missing file!!!  S1399_04112022
# Missing file!!!  S1399_04132022
# Missing file!!!  S1399_04152022
# Missing file!!!  S1399_04202022
# Missing file!!!  S1399_04222022
# Missing file!!!  S1399_05222022
# Missing file!!!  S1399_05232022
# Missing file!!!  S1399_05242022
# Missing file!!!  S1399_05252022
# Missing file!!!  S1399_05262022
# Missing file!!!  S1399_05272022
# Missing file!!!  S1399_05292022
# Missing file!!!  S1399_05302022
# Missing file!!!  S1399_05312022
# Missing file!!!  S1399_06022022
# Missing file!!!  S1399_06062022
# Missing file!!!  S1399_06082022
# Missing file!!!  S1399_06102022
# Missing file!!!  S1399_06132022
# Missing file!!!  S1399_06152022
# Missing file!!!  S1399_06182022
# Missing file!!!  S1399_07072022
# Missing file!!!  S1399_07082022
# Missing file!!!  S1399_07092022
# Missing file!!!  S1399_07112022
# Missing file!!!  S1399_07122022
# Missing file!!!  S1399_07132022
# Missing file!!!  S1399_07142022
# Missing file!!!  S1399_07152022
# Missing file!!!  S1399_07162022
# Missing file!!!  S1399_07172022
# Missing file!!!  S1399_07182022
# Missing file!!!  S1399_07192022
# Missing file!!!  S1400_03172022
# Missing file!!!  S1400_03212022
# Missing file!!!  S1400_03232022
# Missing file!!!  S1400_03252022
# Missing file!!!  S1400_03282022
# Missing file!!!  S1400_03292022
# Missing file!!!  S1400_03302022
# Missing file!!!  S1400_03312022
# Missing file!!!  S1400_04012022
# Missing file!!!  S1400_04032022
# Missing file!!!  S1400_04052022
# Missing file!!!  S1400_04072022
# Missing file!!!  S1400_04082022
# Missing file!!!  S1400_04112022
# Missing file!!!  S1400_04132022
# Missing file!!!  S1400_04152022
# Missing file!!!  S1400_04202022
# Missing file!!!  S1400_04222022
# Missing file!!!  S1400_05222022
# Missing file!!!  S1400_05232022
# Missing file!!!  S1400_05242022
# Missing file!!!  S1400_05252022
# Missing file!!!  S1400_05262022
# Missing file!!!  S1400_05272022
# Missing file!!!  S1400_05292022
# Missing file!!!  S1400_05302022
# Missing file!!!  S1400_05312022
# Missing file!!!  S1400_06022022
# Missing file!!!  S1400_06062022
# Missing file!!!  S1400_06082022
# Missing file!!!  S1400_06102022
# Missing file!!!  S1400_06132022
# Missing file!!!  S1400_06152022
# Missing file!!!  S1400_06182022
# Missing file!!!  S1400_07072022
# Missing file!!!  S1400_07082022
# Missing file!!!  S1400_07092022
# Missing file!!!  S1400_07112022
# Missing file!!!  S1400_07122022
# Missing file!!!  S1400_07132022
# Missing file!!!  S1400_07142022
# Missing file!!!  S1400_07152022
# Missing file!!!  S1400_07162022
# Missing file!!!  S1400_07172022
# Missing file!!!  S1400_07182022
# Missing file!!!  S1400_07192022
# Missing file!!!  S1401_03172022
# Missing file!!!  S1401_03212022
# Missing file!!!  S1401_03232022
# Missing file!!!  S1401_03252022
# Missing file!!!  S1401_03282022
# Missing file!!!  S1401_03292022
# Missing file!!!  S1401_03302022
# Missing file!!!  S1401_03312022
# Missing file!!!  S1401_04012022
# Missing file!!!  S1401_04032022
# Missing file!!!  S1401_04052022
# Missing file!!!  S1401_04072022
# Missing file!!!  S1401_04082022
# Missing file!!!  S1401_04112022
# Missing file!!!  S1401_04132022
# Missing file!!!  S1401_04152022
# Missing file!!!  S1401_04202022
# Missing file!!!  S1401_04222022
# Missing file!!!  S1401_05162022
# Missing file!!!  S1401_05222022
# Missing file!!!  S1401_05232022
# Missing file!!!  S1401_05242022
# Missing file!!!  S1401_05252022
# Missing file!!!  S1401_05262022
# Missing file!!!  S1401_05272022
# Missing file!!!  S1401_05292022
# Missing file!!!  S1401_05302022
# Missing file!!!  S1401_05312022
# Missing file!!!  S1401_06022022
# Missing file!!!  S1401_06062022
# Missing file!!!  S1401_06082022
# Missing file!!!  S1401_06102022
# Missing file!!!  S1401_06132022
# Missing file!!!  S1401_06152022
# Missing file!!!  S1401_06182022
# Missing file!!!  S1401_07072022
# Missing file!!!  S1401_07082022
# Missing file!!!  S1401_07092022
# Missing file!!!  S1401_07112022
# Missing file!!!  S1401_07122022
# Missing file!!!  S1401_07132022
# Missing file!!!  S1401_07142022
# Missing file!!!  S1401_07152022
# Missing file!!!  S1401_07162022
# Missing file!!!  S1401_07172022
# Missing file!!!  S1401_07182022
# Missing file!!!  S1401_07192022

# %%
# ### Figure 5: Flox Mice
# figure = 'fig5'

# # all_session_nums = [
# #                     '03172022', '03212022', '03232022', '03252022', '03292022', '03312022', '04032022', '04052022',
# #                     '04072022', '04082022', '04112022', '04132022', '04152022', '04202022', '04222022', '05022022',
# #                     '05102022', '05162022', '05182022', '05222022', '05232022', '05242022', '05252022', '05262022',
# #                     '05272022', '05292022', '05302022', '05312022',
# #                     ]
# all_session_nums = [
#                     '03172022', '03212022', '03232022', '03252022', '03282022',
#                     '03292022', '03302022', '03312022', '04012022', '04032022',
#                     '04052022', '04072022', '04082022', '04112022', '04132022',
#                     '04152022', '04202022', '04222022', '05022022', '05102022',
#                     '05162022', '05182022', '05222022', '05232022', '05242022',
#                     '05252022', '05262022', '05272022', '05292022', '05302022',
#                     '05312022', '06022022', '06062022', '06082022', '06102022',
#                     '06132022', '06152022', '06182022', '07072022', '07082022',
#                     '07092022', '07112022', '07122022', '07132022', '07142022',
#                     '07152022', '07162022', '07172022', '07182022', '07192022'
#                    ]

# # Drd2f/f control: S1417, 1419, 1421
# # group_1_mice = ['S1417', 'S1419', 'S1421']
# group_1_mice = ['S1417', 'S1419', 'S1421', 'S1460', 'S1462', 'S1473', 'S1474']
# group_1_sess = all_session_nums
# group_1_combo = ['_'.join(_) for _ in list(itertools.product(group_1_mice, group_1_sess))]

# # Chat Cre X Drd2f/f: S1416, 1418, 1420, 1422
# # group_2_mice = ['S1416', 'S1418', 'S1420', 'S1422']
# group_2_mice = ['S1416', 'S1418', 'S1420', 'S1459', 'S1461', 'S1470', 'S1471', 'S1472'] # 'S1422', 
# group_2_sess = all_session_nums
# group_2_combo = ['_'.join(_) for _ in list(itertools.product(group_2_mice, group_2_sess))]

# # Chat Cre control: S1355-1358, S1374, S1376
# # group_3_mice = ['S1355', 'S1356', 'S1357', 'S1358', 'S1374', 'S1376']
# group_3_mice = ['S1355', 'S1356', 'S1357', 'S1358', 'S1374', 'S1376',
#                 'S1448', 'S1449', 'S1450', 'S1451']
# group_3_sess = all_session_nums
# group_3_combo = ['_'.join(_) for _ in list(itertools.product(group_3_mice, group_3_sess))]

# # Chat Cre control: S1399-1401
# group_4_mice = ['S1399', 'S1400', 'S1401']
# group_4_sess = all_session_nums
# group_4_combo = ['_'.join(_) for _ in list(itertools.product(group_4_mice, group_4_sess))]

# group_5_mice = ['S1355', 'S1356', 'S1357', 'S1358', 'S1374', 'S1376',
#                'S1448', 'S1449', 'S1450', 'S1451'
#                'S1399', 'S1400', 'S1401']
# group_5_sess = all_session_nums
# group_5_combo = ['_'.join(_) for _ in list(itertools.product(group_5_mice, group_5_sess))]

# group_6_mice = []
# group_6_sess = []
# group_6_combo = ['_'.join(_) for _ in list(itertools.product(group_6_mice, group_6_sess))]


# channel_definitions = {}
# # channel_definitions = {(file_combo,): {'Ch1': 'gACH', 'Ch2': 'rDA'} for file_combo in group_1_combo}
# channel_definitions.update({(file_combo,): {'Ch5': 'gACH', 'Ch6': 'rDA', 'Ch1':'gDA'} for file_combo in group_1_combo})
# channel_definitions.update({(file_combo,): {'Ch5': 'gACH', 'Ch6': 'rDA', 'Ch1':'gDA'} for file_combo in group_2_combo})
# channel_definitions.update({(file_combo,): {'Ch5': 'gACH', 'Ch6': 'rDA', 'Ch1':'gDA'} for file_combo in group_3_combo})
# channel_definitions.update({(file_combo,): {'Ch5': 'gACH', 'Ch6': 'rDA'} for file_combo in group_4_combo})
# # channel_definitions.update({(file_combo,): {'Ch5': 'gACH', 'Ch6': 'rDA'} for file_combo in group_5_combo})
# # channel_definitions.update({(file_combo,): {'Ch5': 'gACH', 'Ch6': 'rDA'} for file_combo in group_6_combo})


# out_files = {}

# fig_5_signal_files_setup = [group_1_combo, group_2_combo, group_3_combo, group_4_combo, group_5_combo, group_6_combo]
# for g_num in range(0, len(fig_5_signal_files_setup)):
#     fig_5_basis = fig_5_signal_files_setup[g_num]
#     for f in fig_5_basis:
#         glob_file = glob.glob(f'../../data/raw/{figure}/GLM_SIGNALS_{f}*')
#         if len(glob_file) != 1:
#             print('Missing file!!! ', f)
#         else:
#             signal_files += glob_file
#             out_files[glob_file[0]] = (figure, figure + '/g' + str(g_num+1))

# %%
### Figure 4: Tetanus Mice
figure = 'fig4'

# all_session_nums = [
#                     '03172022', '03212022', '03232022', '03252022', '03292022', '03312022', '04032022', '04052022',
#                     '04072022', '04082022', '04112022', '04132022', '04152022', '04202022', '04222022', '05022022',
#                     '05102022', '05162022', '05182022', '05222022', '05232022', '05242022', '05252022', '05262022',
#                     '05272022', '05292022', '05302022', '05312022',
#                     ]
all_session_nums = ['08312021', '09022021', '09062021', '09082021', '09102021', '09132021',
                    '09152021', '09172021', '09202021', '10052021', '10072021', '10122021',
                    '10142021', '10192021', '10212021', '10252021', '10272021', '11302021',
                    '12022021', '12032021', '12062021', '12072021', '12082021', '12092021',
                    '12102021', '12132021', '12142021']

# Control
group_1_mice = ['S1233', 'S1234', 'S1260', 'S1246', 'S1248']
group_1_sess = all_session_nums
group_1_combo = ['_'.join(_) for _ in list(itertools.product(group_1_mice, group_1_sess))]

# Tetanus
group_2_mice = ['S1194', 'S1195', 'S1214', 'S1258', 'S1259']
group_2_sess = all_session_nums
group_2_combo = ['_'.join(_) for _ in list(itertools.product(group_2_mice, group_2_sess))]

group_3_mice = []
group_3_sess = all_session_nums
group_3_combo = ['_'.join(_) for _ in list(itertools.product(group_3_mice, group_3_sess))]

group_4_mice = []
group_4_sess = all_session_nums
group_4_combo = ['_'.join(_) for _ in list(itertools.product(group_4_mice, group_4_sess))]

group_5_mice = []
group_5_sess = all_session_nums
group_5_combo = ['_'.join(_) for _ in list(itertools.product(group_5_mice, group_5_sess))]

group_6_mice = []
group_6_sess = []
group_6_combo = ['_'.join(_) for _ in list(itertools.product(group_6_mice, group_6_sess))]


# channel_definitions = {}
# channel_definitions = {(file_combo,): {'Ch1': 'gACH', 'Ch2': 'rDA'} for file_combo in group_1_combo}
channel_definitions.update({(file_combo,): {'Ch5': 'gDA'} for file_combo in group_1_combo})
channel_definitions.update({(file_combo,): {'Ch5': 'gDA'} for file_combo in group_2_combo})
# channel_definitions.update({(file_combo,): {'Ch5': 'gACH', 'Ch6': 'rDA', 'Ch1':'gDA'} for file_combo in group_3_combo})
# channel_definitions.update({(file_combo,): {'Ch5': 'gACH', 'Ch6': 'rDA'} for file_combo in group_4_combo})
# channel_definitions.update({(file_combo,): {'Ch5': 'gACH', 'Ch6': 'rDA'} for file_combo in group_5_combo})
# channel_definitions.update({(file_combo,): {'Ch5': 'gACH', 'Ch6': 'rDA'} for file_combo in group_6_combo})


fig_4_signal_files_setup = [group_1_combo, group_2_combo, group_3_combo, group_4_combo, group_5_combo, group_6_combo]
for g_num in range(0, len(fig_4_signal_files_setup)):
    fig_4_basis = fig_4_signal_files_setup[g_num]
    for f in fig_4_basis:
        glob_file = glob.glob(str(Path(f'../../data/raw/{figure}/GLM_SIGNALS_{f}*').resolve()))
        if len(glob_file) != 1:
            print('Missing file!!! ', f)
        else:
            signal_files += glob_file
            out_files[glob_file[0]] = (figure, figure + '/g' + str(g_num+1))
# Out:
# Missing file!!!  S1233_08312021
# Missing file!!!  S1233_09022021
# Missing file!!!  S1233_09062021
# Missing file!!!  S1233_09082021
# Missing file!!!  S1233_09102021
# Missing file!!!  S1233_09132021
# Missing file!!!  S1233_09152021
# Missing file!!!  S1233_09172021
# Missing file!!!  S1233_09202021
# Missing file!!!  S1233_10052021
# Missing file!!!  S1233_10072021
# Missing file!!!  S1233_11302021
# Missing file!!!  S1233_12022021
# Missing file!!!  S1233_12032021
# Missing file!!!  S1233_12062021
# Missing file!!!  S1233_12072021
# Missing file!!!  S1233_12082021
# Missing file!!!  S1233_12092021
# Missing file!!!  S1233_12102021
# Missing file!!!  S1233_12132021
# Missing file!!!  S1233_12142021
# Missing file!!!  S1234_08312021
# Missing file!!!  S1234_09022021
# Missing file!!!  S1234_09062021
# Missing file!!!  S1234_09082021
# Missing file!!!  S1234_09102021
# Missing file!!!  S1234_09132021
# Missing file!!!  S1234_09152021
# Missing file!!!  S1234_09172021
# Missing file!!!  S1234_09202021
# Missing file!!!  S1234_10052021
# Missing file!!!  S1234_10072021
# Missing file!!!  S1234_11302021
# Missing file!!!  S1234_12022021
# Missing file!!!  S1234_12032021
# Missing file!!!  S1234_12062021
# Missing file!!!  S1234_12072021
# Missing file!!!  S1234_12082021
# Missing file!!!  S1234_12092021
# Missing file!!!  S1234_12102021
# Missing file!!!  S1234_12132021
# Missing file!!!  S1234_12142021
# Missing file!!!  S1260_08312021
# Missing file!!!  S1260_09022021
# Missing file!!!  S1260_09062021
# Missing file!!!  S1260_09082021
# Missing file!!!  S1260_09102021
# Missing file!!!  S1260_09132021
# Missing file!!!  S1260_09152021
# Missing file!!!  S1260_09172021
# Missing file!!!  S1260_09202021
# Missing file!!!  S1260_10052021
# Missing file!!!  S1260_10072021
# Missing file!!!  S1260_10122021
# Missing file!!!  S1260_10142021
# Missing file!!!  S1260_10192021
# Missing file!!!  S1260_10212021
# Missing file!!!  S1260_10252021
# Missing file!!!  S1260_10272021
# Missing file!!!  S1260_12022021
# Missing file!!!  S1260_12062021
# Missing file!!!  S1260_12082021
# Missing file!!!  S1260_12102021
# Missing file!!!  S1260_12142021
# Missing file!!!  S1246_08312021
# Missing file!!!  S1246_09022021
# Missing file!!!  S1246_09062021
# Missing file!!!  S1246_09082021
# Missing file!!!  S1246_09102021
# Missing file!!!  S1246_09132021
# Missing file!!!  S1246_09152021
# Missing file!!!  S1246_09172021
# Missing file!!!  S1246_09202021
# Missing file!!!  S1246_10052021
# Missing file!!!  S1246_10072021
# Missing file!!!  S1246_10122021
# Missing file!!!  S1246_10142021
# Missing file!!!  S1246_10192021
# Missing file!!!  S1246_10212021
# Missing file!!!  S1246_10252021
# Missing file!!!  S1246_10272021
# Missing file!!!  S1246_11302021
# Missing file!!!  S1246_12032021
# Missing file!!!  S1246_12072021
# Missing file!!!  S1246_12092021
# Missing file!!!  S1246_12132021
# Missing file!!!  S1248_08312021
# Missing file!!!  S1248_09022021
# Missing file!!!  S1248_09062021
# Missing file!!!  S1248_09082021
# Missing file!!!  S1248_09102021
# Missing file!!!  S1248_09132021
# Missing file!!!  S1248_09152021
# Missing file!!!  S1248_09172021
# Missing file!!!  S1248_09202021
# Missing file!!!  S1248_10052021
# Missing file!!!  S1248_10072021
# Missing file!!!  S1248_10122021
# Missing file!!!  S1248_10142021
# Missing file!!!  S1248_10192021
# Missing file!!!  S1248_10212021
# Missing file!!!  S1248_10252021
# Missing file!!!  S1248_10272021
# Missing file!!!  S1248_11302021
# Missing file!!!  S1248_12032021
# Missing file!!!  S1248_12072021
# Missing file!!!  S1248_12092021
# Missing file!!!  S1248_12132021
# Missing file!!!  S1194_10052021
# Missing file!!!  S1194_10072021
# Missing file!!!  S1194_10122021
# Missing file!!!  S1194_10142021
# Missing file!!!  S1194_10192021
# Missing file!!!  S1194_10212021
# Missing file!!!  S1194_10252021
# Missing file!!!  S1194_10272021
# Missing file!!!  S1194_11302021
# Missing file!!!  S1194_12022021
# Missing file!!!  S1194_12032021
# Missing file!!!  S1194_12062021
# Missing file!!!  S1194_12072021
# Missing file!!!  S1194_12082021
# Missing file!!!  S1194_12092021
# Missing file!!!  S1194_12102021
# Missing file!!!  S1194_12132021
# Missing file!!!  S1194_12142021
# Missing file!!!  S1195_10052021
# Missing file!!!  S1195_10072021
# Missing file!!!  S1195_10122021
# Missing file!!!  S1195_10142021
# Missing file!!!  S1195_10192021
# Missing file!!!  S1195_10212021
# Missing file!!!  S1195_10252021
# Missing file!!!  S1195_10272021
# Missing file!!!  S1195_11302021
# Missing file!!!  S1195_12022021
# Missing file!!!  S1195_12032021
# Missing file!!!  S1195_12062021
# Missing file!!!  S1195_12072021
# Missing file!!!  S1195_12082021
# Missing file!!!  S1195_12092021
# Missing file!!!  S1195_12102021
# Missing file!!!  S1195_12132021
# Missing file!!!  S1195_12142021
# Missing file!!!  S1214_08312021
# Missing file!!!  S1214_09022021
# Missing file!!!  S1214_09062021
# Missing file!!!  S1214_09082021
# Missing file!!!  S1214_09102021
# Missing file!!!  S1214_09132021
# Missing file!!!  S1214_09152021
# Missing file!!!  S1214_09172021
# Missing file!!!  S1214_09202021
# Missing file!!!  S1214_10192021
# Missing file!!!  S1214_10272021
# Missing file!!!  S1214_11302021
# Missing file!!!  S1214_12022021
# Missing file!!!  S1214_12032021
# Missing file!!!  S1214_12062021
# Missing file!!!  S1214_12072021
# Missing file!!!  S1214_12082021
# Missing file!!!  S1214_12092021
# Missing file!!!  S1214_12102021
# Missing file!!!  S1214_12132021
# Missing file!!!  S1214_12142021
# Missing file!!!  S1258_08312021
# Missing file!!!  S1258_09022021
# Missing file!!!  S1258_09062021
# Missing file!!!  S1258_09082021
# Missing file!!!  S1258_09102021
# Missing file!!!  S1258_09132021
# Missing file!!!  S1258_09152021
# Missing file!!!  S1258_09172021
# Missing file!!!  S1258_09202021
# Missing file!!!  S1258_10052021
# Missing file!!!  S1258_10072021
# Missing file!!!  S1258_10122021
# Missing file!!!  S1258_10142021
# Missing file!!!  S1258_10192021
# Missing file!!!  S1258_10212021
# Missing file!!!  S1258_10252021
# Missing file!!!  S1258_10272021
# Missing file!!!  S1258_12022021
# Missing file!!!  S1258_12062021
# Missing file!!!  S1258_12082021
# Missing file!!!  S1258_12102021
# Missing file!!!  S1258_12142021
# Missing file!!!  S1259_08312021
# Missing file!!!  S1259_09022021
# Missing file!!!  S1259_09062021
# Missing file!!!  S1259_09082021
# Missing file!!!  S1259_09102021
# Missing file!!!  S1259_09132021
# Missing file!!!  S1259_09152021
# Missing file!!!  S1259_09172021
# Missing file!!!  S1259_09202021
# Missing file!!!  S1259_10052021
# Missing file!!!  S1259_10072021
# Missing file!!!  S1259_10122021
# Missing file!!!  S1259_10142021
# Missing file!!!  S1259_10192021
# Missing file!!!  S1259_10212021
# Missing file!!!  S1259_10252021
# Missing file!!!  S1259_10272021
# Missing file!!!  S1259_12022021
# Missing file!!!  S1259_12062021
# Missing file!!!  S1259_12082021
# Missing file!!!  S1259_12102021
# Missing file!!!  S1259_12142021

# %%
# import glob
# figure = 'fig3-dualhem'
# print(sorted(list(set([_.split('_')[-1].replace('.txt', '') for _ in glob.glob(f'../../data/raw/{figure}/GLM_SIGNALS_*') if 'WT6' in _]))))

# %%
# figure = 'fig5'
# print(sorted(list(set([_.split('_')[-1].replace('.txt', '') for _ in glob.glob(f'../../data/raw/{figure}/GLM_SIGNALS_*')]))))

# %%
# signal_files = ['/Users/josh/Documents/Harvard/GLM/sabatinilab-glm/sglm/data/raw/fig5/GLM_SIGNALS_S1449_06022022.txt']

# %%
for ign in ignore_files:
    signal_files = [_ for _ in signal_files if ign not in _]

table_files = [_.replace('GLM_SIGNALS', 'GLM_TABLE') for _ in signal_files]


channel_assignments = bf.get_rename_columns_by_file(signal_files, channel_definitions)

for file_num in trange(len(signal_files)):

    ## Load Table Data
    # signal_fn = signal_files[0]
    # table_fn = table_files[0]

    signal_path = signal_files[file_num]
    table_path = table_files[file_num]

    signal_fn = Path(signal_files[file_num]).parts[-1]
    table_fn = Path(table_files[file_num]).parts[-1]

    signal_filename_out = signal_fn.replace('GLM_SIGNALS', 'GLM_SIGNALS_INTERIM').replace('txt', 'csv')
    table_filename_out = table_fn.replace('GLM_TABLE', 'GLM_TABLE_INTERIM').replace('txt', 'csv')

    # signal_path_out = f'../../data/interim2/{signal_filename_out}'
    # table_path_out = f'../../data/interim2/{table_filename_out}'

    signal_path_out = signal_path.replace(r'raw', r'interim2').replace('GLM_SIGNALS', 'GLM_SIGNALS_INTERIM').replace('txt', 'csv')
    table_path_out = table_path.replace(r'raw', r'interim2').replace('GLM_TABLE', 'GLM_TABLE_INTERIM').replace('txt', 'csv')

    
    if out_files is not None and signal_path in out_files:
        signal_path_out = signal_path_out.replace(*out_files[signal_path])
        table_path_out = table_path_out.replace(*out_files[signal_path])

    create_folder_if_not_exists(str(Path('/'.join(Path(signal_path_out).parts[:-1])).resolve()))
    create_folder_if_not_exists(str(Path('/'.join(Path(table_path_out).parts[:-1])).resolve()))
    
    signal_df = pd.read_csv(signal_path)
    table_df = pd.read_csv(table_path)

    # Check for multiple copies of the same sideIn
    eq = table_df['photometrySideInIndex'].dropna()
    eq = eq[eq != 0]
    if len(eq) != eq.nunique():
        print(len(eq))
        print(eq.nunique())
        display(eq)
        print(f'Error: Multiple side ins with the same timestamp detected for {signal_path}. Continuing...')
        continue

    print(signal_path)
    signal_df, table_df = gsd.generate_signal_df(signal_path,
                                            table_path,
                                            # signal_filename_out=f'../../data/interim2/{signal_filename_out}',
                                            # table_filename_out=f'../../data/interim2/{table_filename_out}',
                                            trial_bounds_before_center_in = -20,
                                            trial_bounds_after_side_out = 20,
                                            )

    signal_df = signal_df[signal_df['nTrial'] > 0].fillna(0)

    # Break down Preprocess Lynne into component parts

    # Rename Columns
    signal_df = bf.rename_consistent_columns(signal_df)
    
    # print(channel_assignments.keys())
    # print(signal_fn)
    if signal_fn in channel_assignments:
        signal_df = signal_df.rename(channel_assignments[signal_fn], axis=1)

    for y_col in y_col_lst_all:
        if y_col not in signal_df.columns:
            signal_df[y_col] = np.nan
            continue
    
    
    ## Set Full Trial Reward Flags
    signal_df['r_trial'] = (signal_df.groupby('nTrial')['photometrySideInIndexr'].transform(np.sum) > 0) * 1.0
    signal_df['nr_trial'] = (signal_df.groupby('nTrial')['photometrySideInIndexnr'].transform(np.sum) > 0) * 1.0

    ## Define Side Rewarded / Unrewarded Flags
    signal_df = bf.set_port_entry_exit_rewarded_unrewarded_indicators(signal_df)

    ## Define Side Agnostic Events
    signal_df = bf.define_side_agnostic_events(signal_df)

    # print('Percent of Data in ITI:', (df['nTrial'] == df['nEndTrial']).mean())

    signal_df['spnrOff'] = ((signal_df['spnr'] == 1)&(signal_df['photometrySideInIndex'] != 1)).astype(int)
    signal_df['spxrOff'] = ((signal_df['spxr'] == 1)&(signal_df['photometrySideOutIndex'] != 1)).astype(int)
    spnnrOff_a = ((signal_df['spnnr'] == 1)&(signal_df['photometrySideInIndex'] != 1)).astype(int)
    spxnrOff_a = ((signal_df['spxnr'] == 1)&(signal_df['photometrySideOutIndex'] != 1)).astype(int)

    # If we have something listed as a rewarded "off" side entry labeled in the table as a side exit... it means it was a fast "out-in".
    # The latter "in" should be considered an unrewarded side port "off" entry.
    dualism_exen = ((signal_df['spnrOff'] == 1)&(signal_df['photometrySideOutIndex'] == 1)).astype(int)

    # Unrewarded side port entries should be the combination of those simply identified by checking spnnr & the table labels +
    # the dualism defined immediately prior. Then those dualism examples should be remoed from the "off" rewarded entries.
    signal_df['spnnrOff'] = spnnrOff_a + dualism_exen
    signal_df['spnrOff'] = signal_df['spnrOff'] - dualism_exen

    signal_df['spxnrOff'] = spxnrOff_a

    

    signal_df['slOff'] = signal_df['sl'] * signal_df['nr_trial']
    signal_df['slOn'] = signal_df['sl'] - signal_df['slOff']


    
    signal_df['cpnOff'] = ((signal_df['cpn'] == 1)&(signal_df['photometryCenterInIndex'] != 1)).astype(int)
    signal_df['cpxOff'] = ((signal_df['cpx'] == 1)&(signal_df['photometryCenterOutIndex'] != 1)).astype(int)
    # spnnrOff_a = ((signal_df['cpnOff'] == 1)&(signal_df['photometryCenterInIndex'] != 1)).astype(int)
    # spxnrOff_a = ((signal_df['cpxOff'] == 1)&(signal_df['photometryCenterOutIndex'] != 1)).astype(int)

    # # If we have something listed as a rewarded "off" side entry labeled in the table as a side exit... it means it was a fast "out-in".
    # # The latter "in" should be considered an unrewarded side port "off" entry.
    # dualism_exen = ((signal_df['cpnOff'] == 1)&(signal_df['photometryCenterOutIndex'] == 1)).astype(int)

    # # Unrewarded side port entries should be the combination of those simply identified by checking spnnr & the table labels +
    # # the dualism defined immediately prior. Then those dualism examples should be remoed from the "off" rewarded entries.
    # signal_df['spnnrOff'] = spnnrOff_a + dualism_exen
    # signal_df['spnrOff'] = signal_df['spnrOff'] - dualism_exen

    # signal_df['spxnrOff'] = spxnrOff_a

    if signal_path_out:
        signal_df.to_csv(signal_path_out, index_label='index')
    if table_path_out:
        table_df.to_csv(table_path_out, index_label='index')
# Out:
# ('WT63_11082021',)
# > GLM_SIGNALS_WT63_11082021.txt
# ('WT63_11102021',)
# > GLM_SIGNALS_WT63_11102021.txt
# > GLM_SIGNALS_WT63_11102021.txt
# > GLM_SIGNALS_WT63_11102021.txt
# ('WT63_11122021',)
# > GLM_SIGNALS_WT63_11122021.txt
# > GLM_SIGNALS_WT63_11122021.txt
# > GLM_SIGNALS_WT63_11122021.txt
# ('WT63_11162021',)
# > GLM_SIGNALS_WT63_11162021.txt
# > GLM_SIGNALS_WT63_11162021.txt
# > GLM_SIGNALS_WT63_11162021.txt
# ('WT63_11182021',)
# > GLM_SIGNALS_WT63_11182021.txt
# > GLM_SIGNALS_WT63_11182021.txt
# > GLM_SIGNALS_WT63_11182021.txt
# ('WT64_11082021',)
# > GLM_SIGNALS_WT64_11082021.txt
# > GLM_SIGNALS_WT64_11082021.txt
# > GLM_SIGNALS_WT64_11082021.txt
# ('WT64_11102021',)
# > GLM_SIGNALS_WT64_11102021.txt
# > GLM_SIGNALS_WT64_11102021.txt
# > GLM_SIGNALS_WT64_11102021.txt
# ('WT64_11122021',)
# > GLM_SIGNALS_WT64_11122021.txt
# > GLM_SIGNALS_WT64_11122021.txt
# > GLM_SIGNALS_WT64_11122021.txt
# ('WT64_11162021',)
# > GLM_SIGNALS_WT64_11162021.txt
# > GLM_SIGNALS_WT64_11162021.txt
# > GLM_SIGNALS_WT64_11162021.txt
# ('WT64_11182021',)
# > GLM_SIGNALS_WT64_11182021.txt
# > GLM_SIGNALS_WT64_11182021.txt
# > GLM_SIGNALS_WT64_11182021.txt
# ('WT65_11082021',)
# > GLM_SIGNALS_WT65_11082021.txt
# > GLM_SIGNALS_WT65_11082021.txt
# ('WT65_11102021',)
# > GLM_SIGNALS_WT65_11102021.txt
# > GLM_SIGNALS_WT65_11102021.txt
# ('WT65_11122021',)
# > GLM_SIGNALS_WT65_11122021.txt
# > GLM_SIGNALS_WT65_11122021.txt
# ('WT65_11162021',)
# > GLM_SIGNALS_WT65_11162021.txt
# > GLM_SIGNALS_WT65_11162021.txt
# ('WT65_11182021',)
# > GLM_SIGNALS_WT65_11182021.txt
# > GLM_SIGNALS_WT65_11182021.txt
# ('WT66_12132021',)
# > GLM_SIGNALS_WT66_12132021.txt
# ('WT66_12152021',)
# > GLM_SIGNALS_WT66_12152021.txt
# ('WT66_12172021',)
# > GLM_SIGNALS_WT66_12172021.txt
# ('WT66_12192021',)
# > GLM_SIGNALS_WT66_12192021.txt
# ('WT67_12132021',)
# > GLM_SIGNALS_WT67_12132021.txt
# ('WT67_12152021',)
# > GLM_SIGNALS_WT67_12152021.txt
# ('WT67_12172021',)
# > GLM_SIGNALS_WT67_12172021.txt
# ('WT67_12192021',)
# > GLM_SIGNALS_WT67_12192021.txt
# ('WT68_12132021',)
# > GLM_SIGNALS_WT68_12132021.txt
# ('WT68_12152021',)
# > GLM_SIGNALS_WT68_12152021.txt
# ('WT68_12172021',)
# > GLM_SIGNALS_WT68_12172021.txt
# ('WT68_12192021',)
# > GLM_SIGNALS_WT68_12192021.txt
# ('WT69_12132021',)
# > GLM_SIGNALS_WT69_12132021.txt
# ('WT69_12152021',)
# > GLM_SIGNALS_WT69_12152021.txt
# ('WT69_12172021',)
# > GLM_SIGNALS_WT69_12172021.txt
# ('WT69_12192021',)
# > GLM_SIGNALS_WT69_12192021.txt
# ('WT58_10042021',)
# > GLM_SIGNALS_WT58_10042021.txt
# ('WT58_10062021',)
# > GLM_SIGNALS_WT58_10062021.txt
# ('WT58_10082021',)
# > GLM_SIGNALS_WT58_10082021.txt
# ('WT58_10112021',)
# > GLM_SIGNALS_WT58_10112021.txt
# ('WT58_10132021',)
# > GLM_SIGNALS_WT58_10132021.txt
# ('WT58_10152021',)
# > GLM_SIGNALS_WT58_10152021.txt
# ('WT60_10042021',)
# > GLM_SIGNALS_WT60_10042021.txt
# ('WT60_10062021',)
# > GLM_SIGNALS_WT60_10062021.txt
# ('WT60_10082021',)
# > GLM_SIGNALS_WT60_10082021.txt
# ('WT60_10112021',)
# > GLM_SIGNALS_WT60_10112021.txt
# ('WT60_10132021',)
# > GLM_SIGNALS_WT60_10132021.txt
# ('WT60_10152021',)
# > GLM_SIGNALS_WT60_10152021.txt
# ('WT61_10042021',)
# > GLM_SIGNALS_WT61_10042021.txt
# > GLM_SIGNALS_WT61_10042021.txt
# ('WT61_10062021',)
# > GLM_SIGNALS_WT61_10062021.txt
# ('WT61_10082021',)
# ('WT61_10112021',)
# > GLM_SIGNALS_WT61_10112021.txt
# > GLM_SIGNALS_WT61_10112021.txt
# ('WT61_10132021',)
# > GLM_SIGNALS_WT61_10132021.txt
# > GLM_SIGNALS_WT61_10132021.txt
# ('WT61_10152021',)
# ('WT53_09012021',)
# > GLM_SIGNALS_WT53_09012021.txt
# ('WT53_09032021',)
# > GLM_SIGNALS_WT53_09032021.txt
# ('WT53_09062021',)
# > GLM_SIGNALS_WT53_09062021.txt
# ('WT54_09012021',)
# > GLM_SIGNALS_WT54_09012021.txt
# ('WT54_09032021',)
# > GLM_SIGNALS_WT54_09032021.txt
# ('WT54_09062021',)
# > GLM_SIGNALS_WT54_09062021.txt
# ('WT55_09012021',)
# > GLM_SIGNALS_WT55_09012021.txt
# ('WT55_09032021',)
# > GLM_SIGNALS_WT55_09032021.txt
# ('WT55_09062021',)
# > GLM_SIGNALS_WT55_09062021.txt
# ('WT56_09012021',)
# > GLM_SIGNALS_WT56_09012021.txt
# ('WT56_09032021',)
# > GLM_SIGNALS_WT56_09032021.txt
# ('WT56_09062021',)
# ('WT57_10042021',)
# > GLM_SIGNALS_WT57_10042021.txt
# ('WT57_10062021',)
# > GLM_SIGNALS_WT57_10062021.txt
# ('WT57_10082021',)
# > GLM_SIGNALS_WT57_10082021.txt
# ('WT57_10112021',)
# > GLM_SIGNALS_WT57_10112021.txt
# ('WT57_10132021',)
# > GLM_SIGNALS_WT57_10132021.txt
# ('WT57_10152021',)
# > GLM_SIGNALS_WT57_10152021.txt
# ('WT59_10042021',)
# > GLM_SIGNALS_WT59_10042021.txt
# ('WT59_10062021',)
# ('WT59_10082021',)
# > GLM_SIGNALS_WT59_10082021.txt
# ('WT59_10112021',)
# > GLM_SIGNALS_WT59_10112021.txt
# ('WT59_10132021',)
# > GLM_SIGNALS_WT59_10132021.txt
# ('WT59_10152021',)
# > GLM_SIGNALS_WT59_10152021.txt
# ('WT63_03162021',)
# ('WT63_03192021',)
# ('WT63_03232021',)
# ('WT63_03262021',)
# ('WT63_07282021',)
# ('WT63_07302021',)
# ('WT63_08012021',)
# ('WT63_08042021',)
# ('WT63_08062021',)
# ('WT63_08102021',)
# ('WT63_10042021',)
# ('WT63_10082021',)
# ('WT63_10112021',)
# ('WT63_10132021',)
# ('WT63_10182021',)
# ('WT64_03162021',)
# ('WT64_03192021',)
# ('WT64_03232021',)
# ('WT64_03262021',)
# ('WT64_07282021',)
# ('WT64_07302021',)
# ('WT64_08012021',)
# ('WT64_08042021',)
# ('WT64_08062021',)
# ('WT64_08102021',)
# ('WT64_10042021',)
# ('WT64_10082021',)
# ('WT64_10112021',)
# ('WT64_10132021',)
# ('WT64_10182021',)
# ('WT44_03162021',)
# > GLM_SIGNALS_WT44_03162021.txt
# ('WT44_03192021',)
# > GLM_SIGNALS_WT44_03192021.txt
# ('WT44_03232021',)
# > GLM_SIGNALS_WT44_03232021.txt
# ('WT44_03262021',)
# > GLM_SIGNALS_WT44_03262021.txt
# ('WT44_07282021',)
# ('WT44_07302021',)
# ('WT44_08012021',)
# ('WT44_08042021',)
# ('WT44_08062021',)
# ('WT44_08102021',)
# ('WT44_10042021',)
# ('WT44_10082021',)
# ('WT44_10112021',)
# ('WT44_10132021',)
# ('WT44_10182021',)
# ('WT44_11082021',)
# ('WT44_11102021',)
# ('WT44_11122021',)
# ('WT44_11162021',)
# ('WT44_11182021',)
# ('WT51_03162021',)
# ('WT51_03192021',)
# ('WT51_03232021',)
# ('WT51_03262021',)
# ('WT51_07282021',)
# > GLM_SIGNALS_WT51_07282021.txt
# ('WT51_07302021',)
# > GLM_SIGNALS_WT51_07302021.txt
# ('WT51_08012021',)
# > GLM_SIGNALS_WT51_08012021.txt
# ('WT51_08042021',)
# > GLM_SIGNALS_WT51_08042021.txt
# ('WT51_08062021',)
# > GLM_SIGNALS_WT51_08062021.txt
# ('WT51_08102021',)
# > GLM_SIGNALS_WT51_08102021.txt
# ('WT51_10042021',)
# ('WT51_10082021',)
# ('WT51_10112021',)
# ('WT51_10132021',)
# ('WT51_10182021',)
# ('WT51_11082021',)
# ('WT51_11102021',)
# ('WT51_11122021',)
# ('WT51_11162021',)
# ('WT51_11182021',)
# ('WT61_03162021',)
# ('WT61_03192021',)
# ('WT61_03232021',)
# ('WT61_03262021',)
# ('WT61_07282021',)
# ('WT61_07302021',)
# ('WT61_08012021',)
# ('WT61_08042021',)
# ('WT61_08062021',)
# ('WT61_08102021',)
# ('WT61_11082021',)
# ('WT61_11102021',)
# ('WT61_11122021',)
# ('WT61_11162021',)
# ('WT61_11182021',)
# ('WT62_10042021',)
# ('WT62_10082021',)
# ('WT62_10112021',)
# ('WT62_10132021',)
# ('WT62_10182021',)
# ('WT62_11082021',)
# > GLM_SIGNALS_WT62_11082021.txt
# ('WT62_11102021',)
# > GLM_SIGNALS_WT62_11102021.txt
# ('WT62_11122021',)
# > GLM_SIGNALS_WT62_11122021.txt
# ('WT62_11162021',)
# ('WT62_11182021',)
# > GLM_SIGNALS_WT62_11182021.txt
# ('WT65_10042021',)
# ('WT65_10082021',)
# ('WT65_10112021',)
# ('WT65_10132021',)
# ('WT65_10182021',)
# ('S1417_03172022',)
# ('S1417_03212022',)
# ('S1417_03232022',)
# ('S1417_03252022',)
# ('S1417_03282022',)
# ('S1417_03292022',)
# ('S1417_03302022',)
# ('S1417_03312022',)
# ('S1417_04012022',)
# ('S1417_04032022',)
# ('S1417_04052022',)
# ('S1417_04072022',)
# ('S1417_04082022',)
# ('S1417_04112022',)
# ('S1417_04132022',)
# ('S1417_04152022',)
# ('S1417_04202022',)
# ('S1417_04222022',)
# ('S1417_05022022',)
# ('S1417_05102022',)
# ('S1417_05162022',)
# ('S1417_05182022',)
# ('S1417_05222022',)
# ('S1417_05232022',)
# > GLM_SIGNALS_S1417_05232022.txt
# ('S1417_05242022',)
# ('S1417_05252022',)
# ('S1417_05262022',)
# ('S1417_05272022',)
# > GLM_SIGNALS_S1417_05272022.txt
# ('S1417_05292022',)
# ('S1417_05302022',)
# > GLM_SIGNALS_S1417_05302022.txt
# ('S1417_05312022',)
# ('S1417_06022022',)
# ('S1417_06062022',)
# ('S1417_06082022',)
# ('S1417_06102022',)
# ('S1417_06132022',)
# ('S1417_06152022',)
# ('S1417_06182022',)
# ('S1417_07072022',)
# ('S1417_07082022',)
# ('S1417_07092022',)
# ('S1417_07112022',)
# ('S1417_07122022',)
# ('S1417_07132022',)
# ('S1417_07142022',)
# ('S1417_07152022',)
# ('S1417_07162022',)
# ('S1417_07172022',)
# ('S1417_07182022',)
# ('S1417_07192022',)
# ('S1419_03172022',)
# ('S1419_03212022',)
# ('S1419_03232022',)
# ('S1419_03252022',)
# ('S1419_03282022',)
# ('S1419_03292022',)
# ('S1419_03302022',)
# ('S1419_03312022',)
# ('S1419_04012022',)
# ('S1419_04032022',)
# ('S1419_04052022',)
# ('S1419_04072022',)
# ('S1419_04082022',)
# ('S1419_04112022',)
# ('S1419_04132022',)
# ('S1419_04152022',)
# ('S1419_04202022',)
# ('S1419_04222022',)
# ('S1419_05022022',)
# ('S1419_05102022',)
# ('S1419_05162022',)
# ('S1419_05182022',)
# ('S1419_05222022',)
# ('S1419_05232022',)
# > GLM_SIGNALS_S1419_05232022.txt
# ('S1419_05242022',)
# ('S1419_05252022',)
# > GLM_SIGNALS_S1419_05252022.txt
# ('S1419_05262022',)
# ('S1419_05272022',)
# > GLM_SIGNALS_S1419_05272022.txt
# ('S1419_05292022',)
# ('S1419_05302022',)
# > GLM_SIGNALS_S1419_05302022.txt
# ('S1419_05312022',)
# ('S1419_06022022',)
# ('S1419_06062022',)
# ('S1419_06082022',)
# ('S1419_06102022',)
# ('S1419_06132022',)
# ('S1419_06152022',)
# ('S1419_06182022',)
# ('S1419_07072022',)
# ('S1419_07082022',)
# ('S1419_07092022',)
# ('S1419_07112022',)
# ('S1419_07122022',)
# ('S1419_07132022',)
# ('S1419_07142022',)
# ('S1419_07152022',)
# ('S1419_07162022',)
# ('S1419_07172022',)
# ('S1419_07182022',)
# ('S1419_07192022',)
# ('S1421_03172022',)
# ('S1421_03212022',)
# ('S1421_03232022',)
# ('S1421_03252022',)
# ('S1421_03282022',)
# ('S1421_03292022',)
# ('S1421_03302022',)
# ('S1421_03312022',)
# ('S1421_04012022',)
# ('S1421_04032022',)
# ('S1421_04052022',)
# ('S1421_04072022',)
# ('S1421_04082022',)
# ('S1421_04112022',)
# ('S1421_04132022',)
# ('S1421_04152022',)
# ('S1421_04202022',)
# ('S1421_04222022',)
# ('S1421_05022022',)
# ('S1421_05102022',)
# ('S1421_05162022',)
# ('S1421_05182022',)
# ('S1421_05222022',)
# > GLM_SIGNALS_S1421_05222022.txt
# ('S1421_05232022',)
# ('S1421_05242022',)
# > GLM_SIGNALS_S1421_05242022.txt
# ('S1421_05252022',)
# ('S1421_05262022',)
# > GLM_SIGNALS_S1421_05262022.txt
# ('S1421_05272022',)
# ('S1421_05292022',)
# > GLM_SIGNALS_S1421_05292022.txt
# ('S1421_05302022',)
# ('S1421_05312022',)
# > GLM_SIGNALS_S1421_05312022.txt
# ('S1421_06022022',)
# ('S1421_06062022',)
# ('S1421_06082022',)
# ('S1421_06102022',)
# ('S1421_06132022',)
# ('S1421_06152022',)
# ('S1421_06182022',)
# ('S1421_07072022',)
# ('S1421_07082022',)
# ('S1421_07092022',)
# ('S1421_07112022',)
# ('S1421_07122022',)
# ('S1421_07132022',)
# ('S1421_07142022',)
# ('S1421_07152022',)
# ('S1421_07162022',)
# ('S1421_07172022',)
# ('S1421_07182022',)
# ('S1421_07192022',)
# ('S1460_03172022',)
# ('S1460_03212022',)
# ('S1460_03232022',)
# ('S1460_03252022',)
# ('S1460_03282022',)
# ('S1460_03292022',)
# ('S1460_03302022',)
# ('S1460_03312022',)
# ('S1460_04012022',)
# ('S1460_04032022',)
# ('S1460_04052022',)
# ('S1460_04072022',)
# ('S1460_04082022',)
# ('S1460_04112022',)
# ('S1460_04132022',)
# ('S1460_04152022',)
# ('S1460_04202022',)
# ('S1460_04222022',)
# ('S1460_05022022',)
# ('S1460_05102022',)
# ('S1460_05162022',)
# ('S1460_05182022',)
# ('S1460_05222022',)
# ('S1460_05232022',)
# ('S1460_05242022',)
# ('S1460_05252022',)
# ('S1460_05262022',)
# ('S1460_05272022',)
# ('S1460_05292022',)
# ('S1460_05302022',)
# ('S1460_05312022',)
# ('S1460_06022022',)
# ('S1460_06062022',)
# ('S1460_06082022',)
# ('S1460_06102022',)
# ('S1460_06132022',)
# ('S1460_06152022',)
# ('S1460_06182022',)
# ('S1460_07072022',)
# ('S1460_07082022',)
# > GLM_SIGNALS_S1460_07082022.txt
# ('S1460_07092022',)
# ('S1460_07112022',)
# ('S1460_07122022',)
# > GLM_SIGNALS_S1460_07122022.txt
# ('S1460_07132022',)
# ('S1460_07142022',)
# > GLM_SIGNALS_S1460_07142022.txt
# ('S1460_07152022',)
# ('S1460_07162022',)
# ('S1460_07172022',)
# ('S1460_07182022',)
# ('S1460_07192022',)
# ('S1462_03172022',)
# ('S1462_03212022',)
# ('S1462_03232022',)
# ('S1462_03252022',)
# ('S1462_03282022',)
# ('S1462_03292022',)
# ('S1462_03302022',)
# ('S1462_03312022',)
# ('S1462_04012022',)
# ('S1462_04032022',)
# ('S1462_04052022',)
# ('S1462_04072022',)
# ('S1462_04082022',)
# ('S1462_04112022',)
# ('S1462_04132022',)
# ('S1462_04152022',)
# ('S1462_04202022',)
# ('S1462_04222022',)
# ('S1462_05022022',)
# ('S1462_05102022',)
# ('S1462_05162022',)
# ('S1462_05182022',)
# ('S1462_05222022',)
# ('S1462_05232022',)
# ('S1462_05242022',)
# ('S1462_05252022',)
# ('S1462_05262022',)
# ('S1462_05272022',)
# ('S1462_05292022',)
# ('S1462_05302022',)
# ('S1462_05312022',)
# ('S1462_06022022',)
# ('S1462_06062022',)
# ('S1462_06082022',)
# ('S1462_06102022',)
# ('S1462_06132022',)
# ('S1462_06152022',)
# ('S1462_06182022',)
# ('S1462_07072022',)
# ('S1462_07082022',)
# > GLM_SIGNALS_S1462_07082022.txt
# ('S1462_07092022',)
# ('S1462_07112022',)
# ('S1462_07122022',)
# > GLM_SIGNALS_S1462_07122022.txt
# ('S1462_07132022',)
# ('S1462_07142022',)
# > GLM_SIGNALS_S1462_07142022.txt
# ('S1462_07152022',)
# ('S1462_07162022',)
# > GLM_SIGNALS_S1462_07162022.txt
# ('S1462_07172022',)
# ('S1462_07182022',)
# ('S1462_07192022',)
# > GLM_SIGNALS_S1462_07192022.txt
# ('S1473_03172022',)
# ('S1473_03212022',)
# ('S1473_03232022',)
# ('S1473_03252022',)
# ('S1473_03282022',)
# ('S1473_03292022',)
# ('S1473_03302022',)
# ('S1473_03312022',)
# ('S1473_04012022',)
# ('S1473_04032022',)
# ('S1473_04052022',)
# ('S1473_04072022',)
# ('S1473_04082022',)
# ('S1473_04112022',)
# ('S1473_04132022',)
# ('S1473_04152022',)
# ('S1473_04202022',)
# ('S1473_04222022',)
# ('S1473_05022022',)
# ('S1473_05102022',)
# ('S1473_05162022',)
# ('S1473_05182022',)
# ('S1473_05222022',)
# ('S1473_05232022',)
# ('S1473_05242022',)
# ('S1473_05252022',)
# ('S1473_05262022',)
# ('S1473_05272022',)
# ('S1473_05292022',)
# ('S1473_05302022',)
# ('S1473_05312022',)
# ('S1473_06022022',)
# ('S1473_06062022',)
# ('S1473_06082022',)
# ('S1473_06102022',)
# ('S1473_06132022',)
# ('S1473_06152022',)
# ('S1473_06182022',)
# ('S1473_07072022',)
# > GLM_SIGNALS_S1473_07072022.txt
# ('S1473_07082022',)
# ('S1473_07092022',)
# > GLM_SIGNALS_S1473_07092022.txt
# ('S1473_07112022',)
# > GLM_SIGNALS_S1473_07112022.txt
# ('S1473_07122022',)
# ('S1473_07132022',)
# > GLM_SIGNALS_S1473_07132022.txt
# ('S1473_07142022',)
# ('S1473_07152022',)
# > GLM_SIGNALS_S1473_07152022.txt
# ('S1473_07162022',)
# ('S1473_07172022',)
# > GLM_SIGNALS_S1473_07172022.txt
# ('S1473_07182022',)
# ('S1473_07192022',)
# ('S1474_03172022',)
# ('S1474_03212022',)
# ('S1474_03232022',)
# ('S1474_03252022',)
# ('S1474_03282022',)
# ('S1474_03292022',)
# ('S1474_03302022',)
# ('S1474_03312022',)
# ('S1474_04012022',)
# ('S1474_04032022',)
# ('S1474_04052022',)
# ('S1474_04072022',)
# ('S1474_04082022',)
# ('S1474_04112022',)
# ('S1474_04132022',)
# ('S1474_04152022',)
# ('S1474_04202022',)
# ('S1474_04222022',)
# ('S1474_05022022',)
# ('S1474_05102022',)
# ('S1474_05162022',)
# ('S1474_05182022',)
# ('S1474_05222022',)
# ('S1474_05232022',)
# ('S1474_05242022',)
# ('S1474_05252022',)
# ('S1474_05262022',)
# ('S1474_05272022',)
# ('S1474_05292022',)
# ('S1474_05302022',)
# ('S1474_05312022',)
# ('S1474_06022022',)
# ('S1474_06062022',)
# ('S1474_06082022',)
# ('S1474_06102022',)
# ('S1474_06132022',)
# ('S1474_06152022',)
# ('S1474_06182022',)
# ('S1474_07072022',)
# ('S1474_07082022',)
# ('S1474_07092022',)
# ('S1474_07112022',)
# ('S1474_07122022',)
# ('S1474_07132022',)
# ('S1474_07142022',)
# > GLM_SIGNALS_S1474_07142022.txt
# ('S1474_07152022',)
# ('S1474_07162022',)
# ('S1474_07172022',)
# ('S1474_07182022',)
# > GLM_SIGNALS_S1474_07182022.txt
# ('S1474_07192022',)
# ('S1416_03172022',)
# ('S1416_03212022',)
# ('S1416_03232022',)
# ('S1416_03252022',)
# ('S1416_03282022',)
# ('S1416_03292022',)
# ('S1416_03302022',)
# ('S1416_03312022',)
# ('S1416_04012022',)
# ('S1416_04032022',)
# ('S1416_04052022',)
# ('S1416_04072022',)
# ('S1416_04082022',)
# ('S1416_04112022',)
# ('S1416_04132022',)
# ('S1416_04152022',)
# ('S1416_04202022',)
# ('S1416_04222022',)
# ('S1416_05022022',)
# ('S1416_05102022',)
# ('S1416_05162022',)
# ('S1416_05182022',)
# ('S1416_05222022',)
# ('S1416_05232022',)
# > GLM_SIGNALS_S1416_05232022.txt
# ('S1416_05242022',)
# ('S1416_05252022',)
# > GLM_SIGNALS_S1416_05252022.txt
# ('S1416_05262022',)
# ('S1416_05272022',)
# > GLM_SIGNALS_S1416_05272022.txt
# ('S1416_05292022',)
# ('S1416_05302022',)
# > GLM_SIGNALS_S1416_05302022.txt
# ('S1416_05312022',)
# ('S1416_06022022',)
# ('S1416_06062022',)
# ('S1416_06082022',)
# ('S1416_06102022',)
# ('S1416_06132022',)
# ('S1416_06152022',)
# ('S1416_06182022',)
# ('S1416_07072022',)
# ('S1416_07082022',)
# ('S1416_07092022',)
# ('S1416_07112022',)
# ('S1416_07122022',)
# ('S1416_07132022',)
# ('S1416_07142022',)
# ('S1416_07152022',)
# ('S1416_07162022',)
# ('S1416_07172022',)
# ('S1416_07182022',)
# ('S1416_07192022',)
# ('S1418_03172022',)
# ('S1418_03212022',)
# ('S1418_03232022',)
# ('S1418_03252022',)
# ('S1418_03282022',)
# ('S1418_03292022',)
# ('S1418_03302022',)
# ('S1418_03312022',)
# ('S1418_04012022',)
# ('S1418_04032022',)
# ('S1418_04052022',)
# ('S1418_04072022',)
# ('S1418_04082022',)
# ('S1418_04112022',)
# ('S1418_04132022',)
# ('S1418_04152022',)
# ('S1418_04202022',)
# ('S1418_04222022',)
# ('S1418_05022022',)
# ('S1418_05102022',)
# ('S1418_05162022',)
# ('S1418_05182022',)
# ('S1418_05222022',)
# ('S1418_05232022',)
# > GLM_SIGNALS_S1418_05232022.txt
# ('S1418_05242022',)
# ('S1418_05252022',)
# ('S1418_05262022',)
# ('S1418_05272022',)
# > GLM_SIGNALS_S1418_05272022.txt
# ('S1418_05292022',)
# > GLM_SIGNALS_S1418_05292022.txt
# ('S1418_05302022',)
# ('S1418_05312022',)
# > GLM_SIGNALS_S1418_05312022.txt
# ('S1418_06022022',)
# ('S1418_06062022',)
# ('S1418_06082022',)
# ('S1418_06102022',)
# ('S1418_06132022',)
# ('S1418_06152022',)
# ('S1418_06182022',)
# ('S1418_07072022',)
# ('S1418_07082022',)
# ('S1418_07092022',)
# ('S1418_07112022',)
# ('S1418_07122022',)
# ('S1418_07132022',)
# ('S1418_07142022',)
# ('S1418_07152022',)
# ('S1418_07162022',)
# ('S1418_07172022',)
# ('S1418_07182022',)
# ('S1418_07192022',)
# ('S1420_03172022',)
# ('S1420_03212022',)
# ('S1420_03232022',)
# ('S1420_03252022',)
# ('S1420_03282022',)
# ('S1420_03292022',)
# ('S1420_03302022',)
# ('S1420_03312022',)
# ('S1420_04012022',)
# ('S1420_04032022',)
# ('S1420_04052022',)
# ('S1420_04072022',)
# ('S1420_04082022',)
# ('S1420_04112022',)
# ('S1420_04132022',)
# ('S1420_04152022',)
# ('S1420_04202022',)
# ('S1420_04222022',)
# ('S1420_05022022',)
# ('S1420_05102022',)
# ('S1420_05162022',)
# ('S1420_05182022',)
# ('S1420_05222022',)
# > GLM_SIGNALS_S1420_05222022.txt
# ('S1420_05232022',)
# ('S1420_05242022',)
# > GLM_SIGNALS_S1420_05242022.txt
# ('S1420_05252022',)
# ('S1420_05262022',)
# > GLM_SIGNALS_S1420_05262022.txt
# ('S1420_05272022',)
# ('S1420_05292022',)
# > GLM_SIGNALS_S1420_05292022.txt
# ('S1420_05302022',)
# ('S1420_05312022',)
# > GLM_SIGNALS_S1420_05312022.txt
# ('S1420_06022022',)
# ('S1420_06062022',)
# ('S1420_06082022',)
# ('S1420_06102022',)
# ('S1420_06132022',)
# ('S1420_06152022',)
# ('S1420_06182022',)
# ('S1420_07072022',)
# ('S1420_07082022',)
# ('S1420_07092022',)
# ('S1420_07112022',)
# ('S1420_07122022',)
# ('S1420_07132022',)
# ('S1420_07142022',)
# ('S1420_07152022',)
# ('S1420_07162022',)
# ('S1420_07172022',)
# ('S1420_07182022',)
# ('S1420_07192022',)
# ('S1459_03172022',)
# ('S1459_03212022',)
# ('S1459_03232022',)
# ('S1459_03252022',)
# ('S1459_03282022',)
# ('S1459_03292022',)
# ('S1459_03302022',)
# ('S1459_03312022',)
# ('S1459_04012022',)
# ('S1459_04032022',)
# ('S1459_04052022',)
# ('S1459_04072022',)
# ('S1459_04082022',)
# ('S1459_04112022',)
# ('S1459_04132022',)
# ('S1459_04152022',)
# ('S1459_04202022',)
# ('S1459_04222022',)
# ('S1459_05022022',)
# ('S1459_05102022',)
# ('S1459_05162022',)
# ('S1459_05182022',)
# ('S1459_05222022',)
# ('S1459_05232022',)
# ('S1459_05242022',)
# ('S1459_05252022',)
# ('S1459_05262022',)
# ('S1459_05272022',)
# ('S1459_05292022',)
# ('S1459_05302022',)
# ('S1459_05312022',)
# ('S1459_06022022',)
# ('S1459_06062022',)
# ('S1459_06082022',)
# ('S1459_06102022',)
# ('S1459_06132022',)
# ('S1459_06152022',)
# ('S1459_06182022',)
# ('S1459_07072022',)
# ('S1459_07082022',)
# > GLM_SIGNALS_S1459_07082022.txt
# ('S1459_07092022',)
# ('S1459_07112022',)
# ('S1459_07122022',)
# > GLM_SIGNALS_S1459_07122022.txt
# ('S1459_07132022',)
# ('S1459_07142022',)
# ('S1459_07152022',)
# ('S1459_07162022',)
# > GLM_SIGNALS_S1459_07162022.txt
# ('S1459_07172022',)
# ('S1459_07182022',)
# ('S1459_07192022',)
# > GLM_SIGNALS_S1459_07192022.txt
# ('S1461_03172022',)
# ('S1461_03212022',)
# ('S1461_03232022',)
# ('S1461_03252022',)
# ('S1461_03282022',)
# ('S1461_03292022',)
# ('S1461_03302022',)
# ('S1461_03312022',)
# ('S1461_04012022',)
# ('S1461_04032022',)
# ('S1461_04052022',)
# ('S1461_04072022',)
# ('S1461_04082022',)
# ('S1461_04112022',)
# ('S1461_04132022',)
# ('S1461_04152022',)
# ('S1461_04202022',)
# ('S1461_04222022',)
# ('S1461_05022022',)
# ('S1461_05102022',)
# ('S1461_05162022',)
# ('S1461_05182022',)
# ('S1461_05222022',)
# ('S1461_05232022',)
# ('S1461_05242022',)
# ('S1461_05252022',)
# ('S1461_05262022',)
# ('S1461_05272022',)
# ('S1461_05292022',)
# ('S1461_05302022',)
# ('S1461_05312022',)
# ('S1461_06022022',)
# ('S1461_06062022',)
# ('S1461_06082022',)
# ('S1461_06102022',)
# ('S1461_06132022',)
# ('S1461_06152022',)
# ('S1461_06182022',)
# ('S1461_07072022',)
# ('S1461_07082022',)
# > GLM_SIGNALS_S1461_07082022.txt
# ('S1461_07092022',)
# ('S1461_07112022',)
# ('S1461_07122022',)
# > GLM_SIGNALS_S1461_07122022.txt
# ('S1461_07132022',)
# ('S1461_07142022',)
# ('S1461_07152022',)
# ('S1461_07162022',)
# ('S1461_07172022',)
# ('S1461_07182022',)
# ('S1461_07192022',)
# ('S1470_03172022',)
# ('S1470_03212022',)
# ('S1470_03232022',)
# ('S1470_03252022',)
# ('S1470_03282022',)
# ('S1470_03292022',)
# ('S1470_03302022',)
# ('S1470_03312022',)
# ('S1470_04012022',)
# ('S1470_04032022',)
# ('S1470_04052022',)
# ('S1470_04072022',)
# ('S1470_04082022',)
# ('S1470_04112022',)
# ('S1470_04132022',)
# ('S1470_04152022',)
# ('S1470_04202022',)
# ('S1470_04222022',)
# ('S1470_05022022',)
# ('S1470_05102022',)
# ('S1470_05162022',)
# ('S1470_05182022',)
# ('S1470_05222022',)
# ('S1470_05232022',)
# ('S1470_05242022',)
# ('S1470_05252022',)
# ('S1470_05262022',)
# ('S1470_05272022',)
# ('S1470_05292022',)
# ('S1470_05302022',)
# ('S1470_05312022',)
# ('S1470_06022022',)
# ('S1470_06062022',)
# ('S1470_06082022',)
# ('S1470_06102022',)
# ('S1470_06132022',)
# ('S1470_06152022',)
# ('S1470_06182022',)
# ('S1470_07072022',)
# ('S1470_07082022',)
# ('S1470_07092022',)
# ('S1470_07112022',)
# ('S1470_07122022',)
# ('S1470_07132022',)
# ('S1470_07142022',)
# > GLM_SIGNALS_S1470_07142022.txt
# ('S1470_07152022',)
# ('S1470_07162022',)
# ('S1470_07172022',)
# ('S1470_07182022',)
# > GLM_SIGNALS_S1470_07182022.txt
# ('S1470_07192022',)
# ('S1471_03172022',)
# ('S1471_03212022',)
# ('S1471_03232022',)
# ('S1471_03252022',)
# ('S1471_03282022',)
# ('S1471_03292022',)
# ('S1471_03302022',)
# ('S1471_03312022',)
# ('S1471_04012022',)
# ('S1471_04032022',)
# ('S1471_04052022',)
# ('S1471_04072022',)
# ('S1471_04082022',)
# ('S1471_04112022',)
# ('S1471_04132022',)
# ('S1471_04152022',)
# ('S1471_04202022',)
# ('S1471_04222022',)
# ('S1471_05022022',)
# ('S1471_05102022',)
# ('S1471_05162022',)
# ('S1471_05182022',)
# ('S1471_05222022',)
# ('S1471_05232022',)
# ('S1471_05242022',)
# ('S1471_05252022',)
# ('S1471_05262022',)
# ('S1471_05272022',)
# ('S1471_05292022',)
# ('S1471_05302022',)
# ('S1471_05312022',)
# ('S1471_06022022',)
# ('S1471_06062022',)
# ('S1471_06082022',)
# ('S1471_06102022',)
# ('S1471_06132022',)
# ('S1471_06152022',)
# ('S1471_06182022',)
# ('S1471_07072022',)
# ('S1471_07082022',)
# ('S1471_07092022',)
# ('S1471_07112022',)
# ('S1471_07122022',)
# ('S1471_07132022',)
# > GLM_SIGNALS_S1471_07132022.txt
# ('S1471_07142022',)
# ('S1471_07152022',)
# > GLM_SIGNALS_S1471_07152022.txt
# ('S1471_07162022',)
# ('S1471_07172022',)
# > GLM_SIGNALS_S1471_07172022.txt
# ('S1471_07182022',)
# ('S1471_07192022',)
# ('S1472_03172022',)
# ('S1472_03212022',)
# ('S1472_03232022',)
# ('S1472_03252022',)
# ('S1472_03282022',)
# ('S1472_03292022',)
# ('S1472_03302022',)
# ('S1472_03312022',)
# ('S1472_04012022',)
# ('S1472_04032022',)
# ('S1472_04052022',)
# ('S1472_04072022',)
# ('S1472_04082022',)
# ('S1472_04112022',)
# ('S1472_04132022',)
# ('S1472_04152022',)
# ('S1472_04202022',)
# ('S1472_04222022',)
# ('S1472_05022022',)
# ('S1472_05102022',)
# ('S1472_05162022',)
# ('S1472_05182022',)
# ('S1472_05222022',)
# ('S1472_05232022',)
# ('S1472_05242022',)
# ('S1472_05252022',)
# ('S1472_05262022',)
# ('S1472_05272022',)
# ('S1472_05292022',)
# ('S1472_05302022',)
# ('S1472_05312022',)
# ('S1472_06022022',)
# ('S1472_06062022',)
# ('S1472_06082022',)
# ('S1472_06102022',)
# ('S1472_06132022',)
# ('S1472_06152022',)
# ('S1472_06182022',)
# ('S1472_07072022',)
# > GLM_SIGNALS_S1472_07072022.txt
# ('S1472_07082022',)
# ('S1472_07092022',)
# > GLM_SIGNALS_S1472_07092022.txt
# ('S1472_07112022',)
# ('S1472_07122022',)
# ('S1472_07132022',)
# > GLM_SIGNALS_S1472_07132022.txt
# ('S1472_07142022',)
# ('S1472_07152022',)
# ('S1472_07162022',)
# ('S1472_07172022',)
# > GLM_SIGNALS_S1472_07172022.txt
# ('S1472_07182022',)
# ('S1472_07192022',)
# ('S1355_03172022',)
# > GLM_SIGNALS_S1355_03172022.txt
# ('S1355_03212022',)
# > GLM_SIGNALS_S1355_03212022.txt
# ('S1355_03232022',)
# ('S1355_03252022',)
# > GLM_SIGNALS_S1355_03252022.txt
# ('S1355_03282022',)
# ('S1355_03292022',)
# ('S1355_03302022',)
# ('S1355_03312022',)
# > GLM_SIGNALS_S1355_03312022.txt
# ('S1355_04012022',)
# ('S1355_04032022',)
# ('S1355_04052022',)
# ('S1355_04072022',)
# ('S1355_04082022',)
# ('S1355_04112022',)
# ('S1355_04132022',)
# ('S1355_04152022',)
# ('S1355_04202022',)
# ('S1355_04222022',)
# ('S1355_05022022',)
# ('S1355_05102022',)
# ('S1355_05162022',)
# ('S1355_05182022',)
# ('S1355_05222022',)
# ('S1355_05232022',)
# ('S1355_05242022',)
# ('S1355_05252022',)
# ('S1355_05262022',)
# ('S1355_05272022',)
# ('S1355_05292022',)
# ('S1355_05302022',)
# ('S1355_05312022',)
# ('S1355_06022022',)
# ('S1355_06062022',)
# ('S1355_06082022',)
# ('S1355_06102022',)
# ('S1355_06132022',)
# ('S1355_06152022',)
# ('S1355_06182022',)
# ('S1355_07072022',)
# ('S1355_07082022',)
# ('S1355_07092022',)
# ('S1355_07112022',)
# ('S1355_07122022',)
# ('S1355_07132022',)
# ('S1355_07142022',)
# ('S1355_07152022',)
# ('S1355_07162022',)
# ('S1355_07172022',)
# ('S1355_07182022',)
# ('S1355_07192022',)
# ('S1356_03172022',)
# > GLM_SIGNALS_S1356_03172022.txt
# ('S1356_03212022',)
# > GLM_SIGNALS_S1356_03212022.txt
# ('S1356_03232022',)
# ('S1356_03252022',)
# > GLM_SIGNALS_S1356_03252022.txt
# ('S1356_03282022',)
# ('S1356_03292022',)
# > GLM_SIGNALS_S1356_03292022.txt
# ('S1356_03302022',)
# ('S1356_03312022',)
# > GLM_SIGNALS_S1356_03312022.txt
# ('S1356_04012022',)
# ('S1356_04032022',)
# ('S1356_04052022',)
# ('S1356_04072022',)
# ('S1356_04082022',)
# ('S1356_04112022',)
# ('S1356_04132022',)
# ('S1356_04152022',)
# ('S1356_04202022',)
# ('S1356_04222022',)
# ('S1356_05022022',)
# ('S1356_05102022',)
# ('S1356_05162022',)
# ('S1356_05182022',)
# ('S1356_05222022',)
# ('S1356_05232022',)
# ('S1356_05242022',)
# ('S1356_05252022',)
# ('S1356_05262022',)
# ('S1356_05272022',)
# ('S1356_05292022',)
# ('S1356_05302022',)
# ('S1356_05312022',)
# ('S1356_06022022',)
# ('S1356_06062022',)
# ('S1356_06082022',)
# ('S1356_06102022',)
# ('S1356_06132022',)
# ('S1356_06152022',)
# ('S1356_06182022',)
# ('S1356_07072022',)
# ('S1356_07082022',)
# ('S1356_07092022',)
# ('S1356_07112022',)
# ('S1356_07122022',)
# ('S1356_07132022',)
# ('S1356_07142022',)
# ('S1356_07152022',)
# ('S1356_07162022',)
# ('S1356_07172022',)
# ('S1356_07182022',)
# ('S1356_07192022',)
# ('S1357_03172022',)
# > GLM_SIGNALS_S1357_03172022.txt
# ('S1357_03212022',)
# > GLM_SIGNALS_S1357_03212022.txt
# ('S1357_03232022',)
# > GLM_SIGNALS_S1357_03232022.txt
# ('S1357_03252022',)
# > GLM_SIGNALS_S1357_03252022.txt
# ('S1357_03282022',)
# ('S1357_03292022',)
# > GLM_SIGNALS_S1357_03292022.txt
# ('S1357_03302022',)
# ('S1357_03312022',)
# > GLM_SIGNALS_S1357_03312022.txt
# ('S1357_04012022',)
# ('S1357_04032022',)
# ('S1357_04052022',)
# ('S1357_04072022',)
# ('S1357_04082022',)
# ('S1357_04112022',)
# ('S1357_04132022',)
# ('S1357_04152022',)
# ('S1357_04202022',)
# ('S1357_04222022',)
# ('S1357_05022022',)
# ('S1357_05102022',)
# ('S1357_05162022',)
# ('S1357_05182022',)
# ('S1357_05222022',)
# ('S1357_05232022',)
# ('S1357_05242022',)
# ('S1357_05252022',)
# ('S1357_05262022',)
# ('S1357_05272022',)
# ('S1357_05292022',)
# ('S1357_05302022',)
# ('S1357_05312022',)
# ('S1357_06022022',)
# ('S1357_06062022',)
# ('S1357_06082022',)
# ('S1357_06102022',)
# ('S1357_06132022',)
# ('S1357_06152022',)
# ('S1357_06182022',)
# ('S1357_07072022',)
# ('S1357_07082022',)
# ('S1357_07092022',)
# ('S1357_07112022',)
# ('S1357_07122022',)
# ('S1357_07132022',)
# ('S1357_07142022',)
# ('S1357_07152022',)
# ('S1357_07162022',)
# ('S1357_07172022',)
# ('S1357_07182022',)
# ('S1357_07192022',)
# ('S1358_03172022',)
# > GLM_SIGNALS_S1358_03172022.txt
# ('S1358_03212022',)
# > GLM_SIGNALS_S1358_03212022.txt
# ('S1358_03232022',)
# > GLM_SIGNALS_S1358_03232022.txt
# ('S1358_03252022',)
# > GLM_SIGNALS_S1358_03252022.txt
# ('S1358_03282022',)
# ('S1358_03292022',)
# > GLM_SIGNALS_S1358_03292022.txt
# ('S1358_03302022',)
# ('S1358_03312022',)
# ('S1358_04012022',)
# ('S1358_04032022',)
# ('S1358_04052022',)
# ('S1358_04072022',)
# ('S1358_04082022',)
# ('S1358_04112022',)
# ('S1358_04132022',)
# ('S1358_04152022',)
# ('S1358_04202022',)
# ('S1358_04222022',)
# ('S1358_05022022',)
# ('S1358_05102022',)
# ('S1358_05162022',)
# ('S1358_05182022',)
# ('S1358_05222022',)
# ('S1358_05232022',)
# ('S1358_05242022',)
# ('S1358_05252022',)
# ('S1358_05262022',)
# ('S1358_05272022',)
# ('S1358_05292022',)
# ('S1358_05302022',)
# ('S1358_05312022',)
# ('S1358_06022022',)
# ('S1358_06062022',)
# ('S1358_06082022',)
# ('S1358_06102022',)
# ('S1358_06132022',)
# ('S1358_06152022',)
# ('S1358_06182022',)
# ('S1358_07072022',)
# ('S1358_07082022',)
# ('S1358_07092022',)
# ('S1358_07112022',)
# ('S1358_07122022',)
# ('S1358_07132022',)
# ('S1358_07142022',)
# ('S1358_07152022',)
# ('S1358_07162022',)
# ('S1358_07172022',)
# ('S1358_07182022',)
# ('S1358_07192022',)
# ('S1376_03172022',)
# ('S1376_03212022',)
# ('S1376_03232022',)
# ('S1376_03252022',)
# ('S1376_03282022',)
# > GLM_SIGNALS_S1376_03282022.txt
# ('S1376_03292022',)
# ('S1376_03302022',)
# > GLM_SIGNALS_S1376_03302022.txt
# ('S1376_03312022',)
# ('S1376_04012022',)
# > GLM_SIGNALS_S1376_04012022.txt
# ('S1376_04032022',)
# > GLM_SIGNALS_S1376_04032022.txt
# ('S1376_04052022',)
# > GLM_SIGNALS_S1376_04052022.txt
# ('S1376_04072022',)
# > GLM_SIGNALS_S1376_04072022.txt
# ('S1376_04082022',)
# ('S1376_04112022',)
# ('S1376_04132022',)
# ('S1376_04152022',)
# ('S1376_04202022',)
# ('S1376_04222022',)
# ('S1376_05022022',)
# ('S1376_05102022',)
# ('S1376_05162022',)
# ('S1376_05182022',)
# ('S1376_05222022',)
# ('S1376_05232022',)
# ('S1376_05242022',)
# ('S1376_05252022',)
# ('S1376_05262022',)
# ('S1376_05272022',)
# ('S1376_05292022',)
# ('S1376_05302022',)
# ('S1376_05312022',)
# ('S1376_06022022',)
# ('S1376_06062022',)
# ('S1376_06082022',)
# ('S1376_06102022',)
# ('S1376_06132022',)
# ('S1376_06152022',)
# ('S1376_06182022',)
# ('S1376_07072022',)
# ('S1376_07082022',)
# ('S1376_07092022',)
# ('S1376_07112022',)
# ('S1376_07122022',)
# ('S1376_07132022',)
# ('S1376_07142022',)
# ('S1376_07152022',)
# ('S1376_07162022',)
# ('S1376_07172022',)
# ('S1376_07182022',)
# ('S1376_07192022',)
# ('S1448_03172022',)
# ('S1448_03212022',)
# ('S1448_03232022',)
# ('S1448_03252022',)
# ('S1448_03282022',)
# ('S1448_03292022',)
# ('S1448_03302022',)
# ('S1448_03312022',)
# ('S1448_04012022',)
# ('S1448_04032022',)
# ('S1448_04052022',)
# ('S1448_04072022',)
# ('S1448_04082022',)
# ('S1448_04112022',)
# ('S1448_04132022',)
# ('S1448_04152022',)
# ('S1448_04202022',)
# ('S1448_04222022',)
# ('S1448_05022022',)
# ('S1448_05102022',)
# ('S1448_05162022',)
# ('S1448_05182022',)
# ('S1448_05222022',)
# ('S1448_05232022',)
# ('S1448_05242022',)
# ('S1448_05252022',)
# ('S1448_05262022',)
# ('S1448_05272022',)
# ('S1448_05292022',)
# ('S1448_05302022',)
# ('S1448_05312022',)
# ('S1448_06022022',)
# > GLM_SIGNALS_S1448_06022022.txt
# ('S1448_06062022',)
# > GLM_SIGNALS_S1448_06062022.txt
# ('S1448_06082022',)
# > GLM_SIGNALS_S1448_06082022.txt
# ('S1448_06102022',)
# > GLM_SIGNALS_S1448_06102022.txt
# ('S1448_06132022',)
# > GLM_SIGNALS_S1448_06132022.txt
# ('S1448_06152022',)
# > GLM_SIGNALS_S1448_06152022.txt
# ('S1448_06182022',)
# > GLM_SIGNALS_S1448_06182022.txt
# ('S1448_07072022',)
# ('S1448_07082022',)
# ('S1448_07092022',)
# ('S1448_07112022',)
# ('S1448_07122022',)
# ('S1448_07132022',)
# ('S1448_07142022',)
# ('S1448_07152022',)
# ('S1448_07162022',)
# ('S1448_07172022',)
# ('S1448_07182022',)
# ('S1448_07192022',)
# ('S1449_03172022',)
# ('S1449_03212022',)
# ('S1449_03232022',)
# ('S1449_03252022',)
# ('S1449_03282022',)
# ('S1449_03292022',)
# ('S1449_03302022',)
# ('S1449_03312022',)
# ('S1449_04012022',)
# ('S1449_04032022',)
# ('S1449_04052022',)
# ('S1449_04072022',)
# ('S1449_04082022',)
# ('S1449_04112022',)
# ('S1449_04132022',)
# ('S1449_04152022',)
# ('S1449_04202022',)
# ('S1449_04222022',)
# ('S1449_05022022',)
# ('S1449_05102022',)
# ('S1449_05162022',)
# ('S1449_05182022',)
# ('S1449_05222022',)
# ('S1449_05232022',)
# ('S1449_05242022',)
# ('S1449_05252022',)
# ('S1449_05262022',)
# ('S1449_05272022',)
# ('S1449_05292022',)
# ('S1449_05302022',)
# ('S1449_05312022',)
# ('S1449_06022022',)
# > GLM_SIGNALS_S1449_06022022.txt
# ('S1449_06062022',)
# > GLM_SIGNALS_S1449_06062022.txt
# ('S1449_06082022',)
# > GLM_SIGNALS_S1449_06082022.txt
# ('S1449_06102022',)
# > GLM_SIGNALS_S1449_06102022.txt
# ('S1449_06132022',)
# > GLM_SIGNALS_S1449_06132022.txt
# ('S1449_06152022',)
# > GLM_SIGNALS_S1449_06152022.txt
# ('S1449_06182022',)
# > GLM_SIGNALS_S1449_06182022.txt
# ('S1449_07072022',)
# ('S1449_07082022',)
# ('S1449_07092022',)
# ('S1449_07112022',)
# ('S1449_07122022',)
# ('S1449_07132022',)
# ('S1449_07142022',)
# ('S1449_07152022',)
# ('S1449_07162022',)
# ('S1449_07172022',)
# ('S1449_07182022',)
# ('S1449_07192022',)
# ('S1450_03172022',)
# ('S1450_03212022',)
# ('S1450_03232022',)
# ('S1450_03252022',)
# ('S1450_03282022',)
# ('S1450_03292022',)
# ('S1450_03302022',)
# ('S1450_03312022',)
# ('S1450_04012022',)
# ('S1450_04032022',)
# ('S1450_04052022',)
# ('S1450_04072022',)
# ('S1450_04082022',)
# ('S1450_04112022',)
# ('S1450_04132022',)
# ('S1450_04152022',)
# ('S1450_04202022',)
# ('S1450_04222022',)
# ('S1450_05022022',)
# ('S1450_05102022',)
# ('S1450_05162022',)
# ('S1450_05182022',)
# ('S1450_05222022',)
# ('S1450_05232022',)
# ('S1450_05242022',)
# ('S1450_05252022',)
# ('S1450_05262022',)
# ('S1450_05272022',)
# ('S1450_05292022',)
# ('S1450_05302022',)
# ('S1450_05312022',)
# ('S1450_06022022',)
# > GLM_SIGNALS_S1450_06022022.txt
# ('S1450_06062022',)
# > GLM_SIGNALS_S1450_06062022.txt
# ('S1450_06082022',)
# > GLM_SIGNALS_S1450_06082022.txt
# ('S1450_06102022',)
# > GLM_SIGNALS_S1450_06102022.txt
# ('S1450_06132022',)
# > GLM_SIGNALS_S1450_06132022.txt
# ('S1450_06152022',)
# > GLM_SIGNALS_S1450_06152022.txt
# ('S1450_06182022',)
# > GLM_SIGNALS_S1450_06182022.txt
# ('S1450_07072022',)
# ('S1450_07082022',)
# ('S1450_07092022',)
# ('S1450_07112022',)
# ('S1450_07122022',)
# ('S1450_07132022',)
# ('S1450_07142022',)
# ('S1450_07152022',)
# ('S1450_07162022',)
# ('S1450_07172022',)
# ('S1450_07182022',)
# ('S1450_07192022',)
# ('S1451_03172022',)
# ('S1451_03212022',)
# ('S1451_03232022',)
# ('S1451_03252022',)
# ('S1451_03282022',)
# ('S1451_03292022',)
# ('S1451_03302022',)
# ('S1451_03312022',)
# ('S1451_04012022',)
# ('S1451_04032022',)
# ('S1451_04052022',)
# ('S1451_04072022',)
# ('S1451_04082022',)
# ('S1451_04112022',)
# ('S1451_04132022',)
# ('S1451_04152022',)
# ('S1451_04202022',)
# ('S1451_04222022',)
# ('S1451_05022022',)
# ('S1451_05102022',)
# ('S1451_05162022',)
# ('S1451_05182022',)
# ('S1451_05222022',)
# ('S1451_05232022',)
# ('S1451_05242022',)
# ('S1451_05252022',)
# ('S1451_05262022',)
# ('S1451_05272022',)
# ('S1451_05292022',)
# ('S1451_05302022',)
# ('S1451_05312022',)
# ('S1451_06022022',)
# > GLM_SIGNALS_S1451_06022022.txt
# ('S1451_06062022',)
# > GLM_SIGNALS_S1451_06062022.txt
# ('S1451_06082022',)
# > GLM_SIGNALS_S1451_06082022.txt
# ('S1451_06102022',)
# > GLM_SIGNALS_S1451_06102022.txt
# ('S1451_06132022',)
# > GLM_SIGNALS_S1451_06132022.txt
# ('S1451_06152022',)
# > GLM_SIGNALS_S1451_06152022.txt
# ('S1451_06182022',)
# > GLM_SIGNALS_S1451_06182022.txt
# ('S1451_07072022',)
# ('S1451_07082022',)
# ('S1451_07092022',)
# ('S1451_07112022',)
# ('S1451_07122022',)
# ('S1451_07132022',)
# ('S1451_07142022',)
# ('S1451_07152022',)
# ('S1451_07162022',)
# ('S1451_07172022',)
# ('S1451_07182022',)
# ('S1451_07192022',)
# ('S1399_03172022',)
# ('S1399_03212022',)
# ('S1399_03232022',)
# ('S1399_03252022',)
# ('S1399_03282022',)
# ('S1399_03292022',)
# ('S1399_03302022',)
# ('S1399_03312022',)
# ('S1399_04012022',)
# ('S1399_04032022',)
# ('S1399_04052022',)
# ('S1399_04072022',)
# ('S1399_04082022',)
# ('S1399_04112022',)
# ('S1399_04132022',)
# ('S1399_04152022',)
# ('S1399_04202022',)
# ('S1399_04222022',)
# ('S1399_05022022',)
# > GLM_SIGNALS_S1399_05022022.txt
# ('S1399_05102022',)
# > GLM_SIGNALS_S1399_05102022.txt
# ('S1399_05162022',)
# > GLM_SIGNALS_S1399_05162022.txt
# ('S1399_05182022',)
# > GLM_SIGNALS_S1399_05182022.txt
# ('S1399_05222022',)
# ('S1399_05232022',)
# ('S1399_05242022',)
# ('S1399_05252022',)
# ('S1399_05262022',)
# ('S1399_05272022',)
# ('S1399_05292022',)
# ('S1399_05302022',)
# ('S1399_05312022',)
# ('S1399_06022022',)
# ('S1399_06062022',)
# ('S1399_06082022',)
# ('S1399_06102022',)
# ('S1399_06132022',)
# ('S1399_06152022',)
# ('S1399_06182022',)
# ('S1399_07072022',)
# ('S1399_07082022',)
# ('S1399_07092022',)
# ('S1399_07112022',)
# ('S1399_07122022',)
# ('S1399_07132022',)
# ('S1399_07142022',)
# ('S1399_07152022',)
# ('S1399_07162022',)
# ('S1399_07172022',)
# ('S1399_07182022',)
# ('S1399_07192022',)
# ('S1400_03172022',)
# ('S1400_03212022',)
# ('S1400_03232022',)
# ('S1400_03252022',)
# ('S1400_03282022',)
# ('S1400_03292022',)
# ('S1400_03302022',)
# ('S1400_03312022',)
# ('S1400_04012022',)
# ('S1400_04032022',)
# ('S1400_04052022',)
# ('S1400_04072022',)
# ('S1400_04082022',)
# ('S1400_04112022',)
# ('S1400_04132022',)
# ('S1400_04152022',)
# ('S1400_04202022',)
# ('S1400_04222022',)
# ('S1400_05022022',)
# > GLM_SIGNALS_S1400_05022022.txt
# ('S1400_05102022',)
# > GLM_SIGNALS_S1400_05102022.txt
# ('S1400_05162022',)
# > GLM_SIGNALS_S1400_05162022.txt
# ('S1400_05182022',)
# > GLM_SIGNALS_S1400_05182022.txt
# ('S1400_05222022',)
# ('S1400_05232022',)
# ('S1400_05242022',)
# ('S1400_05252022',)
# ('S1400_05262022',)
# ('S1400_05272022',)
# ('S1400_05292022',)
# ('S1400_05302022',)
# ('S1400_05312022',)
# ('S1400_06022022',)
# ('S1400_06062022',)
# ('S1400_06082022',)
# ('S1400_06102022',)
# ('S1400_06132022',)
# ('S1400_06152022',)
# ('S1400_06182022',)
# ('S1400_07072022',)
# ('S1400_07082022',)
# ('S1400_07092022',)
# ('S1400_07112022',)
# ('S1400_07122022',)
# ('S1400_07132022',)
# ('S1400_07142022',)
# ('S1400_07152022',)
# ('S1400_07162022',)
# ('S1400_07172022',)
# ('S1400_07182022',)
# ('S1400_07192022',)
# ('S1401_03172022',)
# ('S1401_03212022',)
# ('S1401_03232022',)
# ('S1401_03252022',)
# ('S1401_03282022',)
# ('S1401_03292022',)
# ('S1401_03302022',)
# ('S1401_03312022',)
# ('S1401_04012022',)
# ('S1401_04032022',)
# ('S1401_04052022',)
# ('S1401_04072022',)
# ('S1401_04082022',)
# ('S1401_04112022',)
# ('S1401_04132022',)
# ('S1401_04152022',)
# ('S1401_04202022',)
# ('S1401_04222022',)
# ('S1401_05022022',)
# > GLM_SIGNALS_S1401_05022022.txt
# ('S1401_05102022',)
# > GLM_SIGNALS_S1401_05102022.txt
# ('S1401_05162022',)
# ('S1401_05182022',)
# > GLM_SIGNALS_S1401_05182022.txt
# ('S1401_05222022',)
# ('S1401_05232022',)
# ('S1401_05242022',)
# ('S1401_05252022',)
# ('S1401_05262022',)
# ('S1401_05272022',)
# ('S1401_05292022',)
# ('S1401_05302022',)
# ('S1401_05312022',)
# ('S1401_06022022',)
# ('S1401_06062022',)
# ('S1401_06082022',)
# ('S1401_06102022',)
# ('S1401_06132022',)
# ('S1401_06152022',)
# ('S1401_06182022',)
# ('S1401_07072022',)
# ('S1401_07082022',)
# ('S1401_07092022',)
# ('S1401_07112022',)
# ('S1401_07122022',)
# ('S1401_07132022',)
# ('S1401_07142022',)
# ('S1401_07152022',)
# ('S1401_07162022',)
# ('S1401_07172022',)
# ('S1401_07182022',)
# ('S1401_07192022',)
# ('S1233_08312021',)
# ('S1233_09022021',)
# ('S1233_09062021',)
# ('S1233_09082021',)
# ('S1233_09102021',)
# ('S1233_09132021',)
# ('S1233_09152021',)
# ('S1233_09172021',)
# ('S1233_09202021',)
# ('S1233_10052021',)
# ('S1233_10072021',)
# ('S1233_10122021',)
# > GLM_SIGNALS_S1233_10122021.txt
# ('S1233_10142021',)
# > GLM_SIGNALS_S1233_10142021.txt
# ('S1233_10192021',)
# > GLM_SIGNALS_S1233_10192021.txt
# ('S1233_10212021',)
# > GLM_SIGNALS_S1233_10212021.txt
# ('S1233_10252021',)
# > GLM_SIGNALS_S1233_10252021.txt
# ('S1233_10272021',)
# > GLM_SIGNALS_S1233_10272021.txt
# ('S1233_11302021',)
# ('S1233_12022021',)
# ('S1233_12032021',)
# ('S1233_12062021',)
# ('S1233_12072021',)
# ('S1233_12082021',)
# ('S1233_12092021',)
# ('S1233_12102021',)
# ('S1233_12132021',)
# ('S1233_12142021',)
# ('S1234_08312021',)
# ('S1234_09022021',)
# ('S1234_09062021',)
# ('S1234_09082021',)
# ('S1234_09102021',)
# ('S1234_09132021',)
# ('S1234_09152021',)
# ('S1234_09172021',)
# ('S1234_09202021',)
# ('S1234_10052021',)
# ('S1234_10072021',)
# ('S1234_10122021',)
# > GLM_SIGNALS_S1234_10122021.txt
# ('S1234_10142021',)
# > GLM_SIGNALS_S1234_10142021.txt
# ('S1234_10192021',)
# > GLM_SIGNALS_S1234_10192021.txt
# ('S1234_10212021',)
# > GLM_SIGNALS_S1234_10212021.txt
# ('S1234_10252021',)
# > GLM_SIGNALS_S1234_10252021.txt
# ('S1234_10272021',)
# > GLM_SIGNALS_S1234_10272021.txt
# ('S1234_11302021',)
# ('S1234_12022021',)
# ('S1234_12032021',)
# ('S1234_12062021',)
# ('S1234_12072021',)
# ('S1234_12082021',)
# ('S1234_12092021',)
# ('S1234_12102021',)
# ('S1234_12132021',)
# ('S1234_12142021',)
# ('S1260_08312021',)
# ('S1260_09022021',)
# ('S1260_09062021',)
# ('S1260_09082021',)
# ('S1260_09102021',)
# ('S1260_09132021',)
# ('S1260_09152021',)
# ('S1260_09172021',)
# ('S1260_09202021',)
# ('S1260_10052021',)
# ('S1260_10072021',)
# ('S1260_10122021',)
# ('S1260_10142021',)
# ('S1260_10192021',)
# ('S1260_10212021',)
# ('S1260_10252021',)
# ('S1260_10272021',)
# ('S1260_11302021',)
# > GLM_SIGNALS_S1260_11302021.txt
# ('S1260_12022021',)
# ('S1260_12032021',)
# > GLM_SIGNALS_S1260_12032021.txt
# ('S1260_12062021',)
# ('S1260_12072021',)
# > GLM_SIGNALS_S1260_12072021.txt
# ('S1260_12082021',)
# ('S1260_12092021',)
# > GLM_SIGNALS_S1260_12092021.txt
# ('S1260_12102021',)
# ('S1260_12132021',)
# > GLM_SIGNALS_S1260_12132021.txt
# ('S1260_12142021',)
# ('S1246_08312021',)
# ('S1246_09022021',)
# ('S1246_09062021',)
# ('S1246_09082021',)
# ('S1246_09102021',)
# ('S1246_09132021',)
# ('S1246_09152021',)
# ('S1246_09172021',)
# ('S1246_09202021',)
# ('S1246_10052021',)
# ('S1246_10072021',)
# ('S1246_10122021',)
# ('S1246_10142021',)
# ('S1246_10192021',)
# ('S1246_10212021',)
# ('S1246_10252021',)
# ('S1246_10272021',)
# ('S1246_11302021',)
# ('S1246_12022021',)
# > GLM_SIGNALS_S1246_12022021.txt
# ('S1246_12032021',)
# ('S1246_12062021',)
# > GLM_SIGNALS_S1246_12062021.txt
# ('S1246_12072021',)
# ('S1246_12082021',)
# > GLM_SIGNALS_S1246_12082021.txt
# ('S1246_12092021',)
# ('S1246_12102021',)
# > GLM_SIGNALS_S1246_12102021.txt
# ('S1246_12132021',)
# ('S1246_12142021',)
# > GLM_SIGNALS_S1246_12142021.txt
# ('S1248_08312021',)
# ('S1248_09022021',)
# ('S1248_09062021',)
# ('S1248_09082021',)
# ('S1248_09102021',)
# ('S1248_09132021',)
# ('S1248_09152021',)
# ('S1248_09172021',)
# ('S1248_09202021',)
# ('S1248_10052021',)
# ('S1248_10072021',)
# ('S1248_10122021',)
# ('S1248_10142021',)
# ('S1248_10192021',)
# ('S1248_10212021',)
# ('S1248_10252021',)
# ('S1248_10272021',)
# ('S1248_11302021',)
# ('S1248_12022021',)
# > GLM_SIGNALS_S1248_12022021.txt
# ('S1248_12032021',)
# ('S1248_12062021',)
# > GLM_SIGNALS_S1248_12062021.txt
# ('S1248_12072021',)
# ('S1248_12082021',)
# > GLM_SIGNALS_S1248_12082021.txt
# ('S1248_12092021',)
# ('S1248_12102021',)
# > GLM_SIGNALS_S1248_12102021.txt
# ('S1248_12132021',)
# ('S1248_12142021',)
# > GLM_SIGNALS_S1248_12142021.txt
# ('S1194_08312021',)
# > GLM_SIGNALS_S1194_08312021.txt
# ('S1194_09022021',)
# > GLM_SIGNALS_S1194_09022021.txt
# ('S1194_09062021',)
# > GLM_SIGNALS_S1194_09062021.txt
# ('S1194_09082021',)
# > GLM_SIGNALS_S1194_09082021.txt
# ('S1194_09102021',)
# > GLM_SIGNALS_S1194_09102021.txt
# ('S1194_09132021',)
# > GLM_SIGNALS_S1194_09132021.txt
# ('S1194_09152021',)
# > GLM_SIGNALS_S1194_09152021.txt
# ('S1194_09172021',)
# > GLM_SIGNALS_S1194_09172021.txt
# ('S1194_09202021',)
# > GLM_SIGNALS_S1194_09202021.txt
# ('S1194_10052021',)
# ('S1194_10072021',)
# ('S1194_10122021',)
# ('S1194_10142021',)
# ('S1194_10192021',)
# ('S1194_10212021',)
# ('S1194_10252021',)
# ('S1194_10272021',)
# ('S1194_11302021',)
# ('S1194_12022021',)
# ('S1194_12032021',)
# ('S1194_12062021',)
# ('S1194_12072021',)
# ('S1194_12082021',)
# ('S1194_12092021',)
# ('S1194_12102021',)
# ('S1194_12132021',)
# ('S1194_12142021',)
# ('S1195_08312021',)
# > GLM_SIGNALS_S1195_08312021.txt
# ('S1195_09022021',)
# > GLM_SIGNALS_S1195_09022021.txt
# ('S1195_09062021',)
# > GLM_SIGNALS_S1195_09062021.txt
# ('S1195_09082021',)
# > GLM_SIGNALS_S1195_09082021.txt
# ('S1195_09102021',)
# > GLM_SIGNALS_S1195_09102021.txt
# ('S1195_09132021',)
# > GLM_SIGNALS_S1195_09132021.txt
# ('S1195_09152021',)
# > GLM_SIGNALS_S1195_09152021.txt
# ('S1195_09172021',)
# > GLM_SIGNALS_S1195_09172021.txt
# ('S1195_09202021',)
# > GLM_SIGNALS_S1195_09202021.txt
# ('S1195_10052021',)
# ('S1195_10072021',)
# ('S1195_10122021',)
# ('S1195_10142021',)
# ('S1195_10192021',)
# ('S1195_10212021',)
# ('S1195_10252021',)
# ('S1195_10272021',)
# ('S1195_11302021',)
# ('S1195_12022021',)
# ('S1195_12032021',)
# ('S1195_12062021',)
# ('S1195_12072021',)
# ('S1195_12082021',)
# ('S1195_12092021',)
# ('S1195_12102021',)
# ('S1195_12132021',)
# ('S1195_12142021',)
# ('S1214_08312021',)
# ('S1214_09022021',)
# ('S1214_09062021',)
# ('S1214_09082021',)
# ('S1214_09102021',)
# ('S1214_09132021',)
# ('S1214_09152021',)
# ('S1214_09172021',)
# ('S1214_09202021',)
# ('S1214_10052021',)
# > GLM_SIGNALS_S1214_10052021.txt
# ('S1214_10072021',)
# > GLM_SIGNALS_S1214_10072021.txt
# ('S1214_10122021',)
# > GLM_SIGNALS_S1214_10122021.txt
# ('S1214_10142021',)
# > GLM_SIGNALS_S1214_10142021.txt
# ('S1214_10192021',)
# ('S1214_10212021',)
# > GLM_SIGNALS_S1214_10212021.txt
# ('S1214_10252021',)
# > GLM_SIGNALS_S1214_10252021.txt
# ('S1214_10272021',)
# ('S1214_11302021',)
# ('S1214_12022021',)
# ('S1214_12032021',)
# ('S1214_12062021',)
# ('S1214_12072021',)
# ('S1214_12082021',)
# ('S1214_12092021',)
# ('S1214_12102021',)
# ('S1214_12132021',)
# ('S1214_12142021',)
# ('S1258_08312021',)
# ('S1258_09022021',)
# ('S1258_09062021',)
# ('S1258_09082021',)
# ('S1258_09102021',)
# ('S1258_09132021',)
# ('S1258_09152021',)
# ('S1258_09172021',)
# ('S1258_09202021',)
# ('S1258_10052021',)
# ('S1258_10072021',)
# ('S1258_10122021',)
# ('S1258_10142021',)
# ('S1258_10192021',)
# ('S1258_10212021',)
# ('S1258_10252021',)
# ('S1258_10272021',)
# ('S1258_11302021',)
# > GLM_SIGNALS_S1258_11302021.txt
# ('S1258_12022021',)
# ('S1258_12032021',)
# > GLM_SIGNALS_S1258_12032021.txt
# ('S1258_12062021',)
# ('S1258_12072021',)
# > GLM_SIGNALS_S1258_12072021.txt
# ('S1258_12082021',)
# ('S1258_12092021',)
# > GLM_SIGNALS_S1258_12092021.txt
# ('S1258_12102021',)
# ('S1258_12132021',)
# > GLM_SIGNALS_S1258_12132021.txt
# ('S1258_12142021',)
# ('S1259_08312021',)
# ('S1259_09022021',)
# ('S1259_09062021',)
# ('S1259_09082021',)
# ('S1259_09102021',)
# ('S1259_09132021',)
# ('S1259_09152021',)
# ('S1259_09172021',)
# ('S1259_09202021',)
# ('S1259_10052021',)
# ('S1259_10072021',)
# ('S1259_10122021',)
# ('S1259_10142021',)
# ('S1259_10192021',)
# ('S1259_10212021',)
# ('S1259_10252021',)
# ('S1259_10272021',)
# ('S1259_11302021',)
# > GLM_SIGNALS_S1259_11302021.txt
# ('S1259_12022021',)
# ('S1259_12032021',)
# > GLM_SIGNALS_S1259_12032021.txt
# ('S1259_12062021',)
# ('S1259_12072021',)
# > GLM_SIGNALS_S1259_12072021.txt
# ('S1259_12082021',)
# ('S1259_12092021',)
# > GLM_SIGNALS_S1259_12092021.txt
# ('S1259_12102021',)
# ('S1259_12132021',)
# > GLM_SIGNALS_S1259_12132021.txt
# ('S1259_12142021',)
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=291.0), HTML(value='')))
# constructed_dir /
# constructed_dir /
# /Users/josh/Documents/Harvard/GLM/sabatinilab-glm/sglm/data/raw/fig1/GLM_SIGNALS_WT63_11102021.txt
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-33d83633999a> in <module>
#      50
#      51     print(signal_path)
# ---> 52     signal_df, table_df = gsd.generate_signal_df(signal_path,
#      53                                             table_path,
#      54                                             # signal_filename_out=f'../../data/interim2/{signal_filename_out}',
#
# ~/Documents/Harvard/GLM/sabatinilab-glm/sglm/sglm/features/gen_signal_df.py in generate_signal_df(signal_filename, table_filename, table_index_columns, basis_Aa_cols, trial_bounds_before_center_in, trial_bounds_after_side_out)
#     384
#     385     # Replace center outs that got transferred to the next timestep to be equal to center in value
# --> 386     df_t = replace_missed_center_out_indexes(df_t, verbose=1)
#     387
#     388     #
#
# ~/Documents/Harvard/GLM/sabatinilab-glm/sglm/sglm/features/gen_signal_df.py in replace_missed_center_out_indexes(df_t, max_num_duplications, verbose)
#     187         duplicated_CO_inx2 = (df_t['photometryCenterOutIndex'] > df_t['photometryCenterOutIndex'].shift(-1))&(df_t['photometryCenterOutIndex'].shift(-1) > 0)&(df_t['photometryCenterOutIndex'] > 0)
#     188
# --> 189         key = df_t.loc[duplicated_CO_inx|duplicated_CO_inx2].index.iloc[0]
#     190         lb, ub = key-5, key+5
#     191         display(df_t[lb:ub])
#
# AttributeError: 'Int64Index' object has no attribute 'iloc'

# %%
signal_df[['sl', 'r_trial', 'nr_trial', 'slOff', ]].iloc[1000:2000].plot()
signal_df[signal_df['r_trial'] == signal_df['nr_trial']]

# %%
# signal_df.columns

# %%
# a = signal_df.groupby('nTrial')['slOff'].sum()
# a[a > 0]

# %%
# # df['spnnr'] = ((df['spnnr'] == 1)&(df['photometrySideInIndex'] != 1)).astype(int)
# # df['spxnr'] = ((df['spxnr'] == 1)&(df['photometrySideOutIndex'] != 1)).astype(int)

# X_cols = [_ for _ in X_cols_all if _ not in left_out]

# if len(leave_one_out_list) > 1:
#     run_id = f'{prefix}_{fn}_{y_col}_drop={"_".join(left_out)}'
# else:
#     run_id = f'{prefix}_{fn}_{y_col}'

# dfrel = df.copy()

# dfrel, X_cols_sftd = lpp.timeshift_vals(dfrel, X_cols, neg_order=neg_order, pos_order=pos_order)

# dfrel_setup, dfrel_holdout = holdout_splits(dfrel,
#                                             id_cols=['nTrial'],
#                                             perc_holdout=pholdout)
# dfrel_setup, dfrel_holdout = dfrel_setup.copy(), dfrel_holdout.copy()

# kfold_cv_idx = sglm_ez.cv_idx_by_trial_id(dfrel_setup,
#                                           trial_id_columns=['nTrial'],
#                                           num_folds=folds,
#                                           test_size=pgss)

# prediction_X_cols = [_ for _ in X_cols if _ not in ['nTrial']]
# prediction_X_cols_sftd = [_ for _ in X_cols_sftd if _ not in ['nTrial']]

# X_setup = get_x(dfrel_setup, prediction_X_cols_sftd, keep_rows=None)
# y_setup = get_y(dfrel_setup, y_col, keep_rows=None)
# X_setup_noiti = get_x(dfrel_setup, prediction_X_cols_sftd, keep_rows=dfrel_setup['wi_trial_keep'])
# y_setup_noiti = get_y(dfrel_setup, y_col, keep_rows=dfrel_setup['wi_trial_keep'])
# best_score, best_score_std, best_params, best_model, cv_results = sglm_ez.simple_cv_fit(X_setup, y_setup, kfold_cv_idx, glm_kwarg_lst, model_type='Normal', verbose=0, score_method=score_method)

# sglm_ez.print_best_model_info(X_setup, best_score, best_params, best_model, start)

# X_holdout_witi = get_x(dfrel_holdout, prediction_X_cols_sftd, keep_rows=None)
# y_holdout_witi = get_y(dfrel_holdout, y_col, keep_rows=None)
# X_holdout_noiti = get_x(dfrel_holdout, prediction_X_cols_sftd, keep_rows=dfrel_holdout['wi_trial_keep'])
# y_holdout_noiti = get_y(dfrel_holdout, y_col, keep_rows=dfrel_holdout['wi_trial_keep'])
# glm, holdout_score, holdout_neg_mse_score = sglm_ez.training_fit_holdout_score(X_setup, y_setup, X_holdout_noiti, y_holdout_noiti, best_params)

# dfrel['pred'] = glm.predict(dfrel[prediction_X_cols_sftd])
# dfrel_setup['pred'] = glm.predict(dfrel_setup[prediction_X_cols_sftd])
# dfrel_holdout['pred'] = glm.predict(dfrel_holdout[prediction_X_cols_sftd])

# # Collect
# results_dict[f'{run_id}'] = {'holdout_score':holdout_score,
#                             'holdout_neg_mse_score':holdout_neg_mse_score,
#                             'best_score':best_score,
#                             'best_params':best_params,
#                             'all_models':sorted([(_['cv_R2_score'],
#                                                     _['cv_mse_score'],
#                                                     sglm_ez.calc_l1(_['cv_coefs']),
#                                                     sglm_ez.calc_l2(_['cv_coefs']),
#                                                     _['glm_kwargs']) for _ in cv_results['full_cv_results']], key=lambda x: -x[0])
#                             }

# X_cols_plot = prediction_X_cols
# X_cols_sftd_plot = prediction_X_cols_sftd

# # print('X_setup.columns', list(X_setup.columns), len(list(X_setup.columns)))
# # print('X_setup_noiti.columns', list(X_setup_noiti.columns), len(list(X_setup_noiti.columns)))
# # print('X_holdout_witi.columns', list(X_holdout_witi.columns), len(list(X_holdout_witi.columns)))
# # print('X_holdout_noiti.columns', list(X_holdout_noiti.columns), len(list(X_holdout_noiti.columns)))


# holdout_score_rnd = np.round(holdout_score, 4)
# best_beta_fn = f'{best_coeffs_folder}/{run_id}_best_{all_betas_basename}_R2_{holdout_score_rnd}.png'
# splt.plot_all_beta_coefs(glm.coef_, X_cols_plot,
#                                 X_cols_sftd_plot,
#                                 plot_width=4,
#                                 # plot_width=2,
#                                 y_lims=(-2.5, 2.5),
#                                 # filename=f'{fn}_coeffs.png',
#                                 binsize=54,
#                                 filename=best_beta_fn,
#                                 plot_name=f'Best Coeffs - {run_id} — {best_params}'
#                                 )

# best_beta_fn = f'{best_reconstruct_folder}/{run_id}_best_{avg_reconstruct_basename}_R2_{holdout_score_rnd}.png'




# splt.plot_avg_reconstructions_v2(dfrel_holdout,
# # splt.plot_avg_reconstructions_v2(dfrel,
#                             channel=y_col,
#                             binsize = 54,
#                             plot_width=4,
#                             min_time = -20,
#                             max_time = 30,
#                             min_signal = -3.0,
#                             max_signal = 3.0,
#                             file_name=best_beta_fn,
#                             title=f'Best Average Reconstruction - {run_id} — {best_params}'
#                             )

# for fitted_model_dict in (cv_results['full_cv_results']):
#     fitted_model = fitted_model_dict['model']
#     kwarg_info = "_".join([f"{_k}_{fitted_model_dict['glm_kwargs'][_k]}" for _k in fitted_model_dict["glm_kwargs"]])

#     model_coef = fitted_model.coef_
#     model_intercept = fitted_model.intercept_

#     std_name = f'{run_id}_{kwarg_info}'
#     np.save(f'{all_models_folder}/coeffs/{std_name}_{model_c_basename}.npy', model_coef)
#     np.save(f'{all_models_folder}/intercepts/{std_name}_{model_i_basename}.npy', model_intercept)
    
#     tmp_holdout_score = fitted_model.r2_score(X_holdout_noiti, y_holdout_noiti)

#     glmsave.append_fit_results(y_col, fitted_model_dict["glm_kwargs"], glm_model=fitted_model, dropped_cols=left_out,
#                             scores={
#                                 'tr_witi':fitted_model.r2_score(X_setup, y_setup),
#                                 'tr_noiti':fitted_model.r2_score(X_setup_noiti, y_setup_noiti),
#                                 'gss_witi':fitted_model_dict['cv_R2_score'],
#                                 'gss_noiti':None,
#                                 'holdout_witi':fitted_model.r2_score(X_holdout_witi, y_holdout_witi),
#                                 'holdout_noiti':fitted_model.r2_score(X_holdout_noiti, y_holdout_noiti)
#                             },
#                             gssids=kfold_cv_idx)

#     tmp = dfrel_holdout.set_index('nTrial').copy()
#     tmp['pred'] = fitted_model.predict(get_x(dfrel_holdout, prediction_X_cols_sftd, keep_rows=None))
#     tmp = lpp.get_first_entry_time(tmp)
#     tmp_y = get_y(dfrel_holdout, y_col, keep_rows=None).copy()
#     tmp_y.index = tmp.index
#     tmp[y_holdout_noiti.name] = tmp_y

#     tmp.to_csv(f'{all_data_folder}/{std_name}_{tmp_data_basename}.csv')

#     holdout_score_rnd = np.round(tmp_holdout_score, 4)


#     splt.plot_all_beta_coefs(fitted_model.coef_, X_cols_plot,
#                                     X_cols_sftd_plot,
#                                     plot_width=4,
#                                     y_lims=(-3.0, 3.0),
#                                     # filename=f'{fn}_coeffs.png',
#                                     binsize=54,
#                                     filename=f'{all_coeffs_folder}/{std_name}_{all_betas_basename}_R2_{holdout_score_rnd}.png',
#                                     plot_name=f'Coeffs by Timeshift - {run_id} — {kwarg_info}'
#                                     # plot_name=f'{fn} — {y_col} — {kwarg_info}'
#                                     )
    
#     plt.close('all')
# plt.close('all')


# glmsave.save()

# %%
# t = df[['nTrial', 'r_trial', 'nr_trial', 'photometrySideInIndexr', 'photometrySideInIndexnr', 'photometryCenterInIndex']]
# t.loc[2295:2345]

# %%
# df

# %%
# sorted(list(set([_.split('_')[-1].split('.')[0] for _ in glob.glob('/Users/josh/Documents/Harvard/GLM/sabatinilab-glm/sglm/data/raw/fig3/*')])))

# %%
signal_fn = signal_files[file_num].split('/')[-1]
table_fn = table_files[file_num].split('/')[-1]

# %%
import glob
g1 = sorted(glob.glob('/Users/josh/Documents/Harvard/GLM/sabatinilab-glm/sglm/data/interim2/*/*.csv'))
g1 = [_ for _ in g1 if '-bu/' not in _]
g2 = sorted(glob.glob('/Users/josh/Documents/Harvard/GLM/sabatinilab-glm/sglm/data/interim2/*/*/*.csv'))
g2 = [_ for _ in g2 if '-bu/' not in _]
for tf in g1:
    tmptf = '/'.join(tf.split('/')[-2:]).replace('.csv', '')
    tmptf = '/'.join(tmptf.split('/')[-2:]).replace('GLM_TABLE_', '')
    tmptf = '/'.join(tmptf.split('/')[-2:]).replace('GLM_SIGNALS_', '')
    tmptf = tmptf.replace('INTERIM_','')
    print(tmptf)

for tf in g2:
    tmptf = '/'.join(tf.split('/')[-3:]).replace('.csv', '')
    tmptf = '/'.join(tmptf.split('/')[-3:]).replace('GLM_TABLE_', '')
    tmptf = '/'.join(tmptf.split('/')[-3:]).replace('GLM_SIGNALS_', '')
    tmptf = tmptf.replace('INTERIM_','')
    print(tmptf)

# %%
import glob
app = []
for tf in sorted(glob.glob('/Users/josh/Documents/Harvard/GLM/sabatinilab-glm/sglm/data/raw/fig4/*.txt')):
    app.append(tf.split('/')[-1].replace('.txt', '').split('_')[-1])

print(sorted(list(set(app))))

# %%
tmp = pd.read_csv('/Users/josh/Documents/Harvard/GLM/sabatinilab-glm/sglm/data/raw/fig5/GLM_SIGNALS_S1449_06022022.txt')
tmp

# %%
tmp = pd.read_csv('/Users/josh/Documents/Harvard/GLM/sabatinilab-glm/sglm/data/raw/fig5/GLM_TABLE_S1449_06022022.txt').drop('word',axis=1).astype(float)
# tmp[(tmp == 19821).sum(axis=1) >= 1]
tmp[(tmp[['photometrySideInIndex']] <= 20000).sum(axis=1) >= 1]

# %%
tmp
