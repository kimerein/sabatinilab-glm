# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# def dfrel_to_ho_set():
#     return

# %%
# from logging.config import _RootLoggerConfiguration

import os
from pathlib import Path

def create_folder_if_not_exists(dir):
    dir = str(Path(dir).resolve())
    constructed_dir = '/'
    made = False
    for fold in dir.split('/'):
        if len(fold) == 0:
            continue
        constructed_dir += fold + '/'
        if os.path.isdir(constructed_dir):
            # print(f'Directory already exists:', constructed_dir)
            pass
        else:
            # print(f'Creating directory:', constructed_dir)
            os.mkdir(constructed_dir)
            made = True
    if made:
        print(f'Created directory:', constructed_dir)
    return

# create_folder_if_not_exists((Path.home() / 'Desktop/nada/folder2').resolve())

# %%
from sglm.models import sglm_cv
import itertools
import time
import glob
import numpy as np
import pandas as pd
import numpy as np
from sglm.features import gen_signal_df as gsd
from sglm.features import build_features as bf
from sglm.features import setup_model_fit as smf
from sglm.models import sglm_cv
from sglm import models
from sglm.visualization import visualize
from sglm.models import train_model
from sglm.models import eval
from sglm import features

neg_order = -20
pos_order = 20

fix_training = True
# fix_training = False
ft_str = '-ft' if fix_training else ''

# multifile_fit = 'single' #False
# multifile_fit = 'all' #True
# multifile_fit = 'by_mouse'
# multifile_fit_list = ['all']
# multifile_fit_list = ['by_mouse']
multifile_fit_list = ['all']
# multifile_fit_list = ['by_mouse', 'all']
# multifile_fit_list = ['all']
# multifile_fit_list = ['single']

# base_prefix = 'trial_abm_slOff'
# base_prefix = 'bidir_pred_bidir'
# base_prefix = 'dh'
# base_prefix = 'gr-dual-n62'
# base_prefix = 'bidir-ctrl-nslO'
# base_prefix = 'DA-DA-pred'
# base_prefix = 'ACH-to-DA'
# base_prefix = 'DA-to-ACH__'

# base_prefix = 'ind'
# base_prefix = 'resid'
# base_prefix = 'resid-chk'
# base_prefix = 'resid-chk5'
# base_prefix = 'test-res_trk'


# base_prefix = 'f1-bkwd-sel'
# base_prefix = 'f1-bkwd-sel-gACH2-rl'
# base_prefix = 'f1-bkwd-sel-rDA2'
# base_prefix = 'f1-bkwd-sel-gDA2'

# base_prefix = 'f1-bkwd-sel-hypPrm-rDA'
# base_prefix = 'f1-bkwd-sel-hypPrm-gACH'

tmp_y_col_setup = 'gACH'
# base_prefix = f'f1-bkwd-sel-{tmp_y_col_setup}3'
# base_prefix = 'f1-bkwd-sel-rDA3'
# base_prefix = 'f1-bkwd-sel-gDA3'

# base_prefix = f'mse-tr-te-invstg3-{tmp_y_col_setup}'
# base_prefix = f'mse-tr-te-invstg-ho-{tmp_y_col_setup}'
# base_prefix = f'mse-tr-te-invstg-all-{tmp_y_col_setup}'
# base_prefix = f'mse-tr-te-lim-bnds-{tmp_y_col_setup}'

# base_prefix = f'bs-words-{tmp_y_col_setup}'
base_prefix = f'nw-anlysis'


data_folder = 'fig1'
# data_folder = 'fig3'
# data_folder = 'fig3-dualhem'
# data_folder = 'fig5/g1'
# data_folder = 'fig5/g2'
# data_folder = 'fig5/g3'
# data_folder = 'fig5/g4'
# data_folder = 'fig5/g5'

# data_folder = 'fig3-dualhem'





if data_folder == 'fig1':

    wt_used = [
                'WT63', 'WT64'
            #    'WT63', 'WT64', 'WT65', 'WT66', 'WT67', 'WT68', 'WT69', # DA
            #    'WT57', 'WT58', 'WT59', 'WT60', 'WT61', 'WT53', 'WT55', 'WT56' # ACH
               ]
    
elif data_folder == 'fig3':
    wt_used = ['WT61', 'WT63', 'WT64', 'WT44', 'WT51']
elif data_folder == 'fig3-dualhem':
    wt_used = ['WT63', 'WT64', 'WT65']

elif data_folder == 'fig4/g1':
    wt_used = ['S1233', 'S1234', 'S1260', 'S1246', 'S1248']
elif data_folder == 'fig4/g2':
    wt_used = ['S1194', 'S1195', 'S1214', 'S1258', 'S1259']

elif data_folder == 'fig5/g1': # Drd2f/f control: S1417, 1419, 1421
    # wt_used = ['S1417', 'S1419', 'S1421']
    wt_used = ['S1417', 'S1419', 'S1421', 'S1460', 'S1462', 'S1473', 'S1474']
elif data_folder == 'fig5/g2': # Chat Cre X Drd2f/f : S1416, 1418, 1420, 1422
    # wt_used = ['S1416', 'S1418', 'S1420', 'S1422']
    wt_used = ['S1416', 'S1418', 'S1420', 'S1459', 'S1461', 'S1470', 'S1471', 'S1472']
elif data_folder == 'fig5/g3': # Chat Cre control: S1355-1358, S1374, S1376
    # wt_used = ['S1355', 'S1356', 'S1357', 'S1358', 'S1374', 'S1376']
    wt_used = ['S1355', 'S1356', 'S1357', 'S1358', 'S1374', 'S1376',
               'S1448', 'S1449', 'S1450', 'S1451']
elif data_folder == 'fig5/g4': # Chat Cre control: S1399-1401
    # wt_used = ['S1399', 'S1400', 'S1401']
    wt_used = ['S1399', 'S1400', 'S1401']
elif data_folder == 'fig5/g5':
    # wt_used = ['S1355', 'S1356', 'S1357', 'S1358', 'S1374', 'S1376', 'S1399', 'S1400', 'S1401']
    wt_used = ['S1355', 'S1356', 'S1357', 'S1358', 'S1374', 'S1376',
               'S1448', 'S1449', 'S1450', 'S1451'
               'S1399', 'S1400', 'S1401']
elif data_folder == 'fig5/g6':
    wt_used = []
else:
    raise ValueError('Unimplemented figure values.')

data_folder_join = '_'.join(data_folder.split('/'))


# ### Backwards Selection
# X_y_pairings = [
#     {'X_cols': {
#                 'rDA': (0, 0),
#                },
#      'y_col': tmp_y_col_setup},
#     {'X_cols': {
#                 'photometryCenterInIndex':(0,0),
#                 'photometryCenterOutIndex':(0,0),
#                 'photometrySideInIndex':(0,0),
#                 'photometrySideInIndexr':(0,0),                
#                 'photometrySideOutIndex':(0,0),
#                 'sl': (0,0),
#                 'spnnrOff': (0,0),
#                },
#      'y_col': tmp_y_col_setup + '_resid'},
#     {'X_cols': {
#                 'photometryCenterInIndex':(0,0),
#                 'photometryCenterOutIndex':(0,0),
#                 'photometrySideInIndex':(0,0),
#                 'photometrySideInIndexr':(0,0),                
#                 'photometrySideOutIndex':(0,0),
#                 'sl': (0,0),
#                 'spnnrOff': (0,0),
#                 'rDA': (0, 0),
#                },
#      'y_col': tmp_y_col_setup},
#     {'X_cols': {
#                 'photometryCenterInIndex':(0,0),
#                 'photometryCenterOutIndex':(0,0),

#                 'photometrySideInIndexAA':(0,0), 'photometrySideInIndexAa':(0,0),
#                 'photometrySideInIndexaA':(0,0), 'photometrySideInIndexaa':(0,0),
#                 'photometrySideInIndexAB':(0,0), 'photometrySideInIndexAb':(0,0),
#                 'photometrySideInIndexaB':(0,0), 'photometrySideInIndexab':(0,0),

#                 'photometrySideOutIndex':(0,0),
#                 'sl': (0,0),
#                 'spnnrOff': (0,0),
#                },
#      'y_col': tmp_y_col_setup},
# ]


# ## Start by saying this model works
# {
#     'photometryCenterInIndex':(0,0),
#     'photometryCenterOutIndex':(0,0),
#     'photometrySideInIndex':(0,0),
#     'photometrySideInIndexr':(0,0),                
#     'photometrySideOutIndex':(0,0),
#     'sl': (0,0),
#     'spnnrOff': (0,0),
# }
# # Go through & drop one by one


num_runs = 10

### Backwards Selection
X_y_pairings_lst = []

X_y_pairings_lst += [[
    {'X_cols': {
                'photometryCenterInIndex':(0,0),
                'photometryCenterOutIndex':(0,0),
                'photometrySideInIndex':(0,0),
                'photometrySideInIndexr':(0,0),                
                'photometrySideOutIndex':(0,0),
                'sl': (0,0),
                'spnnrOff': (0,0),
               },
     'y_col': 'gACH',
     'name': 'base-simple'
     },
    {'X_cols': {
                # 'photometryCenterInIndex':(0,0),
                'photometryCenterOutIndex':(0,0),
                'photometrySideInIndex':(0,0),
                'photometrySideInIndexr':(0,0),
                'photometrySideOutIndex':(0,0),
                'sl': (0,0),
                'spnnrOff': (0,0),
               },
     'y_col': 'gACH',
     'name': 'no-CI'},
    # {'X_cols': {
    #             'photometryCenterInIndex':(0,0),
    #             # 'photometryCenterOutIndex':(0,0),
    #             'photometrySideInIndex':(0,0),
    #             'photometrySideInIndexr':(0,0),
    #             'photometrySideOutIndex':(0,0),
    #             'sl': (0,0),
    #             'spnnrOff': (0,0),
    #            },
    #  'y_col': 'gACH',
    #  'name': 'no-CO'},
    # {'X_cols': {
    #             'photometryCenterInIndex':(0,0),
    #             'photometryCenterOutIndex':(0,0),
    #             # 'photometrySideInIndex':(0,0),
    #             'photometrySideInIndexr':(0,0),
    #             'photometrySideOutIndex':(0,0),
    #             'sl': (0,0),
    #             'spnnrOff': (0,0),
    #            },
    #  'y_col': 'gACH',
    #  'name': 'no-SI'},
    # {'X_cols': {
    #             'photometryCenterInIndex':(0,0),
    #             'photometryCenterOutIndex':(0,0),
    #             'photometrySideInIndex':(0,0),
    #             # 'photometrySideInIndexr':(0,0),
    #             'photometrySideOutIndex':(0,0),
    #             'sl': (0,0),
    #             'spnnrOff': (0,0),
    #            },
    #  'y_col': 'gACH',
    #  'name': 'no-SIr'},
    # {'X_cols': {
    #             'photometryCenterInIndex':(0,0),
    #             'photometryCenterOutIndex':(0,0),
    #             'photometrySideInIndex':(0,0),
    #             'photometrySideInIndexr':(0,0),
    #             # 'photometrySideOutIndex':(0,0),
    #             'sl': (0,0),
    #             'spnnrOff': (0,0),
    #            },
    #  'y_col': 'gACH',
    #  'name': 'no-SO'},
    # {'X_cols': {
    #             'photometryCenterInIndex':(0,0),
    #             'photometryCenterOutIndex':(0,0),
    #             'photometrySideInIndex':(0,0),
    #             'photometrySideInIndexr':(0,0),
    #             'photometrySideOutIndex':(0,0),
    #             # 'sl': (0,0),
    #             'spnnrOff': (0,0),
    #            },
    #  'y_col': 'gACH',
    #  'name': 'no-sl'},
    # {'X_cols': {
    #             'photometryCenterInIndex':(0,0),
    #             'photometryCenterOutIndex':(0,0),
    #             'photometrySideInIndex':(0,0),
    #             'photometrySideInIndexr':(0,0),
    #             'photometrySideOutIndex':(0,0),
    #             'sl': (0,0),
    #             # 'spnnrOff': (0,0),
    #            },
    #  'y_col': 'gACH',
    #  'name': 'no-spnnrOff'},
    # {'X_cols': {
    #             'photometryCenterInIndex':(0,0),
    #             'photometryCenterOutIndex':(0,0),
    #             'photometrySideInIndexAA':(0,0),
    #             'photometrySideInIndexAa':(0,0),
    #             'photometrySideInIndexaA':(0,0),
    #             'photometrySideInIndexaa':(0,0),
    #             'photometrySideInIndexAB':(0,0),
    #             'photometrySideInIndexAb':(0,0),
    #             'photometrySideInIndexaB':(0,0),
    #             'photometrySideInIndexab':(0,0),
    #             'photometrySideOutIndex':(0,0),
    #             'sl': (0,0),
    #             'spnnrOff': (0,0),
    #            },
    #  'y_col': 'gACH',
    #  'name': 'base-words'},

]]

X_y_pairings_lst += [[

    {'X_cols': {
                'photometryCenterInIndex':(0,0),
                'photometryCenterOutIndex':(0,0),
                'photometrySideInIndex':(0,0),
                'photometrySideInIndexr':(0,0),                
                'photometrySideOutIndex':(0,0),
                'sl': (0,0),
                'spnnrOff': (0,0),
               },
     'y_col': 'rDA',
     'name': 'base-simple'
     },
    {'X_cols': {
                # 'photometryCenterInIndex':(0,0),
                'photometryCenterOutIndex':(0,0),
                'photometrySideInIndex':(0,0),
                'photometrySideInIndexr':(0,0),
                'photometrySideOutIndex':(0,0),
                'sl': (0,0),
                'spnnrOff': (0,0),
               },
     'y_col': 'rDA',
     'name': 'no-CI'},
    # {'X_cols': {
    #             'photometryCenterInIndex':(0,0),
    #             # 'photometryCenterOutIndex':(0,0),
    #             'photometrySideInIndex':(0,0),
    #             'photometrySideInIndexr':(0,0),
    #             'photometrySideOutIndex':(0,0),
    #             'sl': (0,0),
    #             'spnnrOff': (0,0),
    #            },
    #  'y_col': 'rDA',
    #  'name': 'no-CO'},
    # {'X_cols': {
    #             'photometryCenterInIndex':(0,0),
    #             'photometryCenterOutIndex':(0,0),
    #             # 'photometrySideInIndex':(0,0),
    #             'photometrySideInIndexr':(0,0),
    #             'photometrySideOutIndex':(0,0),
    #             'sl': (0,0),
    #             'spnnrOff': (0,0),
    #            },
    #  'y_col': 'rDA',
    #  'name': 'no-SI'},
    # {'X_cols': {
    #             'photometryCenterInIndex':(0,0),
    #             'photometryCenterOutIndex':(0,0),
    #             'photometrySideInIndex':(0,0),
    #             # 'photometrySideInIndexr':(0,0),
    #             'photometrySideOutIndex':(0,0),
    #             'sl': (0,0),
    #             'spnnrOff': (0,0),
    #            },
    #  'y_col': 'rDA',
    #  'name': 'no-SIr'},
    # {'X_cols': {
    #             'photometryCenterInIndex':(0,0),
    #             'photometryCenterOutIndex':(0,0),
    #             'photometrySideInIndex':(0,0),
    #             'photometrySideInIndexr':(0,0),
    #             # 'photometrySideOutIndex':(0,0),
    #             'sl': (0,0),
    #             'spnnrOff': (0,0),
    #            },
    #  'y_col': 'rDA',
    #  'name': 'no-SO'},
    # {'X_cols': {
    #             'photometryCenterInIndex':(0,0),
    #             'photometryCenterOutIndex':(0,0),
    #             'photometrySideInIndex':(0,0),
    #             'photometrySideInIndexr':(0,0),
    #             'photometrySideOutIndex':(0,0),
    #             # 'sl': (0,0),
    #             'spnnrOff': (0,0),
    #            },
    #  'y_col': 'rDA',
    #  'name': 'no-sl'},
    # {'X_cols': {
    #             'photometryCenterInIndex':(0,0),
    #             'photometryCenterOutIndex':(0,0),
    #             'photometrySideInIndex':(0,0),
    #             'photometrySideInIndexr':(0,0),
    #             'photometrySideOutIndex':(0,0),
    #             'sl': (0,0),
    #             # 'spnnrOff': (0,0),
    #            },
    #  'y_col': 'rDA',
    #  'name': 'no-spnnrOff'},
    # {'X_cols': {
    #             'photometryCenterInIndex':(0,0),
    #             'photometryCenterOutIndex':(0,0),
    #             'photometrySideInIndexAA':(0,0),
    #             'photometrySideInIndexAa':(0,0),
    #             'photometrySideInIndexaA':(0,0),
    #             'photometrySideInIndexaa':(0,0),
    #             'photometrySideInIndexAB':(0,0),
    #             'photometrySideInIndexAb':(0,0),
    #             'photometrySideInIndexaB':(0,0),
    #             'photometrySideInIndexab':(0,0),
    #             'photometrySideOutIndex':(0,0),
    #             'sl': (0,0),
    #             'spnnrOff': (0,0),
    #            },
    #  'y_col': 'rDA',
    #  'name': 'base-words'},

]]

# X_y_pairings_lst += [[

#     {'X_cols': {
#                 'photometryCenterInIndex':(0,0),
#                 'photometryCenterOutIndex':(0,0),
#                 'photometrySideInIndex':(0,0),
#                 'photometrySideInIndexr':(0,0),                
#                 'photometrySideOutIndex':(0,0),
#                 'sl': (0,0),
#                 'spnnrOff': (0,0),
#                },
#      'y_col': 'gDA',
#      'name': 'base-simple'
#      },
#     {'X_cols': {
#                 # 'photometryCenterInIndex':(0,0),
#                 'photometryCenterOutIndex':(0,0),
#                 'photometrySideInIndex':(0,0),
#                 'photometrySideInIndexr':(0,0),
#                 'photometrySideOutIndex':(0,0),
#                 'sl': (0,0),
#                 'spnnrOff': (0,0),
#                },
#      'y_col': 'gDA',
#      'name': 'no-CI'},
#     {'X_cols': {
#                 'photometryCenterInIndex':(0,0),
#                 # 'photometryCenterOutIndex':(0,0),
#                 'photometrySideInIndex':(0,0),
#                 'photometrySideInIndexr':(0,0),
#                 'photometrySideOutIndex':(0,0),
#                 'sl': (0,0),
#                 'spnnrOff': (0,0),
#                },
#      'y_col': 'gDA',
#      'name': 'no-CO'},
#     {'X_cols': {
#                 'photometryCenterInIndex':(0,0),
#                 'photometryCenterOutIndex':(0,0),
#                 # 'photometrySideInIndex':(0,0),
#                 'photometrySideInIndexr':(0,0),
#                 'photometrySideOutIndex':(0,0),
#                 'sl': (0,0),
#                 'spnnrOff': (0,0),
#                },
#      'y_col': 'gDA',
#      'name': 'no-SI'},
#     {'X_cols': {
#                 'photometryCenterInIndex':(0,0),
#                 'photometryCenterOutIndex':(0,0),
#                 'photometrySideInIndex':(0,0),
#                 # 'photometrySideInIndexr':(0,0),
#                 'photometrySideOutIndex':(0,0),
#                 'sl': (0,0),
#                 'spnnrOff': (0,0),
#                },
#      'y_col': 'gDA',
#      'name': 'no-SIr'},
#     {'X_cols': {
#                 'photometryCenterInIndex':(0,0),
#                 'photometryCenterOutIndex':(0,0),
#                 'photometrySideInIndex':(0,0),
#                 'photometrySideInIndexr':(0,0),
#                 # 'photometrySideOutIndex':(0,0),
#                 'sl': (0,0),
#                 'spnnrOff': (0,0),
#                },
#      'y_col': 'gDA',
#      'name': 'no-SO'},
#     {'X_cols': {
#                 'photometryCenterInIndex':(0,0),
#                 'photometryCenterOutIndex':(0,0),
#                 'photometrySideInIndex':(0,0),
#                 'photometrySideInIndexr':(0,0),
#                 'photometrySideOutIndex':(0,0),
#                 # 'sl': (0,0),
#                 'spnnrOff': (0,0),
#                },
#      'y_col': 'gDA',
#      'name': 'no-sl'},
#     {'X_cols': {
#                 'photometryCenterInIndex':(0,0),
#                 'photometryCenterOutIndex':(0,0),
#                 'photometrySideInIndex':(0,0),
#                 'photometrySideInIndexr':(0,0),
#                 'photometrySideOutIndex':(0,0),
#                 'sl': (0,0),
#                 # 'spnnrOff': (0,0),
#                },
#      'y_col': 'gDA',
#      'name': 'no-spnnrOff'},
#     {'X_cols': {
#                 'photometryCenterInIndex':(0,0),
#                 'photometryCenterOutIndex':(0,0),
#                 'photometrySideInIndexAA':(0,0),
#                 'photometrySideInIndexAa':(0,0),
#                 'photometrySideInIndexaA':(0,0),
#                 'photometrySideInIndexaa':(0,0),
#                 'photometrySideInIndexAB':(0,0),
#                 'photometrySideInIndexAb':(0,0),
#                 'photometrySideInIndexaB':(0,0),
#                 'photometrySideInIndexab':(0,0),
#                 'photometrySideOutIndex':(0,0),
#                 'sl': (0,0),
#                 'spnnrOff': (0,0),
#                },
#      'y_col': 'gDA',
#      'name': 'base-words'},

# ]]


plot_width = 2
max_cols_len_lst = [max([len(_['X_cols']) for _ in inner_list]) for inner_list in X_y_pairings_lst]
plot_rows_lst = [_//plot_width + (_%plot_width > 0)*1 for _ in max_cols_len_lst]

drop_cols_basis = [
    'nTrial',
    'cpn', 'cpx',
    'spnnr',
    'spxnr',
    'spnr', 'spxr',

    'photometryCenterInIndex', 'photometryCenterOutIndex',
    'photometrySideInIndexr', 'photometrySideInIndexnr',
    'photometrySideOutIndex', 'spnnrOff',

    'photometrySideInIndexAA', 'photometrySideInIndexAa',
    'photometrySideInIndexaA', 'photometrySideInIndexaa',
    'photometrySideInIndexAB', 'photometrySideInIndexAb',
    'photometrySideInIndexaB', 'photometrySideInIndexab',

    'photometrySideOutIndexAA', 'photometrySideOutIndexAa',
    'photometrySideOutIndexaA', 'photometrySideOutIndexaa',
    'photometrySideOutIndexAB', 'photometrySideOutIndexAb',
    'photometrySideOutIndexaB', 'photometrySideOutIndexab',
    
    'sl',
    'slOff'
]

# create_folder_if_not_exists(dir)

base_folder = '/Users/josh/Documents/Harvard/GLM/sabatinilab-glm/sglm/outputs'

ssave_folder = 'models/ssave'
all_models_folder = 'models/all_models'
all_data_folder = 'models/all_data'
all_reconstruct_folder = 'reports/figures/all_reconstruct'
all_coeffs_folder = 'reports/figures/all_coeffs'
best_reconstruct_folder = 'reports/figures/best_reconstruct'
best_coeffs_npy_folder = 'reports/coeffs/best_coeffs'
best_resids_npy_folder = 'reports/residuals/best_resids'
best_combined_coeffs_folder = 'reports/coeffs/best_combined_coeffs'
best_coeffs_folder = 'reports/figures/best_coeffs'

all_models_folder = 'models'

avg_reconstruct_basename = 'arr'
all_betas_basename = 'betas'
model_c_basename = 'coeffs'
model_i_basename = 'intercept'
tmp_data_basename = 'tmp_data'



score_method = 'r2'

# Select hyper parameters for GLM to use for model selection
# Step 1: Create a dictionary of lists for these relevant keywords...
kwargs_iterations = {
    'alpha': [0],
    'l1_ratio': [0],

    # 'alpha': [0.0, 0.001, 0.01, 0.1, 1.0],
    # 'l1_ratio': [0.0, 0.0001, 0.001, 0.01],
}

# Step 2: Create a dictionary for the fixed keyword arguments that do not require iteration...
kwargs_fixed = {
    'max_iter': 10000,
    'fit_intercept': False
}

# neg_order, pos_order = -14, 14
# folds = 50
# folds = 10
folds = 10
# folds = 1
pholdout = 0.2
pgss = 0.2

# Step 3: Generate iterable list of keyword sets for possible combinations
glm_kwarg_lst = sglm_cv.generate_mult_params(kwargs_iterations, kwargs_fixed)

all_coeff_dfs = []

multi_start = time.time()

for iXyp, X_y_pairings in enumerate(X_y_pairings_lst):

    widest_orders = [{'X_cols': smf.X_cols_dict_to_default(_['X_cols'], neg_order, pos_order),
                    'y_col': _['y_col']} for _ in X_y_pairings]
    widest_orders = smf.xy_pairs_to_widest_orders(widest_orders)

    max_cols_len = max_cols_len_lst[iXyp]
    plot_rows = plot_rows_lst[iXyp]

    for multifile_fit in multifile_fit_list:
        data_folder_join = '_'.join(data_folder.split('/'))

        # prefix = f'{data_folder}-{multifile_fit}-words-recons'
        prefix = f'{data_folder_join}/{multifile_fit}/{base_prefix}_{iXyp}{ft_str}'

        create_folder_if_not_exists(f'{base_folder}/{prefix}')
        create_folder_if_not_exists(f'{base_folder}/{prefix}/{best_coeffs_folder}')
        create_folder_if_not_exists(f'{base_folder}/{prefix}/{best_coeffs_npy_folder}')
        create_folder_if_not_exists(f'{base_folder}/{prefix}/{best_reconstruct_folder}')
        create_folder_if_not_exists(f'{base_folder}/{prefix}/{best_resids_npy_folder}')
        create_folder_if_not_exists(f'{base_folder}/{prefix}/{best_combined_coeffs_folder}')
        create_folder_if_not_exists(f'{base_folder}/{prefix}/{all_models_folder}/coeffs')
        create_folder_if_not_exists(f'{base_folder}/{prefix}/{all_models_folder}/intercepts')
        create_folder_if_not_exists(f'{base_folder}/{prefix}/{all_coeffs_folder}')
        create_folder_if_not_exists(f'{base_folder}/{prefix}/{all_reconstruct_folder}')
        create_folder_if_not_exists(f'{base_folder}/{prefix}/{best_reconstruct_folder}')

        # Load Signal Data
        signal_files = []
        mouse_names = []
        for wt in wt_used:
            addl_sig_files = glob.glob(f'../../data/interim/{data_folder}/GLM_SIGNALS_INTERIM_{wt}_*')
            signal_files += addl_sig_files
            mouse_names += [wt] * len(addl_sig_files)
            
        if multifile_fit == 'all':
            combo_dfs, X_cols_sftd, _ = smf.multi_file_analysis_prep(signal_files, widest_orders,)
            combo_fns = ['_'.join(wt_used).replace('WT', '').replace('S', '')]
            mouse_names = combo_fns
        elif multifile_fit == 'by_mouse':
            combo_dfs = []
            X_cols_sftd_lst = []
            combo_fns = []
            mouse_names_2 = []
            for mouse_id in wt_used:
                mouse_id_files = [_ for _ in signal_files if mouse_id in _]
                mouse_names_2 += [mouse_id]
                print('mouse_id', mouse_id)
                combo_dfs_tmp, X_cols_sftd_tmp, _ = smf.multi_file_analysis_prep(mouse_id_files, widest_orders,)
                combo_dfs += combo_dfs_tmp
                X_cols_sftd_lst.append(X_cols_sftd_tmp)
                combo_fns.append(mouse_id)
                
            for xcsl in X_cols_sftd_lst:
                if xcsl != X_cols_sftd_lst[0]:
                    raise ValueError('X_cols_sftd_lst should contain the same elements for every entry')
            mouse_names = mouse_names_2
            
            X_cols_sftd = X_cols_sftd_lst[0]

        elif multifile_fit == 'single':
            combo_dfs, X_cols_sftd, combo_fns = smf.single_file_analysis_prep(signal_files, widest_orders,)
            mouse_names = mouse_names
        else:
            raise ValueError('multifile_fit must be "all", "single", or "by_mouse"')

        # print(combo_dfs)

        start = time.time()

        results_dict = {}

        for file_num in range(len(combo_dfs)):


            # Load Table Data
            signal_df = combo_dfs[file_num].copy()
            signal_fn = combo_fns[file_num]
            mouse_id = mouse_names[file_num]

            fn = signal_fn.split('.')[0].split('/')[-1]

            print(mouse_names, file_num, mouse_id)

            dfrel_basis = signal_df.reset_index(drop=False).copy()
            print('dfrel_basis', dfrel_basis.shape)

            signal_filename_out = 'FINAL_' + signal_fn.split('/')[-1].replace('GLM_SIGNALS_INTERIM_', '').replace('txt', 'csv') + '.csv'
            print(signal_filename_out)

            dfrel_basis['mouse_id'] = mouse_id
            dfrel_basis.set_index(['file_num'], append=True, inplace=True)


            dfrr_cols = ['nTrial', 'nEndTrial', 'wi_trial_keep', 'gDA', 'gACH', 'rDA',
            'diffTrialNums', 'dupe',
            'photometryCenterInIndex', 'photometryCenterOutIndex',
            'photometrySideInIndexr', 'photometrySideInIndexnr',
            'photometrySideOutIndex', 'spnnrOff', 'sl',

            'photometrySideInIndexAA', 'photometrySideInIndexAa',
            'photometrySideInIndexaA','photometrySideInIndexaa',
            'photometrySideInIndexAB', 'photometrySideInIndexAb',
            'photometrySideInIndexaB','photometrySideInIndexab',

            ]
            

            # dfrel_resids = dfrel_basis[['nTrial', 'wi_trial_keep', 'gDA', 'gACH', 'rDA']].copy()
            dfrel_resids = dfrel_basis[dfrr_cols].copy()

            holdout_score_rnd = None

            dfrel_resids_setup = pd.DataFrame()
            dfrel_resids_holdout = pd.DataFrame()

            for irun in range(num_runs):
                
                if fix_training:
                    full_drop_basis = []
                    y_col_lst = []
                    for X_y_dct in X_y_pairings:
                        X_cols_basis = X_y_dct['X_cols']
                        y_col = X_y_dct['y_col']
                        X_cols_sftd_basis = bf.col_shift_bounds_dict_to_col_list(X_cols_basis, X_cols_sftd)
                        full_drop_basis += X_cols_sftd_basis
                        
                        if y_col[-len('_resid'):] != '_resid':
                            y_col_lst += [y_col]
                    full_drop_basis = sorted(list(set(full_drop_basis)))
                    y_col_drop_basis = sorted(list(set(y_col_lst)))
                    full_drop_basis = sorted(list(set(drop_cols_basis + full_drop_basis + y_col_drop_basis)))

                    print('-',y_col_lst)

                    dfrel_ft = dfrel_basis.copy()
                    # print('full_drop_basis', full_drop_basis)
                    # print('y_col_drop_basis', y_col_drop_basis)
                    # print('dfrel_ft', len(dfrel_ft))
                    srs_a = (dfrel_ft[full_drop_basis].isna().sum(axis=1))
                    srs_b = (dfrel_ft[y_col_drop_basis] == 0).sum(axis=1)
                    # print('srs_a', srs_a[srs_a > 0])
                    # print('srs_b', srs_b[srs_b > 0])
                    
                    dfrel_ft = dfrel_ft[(dfrel_ft[full_drop_basis].isna().sum(axis=1) == 0)&((dfrel_ft[y_col_drop_basis] == 0).sum(axis=1) == 0)]
                    if dfrel_ft.shape[0] == 0:
                        print(f'No datapoints found for non-NaN dropcols & non-zero ycols for fixed_training: {prefix}_{fn}')
                        continue
                    
                    dfrel_ft_setup, dfrel_ft_holdout, holdout = models.split_data.holdout_splits(dfrel_ft, id_cols=['nTrial'], perc_holdout=pholdout)
                    dfrel_ft_setup, dfrel_ft_holdout = dfrel_ft_setup.copy(), dfrel_ft_holdout.copy()

                    dfrel_resids_setup = dfrel_ft_setup[dfrr_cols].copy()
                    dfrel_resids_holdout = dfrel_ft_holdout[dfrr_cols].copy()


                
                for iXyd, X_y_dct in enumerate(X_y_pairings):
                    dfrel = dfrel_basis.copy()
                    X_cols_basis = X_y_dct['X_cols']
                    y_col = X_y_dct['y_col']
                    name = X_y_dct['name']
                    X_cols_sftd_basis = bf.col_shift_bounds_dict_to_col_list(X_cols_basis, X_cols_sftd)

                    
                    run_id = f'{fn}_{y_col}_{iXyd}_run_num={irun}' if num_runs > 1 else f'{fn}_{y_col}_{iXyd}'

                    # print('dfrel.columns', list(dfrel.columns))
                    #### Revise line to reduce length / number of checks

                    dfrel = dfrel[(dfrel[drop_cols_basis + X_cols_sftd_basis + [y_col]].isna().sum(axis=1) == 0)&(dfrel[y_col] != 0)]
                    if dfrel.shape[0] == 0:
                        print(f'No datapoints found for non-NaN dropcols & non-zero ycols for run id: {run_id}.')
                        continue
                    
                    if fix_training:
                        assert np.all(dfrel_ft.fillna(0) == dfrel.fillna(0))
                        dfrel = dfrel_ft.copy()
                        dfrel_setup, dfrel_holdout = dfrel_ft_setup.copy(), dfrel_ft_holdout.copy()
                    else:
                        dfrel_setup, dfrel_holdout, holdout = models.split_data.holdout_splits(dfrel, id_cols=['nTrial'], perc_holdout=pholdout)
                        dfrel_setup, dfrel_holdout = dfrel_setup.copy(), dfrel_holdout.copy()

                    
                    print('dfr.shape', dfrel.shape)

                    print(f'> Included file_nums for y_col {y_col}:', list(dfrel.reset_index()['file_num'].unique()))
                    

                    # # kfold_cv_idx = models.split_data.cv_idx_by_trial_id(dfrel_setup, trial_id_columns=['nTrial'], num_folds=folds, test_size=pgss)
                    # if len(glm_kwarg_lst) > 1:
                    #     # Generate cross-validation (technically, group / shuffle split) sets for training / model selection
                    #     kfold_cv_idx = models.split_data.cv_idx_by_trial_id(dfrel_setup, trial_id_columns=['nTrial'], num_folds=folds, test_size=pgss)
                    #     print('size>1:',kfold_cv_idx)
                    # else:
                    #     kfold_cv_idx = models.split_data.cv_idx_by_trial_id(dfrel_setup, trial_id_columns=['nTrial'], num_folds=1, test_size=pgss)
                    #     print('size=1:',kfold_cv_idx)
                    # kfold_cv_idx = models.split_data.cv_idx_by_trial_id(dfrel_setup, trial_id_columns=['nTrial'], num_folds=folds, test_size=pgss)



                    prediction_X_cols = [_ for _ in X_cols_basis if _ not in ['nTrial']]
                    prediction_X_cols_sftd = [_ for _ in X_cols_sftd_basis if _ not in ['nTrial']]
                    
                    X_witi, y_witi, X_noiti, y_noiti = train_model.get_xy_all_noniti(dfrel, prediction_X_cols_sftd, y_col, noniticol='wi_trial_keep')
                    X_setup_witi, y_setup_witi, X_setup_noiti, y_setup_noiti = train_model.get_xy_all_noniti(dfrel_setup, prediction_X_cols_sftd, y_col, noniticol='wi_trial_keep')
                    X_holdout_witi, y_holdout_witi, X_holdout_noiti, y_holdout_noiti = train_model.get_xy_all_noniti(dfrel_holdout, prediction_X_cols_sftd,
                                                                                                                    y_col, noniticol='wi_trial_keep')


                    dfrel_witi, _, dfrel_noiti, _ = train_model.get_xy_all_noniti(dfrel, list(dfrel.columns), y_col, noniticol='wi_trial_keep')
                    dfrel_setup_witi, _, dfrel_setup_noiti, _ = train_model.get_xy_all_noniti(dfrel_setup, list(dfrel_setup.columns), y_col, noniticol='wi_trial_keep')
                    dfrel_holdout_witi, _, dfrel_holdout_noiti, _ = train_model.get_xy_all_noniti(dfrel_holdout, list(dfrel_holdout.columns), y_col, noniticol='wi_trial_keep')


                    # Generate cross-validation (technically, group / shuffle split) sets for training / model selection
                    kfold_cv_idx = models.split_data.cv_idx_by_trial_id(dfrel_setup_noiti, trial_id_columns=['nTrial'], num_folds=folds, test_size=pgss)

                    # X_all_witi, y_all_witi, X_all_noiti, y_all_noiti = train_model.get_xy_all_noniti(dfrel, prediction_X_cols_sftd,
                    #                                                                                  y_col, noniticol='wi_trial_keep')

                    print('X_setup.columns:', X_setup_noiti.columns)

                    best_score, best_score_std, best_params, best_model, cv_results = models.sglm_cv.simple_cv_fit(X_setup_noiti, y_setup_noiti, kfold_cv_idx, glm_kwarg_lst, model_type='Normal',
                                                                                                                verbose=0, score_method=score_method)
                    
                    
                    
                    
                    
                    
                    
                    eval.print_best_model_info(X_setup_noiti, best_score, best_params, best_model, start)
                    glm, holdout_score, holdout_neg_mse_score = eval.training_fit_holdout_score(X_setup_noiti, y_setup_noiti, X_holdout_noiti, y_holdout_noiti, best_params)


                    dfrel['pred'] = glm.predict(X_witi)
                    dfrel_setup['pred'] = glm.predict(X_setup_witi)
                    dfrel_holdout['pred'] = glm.predict(X_holdout_witi)

                    # Collect
                    results_dict[f'{run_id}'] = {'holdout_score':holdout_score,
                                                'holdout_neg_mse_score':holdout_neg_mse_score,
                                                'best_score':best_score,
                                                'best_params':best_params,
                                                'all_models':sorted([(_['cv_R2_score'],
                                                                        _['cv_mse_score'],
                                                                        eval.calc_l1(_['cv_coefs']),
                                                                        eval.calc_l2(_['cv_coefs']),
                                                                        _['glm_kwargs']) for _ in cv_results['full_cv_results']], key=lambda x: -x[0])
                                                }
                    print(f'Holdout Score: {holdout_score}')

                    # Generate and save plots of the beta coefficients
                    X_cols_plot = prediction_X_cols
                    X_cols_sftd_plot = prediction_X_cols_sftd
                    

                    holdout_score_rnd = np.round(holdout_score, 4)
                    best_beta_fn = f'{base_folder}/{prefix}/{best_coeffs_folder}/{run_id}_best_{all_betas_basename}_R2_{holdout_score_rnd}.png'

                    tr_score = dfrel_setup

                    setup_df = pd.DataFrame(np.concatenate([np.array([glm.intercept_]), glm.coef_], axis=0).reshape(1,-1),
                                index=[run_id], columns=['int']+prediction_X_cols_sftd)
                    setup_df['mouse_id'] = mouse_id
                    setup_df['channel_name'] = y_col + '_' + str(iXyd) + f'_run_num={irun}' if num_runs > 1 else y_col + '_' + str(iXyd)

                    print(len(cv_results), cv_results.keys())

                    setup_df['name'] = name

                    # Only get R^2 values if only a single model fit
                    if len(cv_results['full_cv_results']) == 1:

                        assert holdout_neg_mse_score == glm.neg_mse_score(X_holdout_noiti, y_holdout_noiti)

                        setup_df['mse_tr'] = -glm.neg_mse_score(X_setup_noiti, y_setup_noiti)
                        setup_df['mse_cv'] = cv_results['full_cv_results'][0]['cv_mse_score']
                        setup_df['mse_te'] = -glm.neg_mse_score(X_holdout_noiti, y_holdout_noiti) #-holdout_neg_mse_score


                        setup_df['r2_tr'] = glm.r2_score(X_setup_noiti, y_setup_noiti)
                        setup_df['r2_cv'] = cv_results['full_cv_results'][0]['cv_R2_score']
                        setup_df['r2_te'] = glm.r2_score(X_holdout_noiti, y_holdout_noiti) #-holdout_neg_mse_score

                        # setup_df['tr_num_r'] = dfrel_setup
                        # setup_df['tr_num_nr'] = dfrel_setup
                        # setup_df['cv_num_r'] = dfrel_setup
                        # setup_df['cv_num_nr'] = dfrel_setup
                        # setup_df['te_num_r'] = dfrel_setup
                        # setup_df['te_num_nr'] = dfrel_setup
                        # print('Here')

                    else: 
                        setup_df['mse_tr'] = 0.0
                        setup_df['mse_cv'] = 0.0
                        setup_df['mse_te'] = 0.0

                        setup_df['r2_tr'] = 0.0
                        setup_df['r2_cv'] = 0.0
                        setup_df['r2_te'] = 0.0

                    multi_end = time.time()
                    setup_df['timestamp'] = str(multi_end - multi_start) + ' s'

                    setup_df = setup_df.set_index(['mouse_id', 'channel_name', 'name', 'mse_tr', 'mse_cv', 'mse_te', 'r2_tr', 'r2_cv', 'r2_te', 'timestamp'], append=True)

                    tot_trials_setup = dfrel_setup_noiti['photometrySideInIndex'].sum()
                    tot_trials_holdout = dfrel_holdout_noiti['photometrySideInIndex'].sum()

                    setup_df['AA_cnt_tr'] = dfrel_setup_noiti['photometrySideInIndexAA'].sum()/tot_trials_setup
                    setup_df['Aa_cnt_tr'] = dfrel_setup_noiti['photometrySideInIndexAa'].sum()/tot_trials_setup
                    setup_df['aA_cnt_tr'] = dfrel_setup_noiti['photometrySideInIndexaA'].sum()/tot_trials_setup
                    setup_df['aa_cnt_tr'] = dfrel_setup_noiti['photometrySideInIndexaa'].sum()/tot_trials_setup
                    setup_df['AB_cnt_tr'] = dfrel_setup_noiti['photometrySideInIndexAB'].sum()/tot_trials_setup
                    setup_df['Ab_cnt_tr'] = dfrel_setup_noiti['photometrySideInIndexAb'].sum()/tot_trials_setup
                    setup_df['aB_cnt_tr'] = dfrel_setup_noiti['photometrySideInIndexaB'].sum()/tot_trials_setup
                    setup_df['ab_cnt_tr'] = dfrel_setup_noiti['photometrySideInIndexab'].sum()/tot_trials_setup

                    setup_df['AA_cnt_te'] = dfrel_holdout_noiti['photometrySideInIndexAA'].sum()/tot_trials_holdout
                    setup_df['Aa_cnt_te'] = dfrel_holdout_noiti['photometrySideInIndexAa'].sum()/tot_trials_holdout
                    setup_df['aA_cnt_te'] = dfrel_holdout_noiti['photometrySideInIndexaA'].sum()/tot_trials_holdout
                    setup_df['aa_cnt_te'] = dfrel_holdout_noiti['photometrySideInIndexaa'].sum()/tot_trials_holdout
                    setup_df['AB_cnt_te'] = dfrel_holdout_noiti['photometrySideInIndexAB'].sum()/tot_trials_holdout
                    setup_df['Ab_cnt_te'] = dfrel_holdout_noiti['photometrySideInIndexAb'].sum()/tot_trials_holdout
                    setup_df['aB_cnt_te'] = dfrel_holdout_noiti['photometrySideInIndexaB'].sum()/tot_trials_holdout
                    setup_df['ab_cnt_te'] = dfrel_holdout_noiti['photometrySideInIndexab'].sum()/tot_trials_holdout

                    setup_df.to_csv(f'{base_folder}/{prefix}/{best_coeffs_npy_folder}/{run_id}_best_coeffs_R2_{holdout_score_rnd}.csv', index=True, header=True)
                    all_coeff_dfs.append(setup_df)


                    # visualize.plot_all_beta_coefs(glm.coef_, X_cols_plot,
                    #                                 X_cols_sftd_plot,
                    #                                 # plot_width=4,
                    #                                 plot_width=plot_width,
                    #                                 plot_rows=plot_rows,
                    #                                 y_lims=(-3.0, 3.0),
                    #                                 binsize=54,
                    #                                 filename=best_beta_fn,
                    #                                 plot_name=f'Best Coeffs - {run_id} — {best_params}'
                    #                                 )
                    

                    # best_rcnstrct_fn = f'{base_folder}/{prefix}/{best_reconstruct_folder}/{run_id}_best_{avg_reconstruct_basename}_R2_{holdout_score_rnd}.png'


                    # visualize.plot_avg_reconstructions_v2(dfrel_holdout,
                    #                             alignment_col_lst=[ #'cpn', 'spnr', 'spnnr',
                    #                                                 # 'photometryCenterInIndex', #'photometryCenterOutIndex',
                    #                                                 'photometrySideInIndexr', 'photometrySideInIndexnr',
                    #                                                 'photometrySideOutIndexr', 'photometrySideOutIndexnr',

                    #                                                 'photometrySideInIndexAA', 'photometrySideInIndexAa',
                    #                                                 'photometrySideInIndexaA','photometrySideInIndexaa',
                    #                                                 'photometrySideInIndexAB', 'photometrySideInIndexAb',
                    #                                                 'photometrySideInIndexaB','photometrySideInIndexab',

                    #                                                 'photometryCenterInIndex', #'photometryCenterOutIndex',

                    #                                                 'photometrySideInIndex',

                    #                                                 # 'photometrySideOutIndexAA', 'photometrySideOutIndexAa',
                    #                                                 # 'photometrySideOutIndexaA', 'photometrySideOutIndexaa',
                    #                                                 # 'photometrySideOutIndexAB', 'photometrySideOutIndexAb',
                    #                                                 # 'photometrySideOutIndexaB', 'photometrySideOutIndexab',
                    #                                         ],
                                            
                    #                             channel=y_col,
                    #                             binsize = 54,
                    #                             # plot_width=4,
                    #                             plot_width=2,
                    #                             min_time = -20,
                    #                             max_time = 30,
                    #                             min_signal = -3.0,
                    #                             max_signal = 3.0,
                    #                             file_name=best_rcnstrct_fn,
                    #                             title=f'Best Average Reconstruction - {run_id} — {best_params}'
                    #                             )

                    # best_rcnstrct_fn = f'{base_folder}/{prefix}/{best_reconstruct_folder}/{run_id}_tr+ho_best_{avg_reconstruct_basename}_R2_{holdout_score_rnd}.png'

                    # visualize.plot_avg_reconstructions_v2(dfrel,
                    #                             alignment_col_lst=[ #'cpn', 'spnr', 'spnnr',
                    #                                                 # 'photometryCenterInIndex', #'photometryCenterOutIndex',
                    #                                                 'photometrySideInIndexr', 'photometrySideInIndexnr',
                    #                                                 'photometrySideOutIndexr', 'photometrySideOutIndexnr',

                    #                                                 'photometrySideInIndexAA', 'photometrySideInIndexAa',
                    #                                                 'photometrySideInIndexaA','photometrySideInIndexaa',
                    #                                                 'photometrySideInIndexAB', 'photometrySideInIndexAb',
                    #                                                 'photometrySideInIndexaB','photometrySideInIndexab',

                    #                                                 'photometryCenterInIndex', #'photometryCenterOutIndex',

                    #                                                 'photometrySideInIndex',

                    #                                                 # 'photometrySideOutIndexAA', 'photometrySideOutIndexAa',
                    #                                                 # 'photometrySideOutIndexaA', 'photometrySideOutIndexaa',
                    #                                                 # 'photometrySideOutIndexAB', 'photometrySideOutIndexAb',
                    #                                                 # 'photometrySideOutIndexaB', 'photometrySideOutIndexab',
                    #                                         ],
                                            
                    #                             channel=y_col,
                    #                             binsize = 54,
                    #                             # plot_width=4,
                    #                             plot_width=2,
                    #                             min_time = -20,
                    #                             max_time = 30,
                    #                             min_signal = -3.0,
                    #                             max_signal = 3.0,
                    #                             file_name=best_rcnstrct_fn,
                    #                             title=f'Best Average Reconstruction — Training + Holdout - {run_id} — {best_params}'
                    #                             )


                    # dfrel_resids = dfrel[['file_num', 'nTrial', 'wi_trial_keep', 'gDA', 'gACH', 'rDA', 'pred']].copy()
                    # dfrel_resids['mouse_id'] = mouse_id
                    # dfrel_resids['channel_name'] = y_col

                    # dfrel_resids.set_index(['mouse_id', 'channel_name', 'file_num', 'nTrial'], inplace=True)
                    # dfrel_resids.to_csv(f'{base_folder}/{prefix}/{best_resids_npy_folder}/{run_id}_best_resids_R2_{holdout_score_rnd}.csv', index=True, header=True)

                    dfrel_basis[y_col + '_resid'] = (dfrel_basis[y_col] - dfrel['pred']).values
                    if fix_training:
                        dfrel_ft[y_col + '_resid'] = (dfrel_ft[y_col] - dfrel['pred']).values
                        dfrel_ft_setup[y_col + '_resid'] = (dfrel_ft_setup[y_col] - dfrel_setup['pred']).values
                        dfrel_ft_holdout[y_col + '_resid'] = (dfrel_ft_holdout[y_col] - dfrel_holdout['pred']).values
                    
                    # print(dfrel_resids)
                    # print(dfrel[['pred']])
                    # dfrel.set_index(['file_num_inx'], append=True, inplace=True)

                    pred_col_name = f'pred_paramsNum={iXyd}_{y_col}_run_num={irun}' if num_runs > 1 else f'pred_paramsNum={iXyd}_{y_col}'

                    dfrel_resids[pred_col_name] = glm.predict(dfrel_basis[prediction_X_cols_sftd])
                    
                    if len(dfrel_resids_setup):
                        dfrel_resids_setup[pred_col_name] = glm.predict(dfrel_ft[~holdout][prediction_X_cols_sftd])
                    if len(dfrel_resids_holdout):
                        dfrel_resids_holdout[pred_col_name] = glm.predict(dfrel_ft[holdout][prediction_X_cols_sftd])


                    # for fitted_model_dict in (cv_results['full_cv_results']):
                    #     fitted_model = fitted_model_dict['model']
                    #     kwarg_info = "_".join([f"{_k}_{fitted_model_dict['glm_kwargs'][_k]}" for _k in fitted_model_dict["glm_kwargs"]])

                    #     model_coef = fitted_model.coef_
                    #     model_intercept = fitted_model.intercept_

                    #     std_name = f'{run_id}_{kwarg_info}'
                    #     np.save(f'{base_folder}/{prefix}/{all_models_folder}/coeffs/{std_name}_{model_c_basename}.npy', model_coef)
                    #     np.save(f'{base_folder}/{prefix}/{all_models_folder}/intercepts/{std_name}_{model_i_basename}.npy', model_intercept)
                        
                    #     tmp_holdout_score = fitted_model.r2_score(X_holdout_noiti, y_holdout_noiti)
                    #     holdout_score_rnd = np.round(tmp_holdout_score, 4)
                        

                    #     visualize.plot_all_beta_coefs(fitted_model.coef_, X_cols_plot,
                    #                                     X_cols_sftd_plot,
                    #                                     plot_width=4,
                    #                                     y_lims=(-3.0, 3.0),
                    #                                     # filename=f'{fn}_coeffs.png',
                    #                                     binsize=54,
                    #                                     filename=f'{base_folder}/{prefix}/{all_coeffs_folder}/{std_name}_{all_betas_basename}_R2_{holdout_score_rnd}.png',
                    #                                     plot_name=f'Coeffs by Timeshift - {run_id} — {kwarg_info}'
                    #                                     # plot_name=f'{fn} — {y_col} — {kwarg_info}'
                    #                                     )


                    #     visualize.plot_avg_reconstructions_v2(dfrel_holdout,
                    #     # visualize.plot_avg_reconstructions_v2(dfrel,
                    #                                     channel=y_col,
                    #                                     plot_width=4,
                    #                                     binsize = 54,
                    #                                     min_time = -20,
                    #                                     max_time = 30,
                    #                                     min_signal = -2.5,
                    #                                     max_signal = 2.5,
                    #                                     file_name=f'{base_folder}/{prefix}/{all_reconstruct_folder}/{std_name}_{avg_reconstruct_basename}_R2_{holdout_score_rnd}.png',
                    #                                     title=f'Average Reconstruction - {run_id} — {kwarg_info}'
                    #                                 )
                
                if len(dfrel_resids) != 0 and holdout_score_rnd is not None:
                    # dfrel_resids.set_index(['nTrial'], append=True, inplace=True)
                    # dfrel_resids.to_csv(f'{base_folder}/{prefix}/{best_resids_npy_folder}/{fn}_best_resids_R2_{holdout_score_rnd}_all.csv', index=True, header=True)
                    dfrel_resids.set_index(['nTrial'], append=True).to_csv(f'{base_folder}/{prefix}/{best_resids_npy_folder}/{fn}_best_resids_R2_{holdout_score_rnd}_all.csv', index=True, header=True)                
                if len(dfrel_resids_setup) != 0 and holdout_score_rnd is not None:
                    # dfrel_resids_setup.set_index(['nTrial'], append=True, inplace=True)
                    # dfrel_resids_setup.to_csv(f'{base_folder}/{prefix}/{best_resids_npy_folder}/{fn}_best_resids_R2_{holdout_score_rnd}_stp.csv', index=True, header=True)
                    dfrel_resids_setup.set_index(['nTrial'], append=True).to_csv(f'{base_folder}/{prefix}/{best_resids_npy_folder}/{fn}_best_resids_R2_{holdout_score_rnd}_stp.csv', index=True, header=True)
                if len(dfrel_resids_holdout) != 0 and holdout_score_rnd is not None:
                    # dfrel_resids_holdout.set_index(['nTrial'], append=True, inplace=True)
                    # dfrel_resids_holdout.to_csv(f'{base_folder}/{prefix}/{best_resids_npy_folder}/{fn}_best_resids_R2_{holdout_score_rnd}_ho.csv', index=True, header=True)
                    dfrel_resids_holdout.set_index(['nTrial'], append=True).to_csv(f'{base_folder}/{prefix}/{best_resids_npy_folder}/{fn}_best_resids_R2_{holdout_score_rnd}_ho.csv', index=True, header=True)

    combined_best_coeffs = pd.concat(all_coeff_dfs, axis=0)
    combined_best_coeffs.to_csv(f'{base_folder}/{prefix}/{best_combined_coeffs_folder}/best_coeffs_combo.csv', index=True, header=True)
# Out:
# Created directory: /Users/josh/Documents/Harvard/GLM/sabatinilab-glm/sglm/outputs/fig1/all/nw-anlysis_0-ft/
# Created directory: /Users/josh/Documents/Harvard/GLM/sabatinilab-glm/sglm/outputs/fig1/all/nw-anlysis_0-ft/reports/figures/best_coeffs/
# Created directory: /Users/josh/Documents/Harvard/GLM/sabatinilab-glm/sglm/outputs/fig1/all/nw-anlysis_0-ft/reports/coeffs/best_coeffs/
# Created directory: /Users/josh/Documents/Harvard/GLM/sabatinilab-glm/sglm/outputs/fig1/all/nw-anlysis_0-ft/reports/figures/best_reconstruct/
# Created directory: /Users/josh/Documents/Harvard/GLM/sabatinilab-glm/sglm/outputs/fig1/all/nw-anlysis_0-ft/reports/residuals/best_resids/
# Created directory: /Users/josh/Documents/Harvard/GLM/sabatinilab-glm/sglm/outputs/fig1/all/nw-anlysis_0-ft/reports/coeffs/best_combined_coeffs/
# Created directory: /Users/josh/Documents/Harvard/GLM/sabatinilab-glm/sglm/outputs/fig1/all/nw-anlysis_0-ft/models/coeffs/
# Created directory: /Users/josh/Documents/Harvard/GLM/sabatinilab-glm/sglm/outputs/fig1/all/nw-anlysis_0-ft/models/intercepts/
# Created directory: /Users/josh/Documents/Harvard/GLM/sabatinilab-glm/sglm/outputs/fig1/all/nw-anlysis_0-ft/reports/figures/all_coeffs/
# Created directory: /Users/josh/Documents/Harvard/GLM/sabatinilab-glm/sglm/outputs/fig1/all/nw-anlysis_0-ft/reports/figures/all_reconstruct/
# ['63_64'] 0 63_64
# dfrel_basis (273339, 388)
# FINAL_63_64.csv
# - ['gACH', 'gACH']
# dfr.shape (273339, 388)
# > Included file_nums for y_col gACH: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# X_setup.columns: Index(['photometryCenterInIndex_-20', 'photometryCenterInIndex_-19',
#        'photometryCenterInIndex_-18', 'photometryCenterInIndex_-17',
#        'photometryCenterInIndex_-16', 'photometryCenterInIndex_-15',
#        'photometryCenterInIndex_-14', 'photometryCenterInIndex_-13',
#        'photometryCenterInIndex_-12', 'photometryCenterInIndex_-11',
#        ...
#        'spnnrOff_11', 'spnnrOff_12', 'spnnrOff_13', 'spnnrOff_14',
#        'spnnrOff_15', 'spnnrOff_16', 'spnnrOff_17', 'spnnrOff_18',
#        'spnnrOff_19', 'spnnrOff_20'],
#       dtype='object', length=287)
# PCA fit in 7.3347249031066895 seconds
# > PCA-based Model fit in 6.644493818283081 seconds
# > PCA GLM Built in 14.991819143295288 seconds
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Running multi
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# > cv_mean_score_train: 0.24071286010656562
# > cv_R2_score: 0.23724499017585465
# > cv_mean_score: 0.2373159759437648
# Running multi
# Multirun queue completed
#
# ---
#
# Best Score: 0.23724499017585465
# Best Params: {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Best Model: <sglm.models.sglm.GLM object at 0x7fd6a37bf400>
# Best Model — Intercept: 0.0
# Overall RunTime: 102.23722410202026
#
# Holdout Score: 0.2335317376677628
# 5 dict_keys(['best_score', 'best_score_std', 'best_params', 'best_model', 'full_cv_results'])
# dfr.shape (273339, 389)
# > Included file_nums for y_col gACH: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# X_setup.columns: Index(['photometryCenterOutIndex_-20', 'photometryCenterOutIndex_-19',
#        'photometryCenterOutIndex_-18', 'photometryCenterOutIndex_-17',
#        'photometryCenterOutIndex_-16', 'photometryCenterOutIndex_-15',
#        'photometryCenterOutIndex_-14', 'photometryCenterOutIndex_-13',
#        'photometryCenterOutIndex_-12', 'photometryCenterOutIndex_-11',
#        ...
#        'spnnrOff_11', 'spnnrOff_12', 'spnnrOff_13', 'spnnrOff_14',
#        'spnnrOff_15', 'spnnrOff_16', 'spnnrOff_17', 'spnnrOff_18',
#        'spnnrOff_19', 'spnnrOff_20'],
#       dtype='object', length=246)
# PCA fit in 2.3340537548065186 seconds
# > PCA-based Model fit in 2.164497137069702 seconds
# > PCA GLM Built in 4.87765908241272 seconds
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Running multi
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# > cv_mean_score_train: 0.23825263106205244
# > cv_R2_score: 0.23787653107149176
# > cv_mean_score: 0.23785398052930823
# Running multi
# Multirun queue completed
#
# ---
#
# Best Score: 0.23787653107149176
# Best Params: {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Best Model: <sglm.models.sglm.GLM object at 0x7fd6a37bfac0>
# Best Model — Intercept: 0.0
# Overall RunTime: 172.88215589523315
#
# Holdout Score: 0.2314737819125905
# 5 dict_keys(['best_score', 'best_score_std', 'best_params', 'best_model', 'full_cv_results'])
# - ['gACH', 'gACH']
# dfr.shape (273339, 389)
# > Included file_nums for y_col gACH: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# X_setup.columns: Index(['photometryCenterInIndex_-20', 'photometryCenterInIndex_-19',
#        'photometryCenterInIndex_-18', 'photometryCenterInIndex_-17',
#        'photometryCenterInIndex_-16', 'photometryCenterInIndex_-15',
#        'photometryCenterInIndex_-14', 'photometryCenterInIndex_-13',
#        'photometryCenterInIndex_-12', 'photometryCenterInIndex_-11',
#        ...
#        'spnnrOff_11', 'spnnrOff_12', 'spnnrOff_13', 'spnnrOff_14',
#        'spnnrOff_15', 'spnnrOff_16', 'spnnrOff_17', 'spnnrOff_18',
#        'spnnrOff_19', 'spnnrOff_20'],
#       dtype='object', length=287)
# PCA fit in 17.57534098625183 seconds
# > PCA-based Model fit in 3.4783499240875244 seconds
# > PCA GLM Built in 21.940614223480225 seconds
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Running multi
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# > cv_mean_score_train: 0.23901207843326774
# > cv_R2_score: 0.23847520615923756
# > cv_mean_score: 0.23851095391755436
# Running multi
# Multirun queue completed
#
# ---
#
# Best Score: 0.23847520615923756
# Best Params: {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Best Model: <sglm.models.sglm.GLM object at 0x7fd6a37bfe20>
# Best Model — Intercept: 0.0
# Overall RunTime: 330.93616008758545
#
# Holdout Score: 0.23791544265201503
# 5 dict_keys(['best_score', 'best_score_std', 'best_params', 'best_model', 'full_cv_results'])
# dfr.shape (273339, 389)
# > Included file_nums for y_col gACH: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# X_setup.columns: Index(['photometryCenterOutIndex_-20', 'photometryCenterOutIndex_-19',
#        'photometryCenterOutIndex_-18', 'photometryCenterOutIndex_-17',
#        'photometryCenterOutIndex_-16', 'photometryCenterOutIndex_-15',
#        'photometryCenterOutIndex_-14', 'photometryCenterOutIndex_-13',
#        'photometryCenterOutIndex_-12', 'photometryCenterOutIndex_-11',
#        ...
#        'spnnrOff_11', 'spnnrOff_12', 'spnnrOff_13', 'spnnrOff_14',
#        'spnnrOff_15', 'spnnrOff_16', 'spnnrOff_17', 'spnnrOff_18',
#        'spnnrOff_19', 'spnnrOff_20'],
#       dtype='object', length=246)
# PCA fit in 2.7849581241607666 seconds
# > PCA-based Model fit in 2.4650402069091797 seconds
# > PCA GLM Built in 5.735074043273926 seconds
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Running multi
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# > cv_mean_score_train: 0.2368911713833377
# > cv_R2_score: 0.2373963335647461
# > cv_mean_score: 0.23747183162390068
# Running multi
# Multirun queue completed
#
# ---
#
# Best Score: 0.2373963335647461
# Best Params: {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Best Model: <sglm.models.sglm.GLM object at 0x7fd6383e5e50>
# Best Model — Intercept: 0.0
# Overall RunTime: 401.71260690689087
#
# Holdout Score: 0.23641861475333537
# 5 dict_keys(['best_score', 'best_score_std', 'best_params', 'best_model', 'full_cv_results'])
# - ['gACH', 'gACH']
# dfr.shape (273339, 389)
# > Included file_nums for y_col gACH: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# X_setup.columns: Index(['photometryCenterInIndex_-20', 'photometryCenterInIndex_-19',
#        'photometryCenterInIndex_-18', 'photometryCenterInIndex_-17',
#        'photometryCenterInIndex_-16', 'photometryCenterInIndex_-15',
#        'photometryCenterInIndex_-14', 'photometryCenterInIndex_-13',
#        'photometryCenterInIndex_-12', 'photometryCenterInIndex_-11',
#        ...
#        'spnnrOff_11', 'spnnrOff_12', 'spnnrOff_13', 'spnnrOff_14',
#        'spnnrOff_15', 'spnnrOff_16', 'spnnrOff_17', 'spnnrOff_18',
#        'spnnrOff_19', 'spnnrOff_20'],
#       dtype='object', length=287)
# PCA fit in 4.578209161758423 seconds
# > PCA-based Model fit in 3.0462732315063477 seconds
# > PCA GLM Built in 8.320709943771362 seconds
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Running multi
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# > cv_mean_score_train: 0.2383418356512311
# > cv_R2_score: 0.23285674067043782
# > cv_mean_score: 0.23276775835534025
# Running multi
# Multirun queue completed
#
# ---
#
# Best Score: 0.23285674067043782
# Best Params: {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Best Model: <sglm.models.sglm.GLM object at 0x7fd6383e5340>
# Best Model — Intercept: 0.0
# Overall RunTime: 560.9451019763947
#
# Holdout Score: 0.2447155251719847
# 5 dict_keys(['best_score', 'best_score_std', 'best_params', 'best_model', 'full_cv_results'])
# dfr.shape (273339, 389)
# > Included file_nums for y_col gACH: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# X_setup.columns: Index(['photometryCenterOutIndex_-20', 'photometryCenterOutIndex_-19',
#        'photometryCenterOutIndex_-18', 'photometryCenterOutIndex_-17',
#        'photometryCenterOutIndex_-16', 'photometryCenterOutIndex_-15',
#        'photometryCenterOutIndex_-14', 'photometryCenterOutIndex_-13',
#        'photometryCenterOutIndex_-12', 'photometryCenterOutIndex_-11',
#        ...
#        'spnnrOff_11', 'spnnrOff_12', 'spnnrOff_13', 'spnnrOff_14',
#        'spnnrOff_15', 'spnnrOff_16', 'spnnrOff_17', 'spnnrOff_18',
#        'spnnrOff_19', 'spnnrOff_20'],
#       dtype='object', length=246)
# PCA fit in 4.019495248794556 seconds
# > PCA-based Model fit in 19.586995363235474 seconds
# > PCA GLM Built in 24.457715272903442 seconds
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Running multi
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# > cv_mean_score_train: 0.23631812298020272
# > cv_R2_score: 0.232818994477617
# > cv_mean_score: 0.23277039890294732
# Running multi
# Multirun queue completed
#
# ---
#
# Best Score: 0.232818994477617
# Best Params: {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Best Model: <sglm.models.sglm.GLM object at 0x7fd6383e5af0>
# Best Model — Intercept: 0.0
# Overall RunTime: 655.072005033493
#
# Holdout Score: 0.24209871067616795
# 5 dict_keys(['best_score', 'best_score_std', 'best_params', 'best_model', 'full_cv_results'])
# - ['gACH', 'gACH']
# dfr.shape (273339, 389)
# > Included file_nums for y_col gACH: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# X_setup.columns: Index(['photometryCenterInIndex_-20', 'photometryCenterInIndex_-19',
#        'photometryCenterInIndex_-18', 'photometryCenterInIndex_-17',
#        'photometryCenterInIndex_-16', 'photometryCenterInIndex_-15',
#        'photometryCenterInIndex_-14', 'photometryCenterInIndex_-13',
#        'photometryCenterInIndex_-12', 'photometryCenterInIndex_-11',
#        ...
#        'spnnrOff_11', 'spnnrOff_12', 'spnnrOff_13', 'spnnrOff_14',
#        'spnnrOff_15', 'spnnrOff_16', 'spnnrOff_17', 'spnnrOff_18',
#        'spnnrOff_19', 'spnnrOff_20'],
#       dtype='object', length=287)
# PCA fit in 4.865511894226074 seconds
# > PCA-based Model fit in 3.164897918701172 seconds
# > PCA GLM Built in 8.650094985961914 seconds
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Running multi
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# > cv_mean_score_train: 0.23742052838052388
# > cv_R2_score: 0.22966476299517136
# > cv_mean_score: 0.2297777425608433
# Running multi
# Multirun queue completed
#
# ---
#
# Best Score: 0.22966476299517136
# Best Params: {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Best Model: <sglm.models.sglm.GLM object at 0x7fd6897ea7c0>
# Best Model — Intercept: 0.0
# Overall RunTime: 828.8113420009613
#
# Holdout Score: 0.2525374480213437
# 5 dict_keys(['best_score', 'best_score_std', 'best_params', 'best_model', 'full_cv_results'])
# dfr.shape (273339, 389)
# > Included file_nums for y_col gACH: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# X_setup.columns: Index(['photometryCenterOutIndex_-20', 'photometryCenterOutIndex_-19',
#        'photometryCenterOutIndex_-18', 'photometryCenterOutIndex_-17',
#        'photometryCenterOutIndex_-16', 'photometryCenterOutIndex_-15',
#        'photometryCenterOutIndex_-14', 'photometryCenterOutIndex_-13',
#        'photometryCenterOutIndex_-12', 'photometryCenterOutIndex_-11',
#        ...
#        'spnnrOff_11', 'spnnrOff_12', 'spnnrOff_13', 'spnnrOff_14',
#        'spnnrOff_15', 'spnnrOff_16', 'spnnrOff_17', 'spnnrOff_18',
#        'spnnrOff_19', 'spnnrOff_20'],
#       dtype='object', length=246)
# PCA fit in 2.9432809352874756 seconds
# > PCA-based Model fit in 3.468034029006958 seconds
# > PCA GLM Built in 7.073480844497681 seconds
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Running multi
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# > cv_mean_score_train: 0.234042205337677
# > cv_R2_score: 0.23285382102733276
# > cv_mean_score: 0.23292742338049804
# Running multi
# Multirun queue completed
#
# ---
#
# Best Score: 0.23285382102733276
# Best Params: {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Best Model: <sglm.models.sglm.GLM object at 0x7fd681f12c70>
# Best Model — Intercept: 0.0
# Overall RunTime: 925.5027229785919
#
# Holdout Score: 0.25171454978641417
# 5 dict_keys(['best_score', 'best_score_std', 'best_params', 'best_model', 'full_cv_results'])
# - ['gACH', 'gACH']
# dfr.shape (273339, 389)
# > Included file_nums for y_col gACH: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# X_setup.columns: Index(['photometryCenterInIndex_-20', 'photometryCenterInIndex_-19',
#        'photometryCenterInIndex_-18', 'photometryCenterInIndex_-17',
#        'photometryCenterInIndex_-16', 'photometryCenterInIndex_-15',
#        'photometryCenterInIndex_-14', 'photometryCenterInIndex_-13',
#        'photometryCenterInIndex_-12', 'photometryCenterInIndex_-11',
#        ...
#        'spnnrOff_11', 'spnnrOff_12', 'spnnrOff_13', 'spnnrOff_14',
#        'spnnrOff_15', 'spnnrOff_16', 'spnnrOff_17', 'spnnrOff_18',
#        'spnnrOff_19', 'spnnrOff_20'],
#       dtype='object', length=287)
# PCA fit in 5.671412944793701 seconds
# > PCA-based Model fit in 3.8621978759765625 seconds
# > PCA GLM Built in 10.462821006774902 seconds
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Running multi
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# > cv_mean_score_train: 0.24074669965532797
# > cv_R2_score: 0.24025584480848827
# > cv_mean_score: 0.24028557047313312
# Running multi
# Multirun queue completed
#
# ---
#
# Best Score: 0.24025584480848827
# Best Params: {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Best Model: <sglm.models.sglm.GLM object at 0x7fd68148b070>
# Best Model — Intercept: 0.0
# Overall RunTime: 1102.8807752132416
#
# Holdout Score: 0.23007976906532734
# 5 dict_keys(['best_score', 'best_score_std', 'best_params', 'best_model', 'full_cv_results'])
# dfr.shape (273339, 389)
# > Included file_nums for y_col gACH: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# X_setup.columns: Index(['photometryCenterOutIndex_-20', 'photometryCenterOutIndex_-19',
#        'photometryCenterOutIndex_-18', 'photometryCenterOutIndex_-17',
#        'photometryCenterOutIndex_-16', 'photometryCenterOutIndex_-15',
#        'photometryCenterOutIndex_-14', 'photometryCenterOutIndex_-13',
#        'photometryCenterOutIndex_-12', 'photometryCenterOutIndex_-11',
#        ...
#        'spnnrOff_11', 'spnnrOff_12', 'spnnrOff_13', 'spnnrOff_14',
#        'spnnrOff_15', 'spnnrOff_16', 'spnnrOff_17', 'spnnrOff_18',
#        'spnnrOff_19', 'spnnrOff_20'],
#       dtype='object', length=246)
# PCA fit in 21.573466777801514 seconds
# > PCA-based Model fit in 4.778587102890015 seconds
# > PCA GLM Built in 27.170711040496826 seconds
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Running multi
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# > cv_mean_score_train: 0.23900815808757506
# > cv_R2_score: 0.23641346382115747
# > cv_mean_score: 0.2362969470861845
# Running multi
# Multirun queue completed
#
# ---
#
# Best Score: 0.23641346382115747
# Best Params: {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Best Model: <sglm.models.sglm.GLM object at 0x7fd68148bfd0>
# Best Model — Intercept: 0.0
# Overall RunTime: 1197.4354321956635
#
# Holdout Score: 0.22952091174181322
# 5 dict_keys(['best_score', 'best_score_std', 'best_params', 'best_model', 'full_cv_results'])
# - ['gACH', 'gACH']
# dfr.shape (273339, 389)
# > Included file_nums for y_col gACH: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# X_setup.columns: Index(['photometryCenterInIndex_-20', 'photometryCenterInIndex_-19',
#        'photometryCenterInIndex_-18', 'photometryCenterInIndex_-17',
#        'photometryCenterInIndex_-16', 'photometryCenterInIndex_-15',
#        'photometryCenterInIndex_-14', 'photometryCenterInIndex_-13',
#        'photometryCenterInIndex_-12', 'photometryCenterInIndex_-11',
#        ...
#        'spnnrOff_11', 'spnnrOff_12', 'spnnrOff_13', 'spnnrOff_14',
#        'spnnrOff_15', 'spnnrOff_16', 'spnnrOff_17', 'spnnrOff_18',
#        'spnnrOff_19', 'spnnrOff_20'],
#       dtype='object', length=287)
# PCA fit in 5.398956060409546 seconds
# > PCA-based Model fit in 3.309678077697754 seconds
# > PCA GLM Built in 9.386854887008667 seconds
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Running multi
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# > cv_mean_score_train: 0.23933420419269053
# > cv_R2_score: 0.2329546079485295
# > cv_mean_score: 0.232876905038653
# Running multi
# Multirun queue completed
#
# ---
#
# Best Score: 0.2329546079485295
# Best Params: {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Best Model: <sglm.models.sglm.GLM object at 0x7fd681f12fa0>
# Best Model — Intercept: 0.0
# Overall RunTime: 1364.5547189712524
#
# Holdout Score: 0.2425555903797013
# 5 dict_keys(['best_score', 'best_score_std', 'best_params', 'best_model', 'full_cv_results'])
# dfr.shape (273339, 389)
# > Included file_nums for y_col gACH: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# X_setup.columns: Index(['photometryCenterOutIndex_-20', 'photometryCenterOutIndex_-19',
#        'photometryCenterOutIndex_-18', 'photometryCenterOutIndex_-17',
#        'photometryCenterOutIndex_-16', 'photometryCenterOutIndex_-15',
#        'photometryCenterOutIndex_-14', 'photometryCenterOutIndex_-13',
#        'photometryCenterOutIndex_-12', 'photometryCenterOutIndex_-11',
#        ...
#        'spnnrOff_11', 'spnnrOff_12', 'spnnrOff_13', 'spnnrOff_14',
#        'spnnrOff_15', 'spnnrOff_16', 'spnnrOff_17', 'spnnrOff_18',
#        'spnnrOff_19', 'spnnrOff_20'],
#       dtype='object', length=246)
# PCA fit in 2.84971022605896 seconds
# > PCA-based Model fit in 2.505373954772949 seconds
# > PCA GLM Built in 5.895553112030029 seconds
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Running multi
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# > cv_mean_score_train: 0.2365042100332797
# > cv_R2_score: 0.23534307507546648
# > cv_mean_score: 0.23534286609653915
# Running multi
# Multirun queue completed
#
# ---
#
# Best Score: 0.23534307507546648
# Best Params: {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Best Model: <sglm.models.sglm.GLM object at 0x7fd670445e80>
# Best Model — Intercept: 0.0
# Overall RunTime: 1433.4752838611603
#
# Holdout Score: 0.2402985372738493
# 5 dict_keys(['best_score', 'best_score_std', 'best_params', 'best_model', 'full_cv_results'])
# - ['gACH', 'gACH']
# dfr.shape (273339, 389)
# > Included file_nums for y_col gACH: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# X_setup.columns: Index(['photometryCenterInIndex_-20', 'photometryCenterInIndex_-19',
#        'photometryCenterInIndex_-18', 'photometryCenterInIndex_-17',
#        'photometryCenterInIndex_-16', 'photometryCenterInIndex_-15',
#        'photometryCenterInIndex_-14', 'photometryCenterInIndex_-13',
#        'photometryCenterInIndex_-12', 'photometryCenterInIndex_-11',
#        ...
#        'spnnrOff_11', 'spnnrOff_12', 'spnnrOff_13', 'spnnrOff_14',
#        'spnnrOff_15', 'spnnrOff_16', 'spnnrOff_17', 'spnnrOff_18',
#        'spnnrOff_19', 'spnnrOff_20'],
#       dtype='object', length=287)
# PCA fit in 3.6586191654205322 seconds
# > PCA-based Model fit in 2.8686249256134033 seconds
# > PCA GLM Built in 7.047278642654419 seconds
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Running multi
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# > cv_mean_score_train: 0.2391571804329637
# > cv_R2_score: 0.2334526913476267
# > cv_mean_score: 0.23332601865405253
# Running multi
# Multirun queue completed
#
# ---
#
# Best Score: 0.2334526913476267
# Best Params: {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Best Model: <sglm.models.sglm.GLM object at 0x7fd6704451c0>
# Best Model — Intercept: 0.0
# Overall RunTime: 1600.6066510677338
#
# Holdout Score: 0.2413447896763491
# 5 dict_keys(['best_score', 'best_score_std', 'best_params', 'best_model', 'full_cv_results'])
# dfr.shape (273339, 389)
# > Included file_nums for y_col gACH: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# X_setup.columns: Index(['photometryCenterOutIndex_-20', 'photometryCenterOutIndex_-19',
#        'photometryCenterOutIndex_-18', 'photometryCenterOutIndex_-17',
#        'photometryCenterOutIndex_-16', 'photometryCenterOutIndex_-15',
#        'photometryCenterOutIndex_-14', 'photometryCenterOutIndex_-13',
#        'photometryCenterOutIndex_-12', 'photometryCenterOutIndex_-11',
#        ...
#        'spnnrOff_11', 'spnnrOff_12', 'spnnrOff_13', 'spnnrOff_14',
#        'spnnrOff_15', 'spnnrOff_16', 'spnnrOff_17', 'spnnrOff_18',
#        'spnnrOff_19', 'spnnrOff_20'],
#       dtype='object', length=246)
# PCA fit in 3.2853410243988037 seconds
# > PCA-based Model fit in 2.441622018814087 seconds
# > PCA GLM Built in 6.145483016967773 seconds
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Running multi
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# > cv_mean_score_train: 0.2378651711485508
# > cv_R2_score: 0.22900105091150957
# > cv_mean_score: 0.2288494297932086
# Running multi
# Multirun queue completed
#
# ---
#
# Best Score: 0.22900105091150957
# Best Params: {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Best Model: <sglm.models.sglm.GLM object at 0x7fd681f3e070>
# Best Model — Intercept: 0.0
# Overall RunTime: 1682.624451160431
#
# Holdout Score: 0.23986923800758564
# 5 dict_keys(['best_score', 'best_score_std', 'best_params', 'best_model', 'full_cv_results'])
# - ['gACH', 'gACH']
# dfr.shape (273339, 389)
# > Included file_nums for y_col gACH: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# X_setup.columns: Index(['photometryCenterInIndex_-20', 'photometryCenterInIndex_-19',
#        'photometryCenterInIndex_-18', 'photometryCenterInIndex_-17',
#        'photometryCenterInIndex_-16', 'photometryCenterInIndex_-15',
#        'photometryCenterInIndex_-14', 'photometryCenterInIndex_-13',
#        'photometryCenterInIndex_-12', 'photometryCenterInIndex_-11',
#        ...
#        'spnnrOff_11', 'spnnrOff_12', 'spnnrOff_13', 'spnnrOff_14',
#        'spnnrOff_15', 'spnnrOff_16', 'spnnrOff_17', 'spnnrOff_18',
#        'spnnrOff_19', 'spnnrOff_20'],
#       dtype='object', length=287)
# PCA fit in 10.820075035095215 seconds
# > PCA-based Model fit in 4.971897125244141 seconds
# > PCA GLM Built in 16.405277967453003 seconds
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Running multi
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# > cv_mean_score_train: 0.2389554633248137
# > cv_R2_score: 0.23137451605962733
# > cv_mean_score: 0.23144896821836242
# Running multi
# Multirun queue completed
#
# ---
#
# Best Score: 0.23137451605962733
# Best Params: {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Best Model: <sglm.models.sglm.GLM object at 0x7fd681f3eb80>
# Best Model — Intercept: 0.0
# Overall RunTime: 1911.6102499961853
#
# Holdout Score: 0.24415977029080826
# 5 dict_keys(['best_score', 'best_score_std', 'best_params', 'best_model', 'full_cv_results'])
# dfr.shape (273339, 389)
# > Included file_nums for y_col gACH: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# X_setup.columns: Index(['photometryCenterOutIndex_-20', 'photometryCenterOutIndex_-19',
#        'photometryCenterOutIndex_-18', 'photometryCenterOutIndex_-17',
#        'photometryCenterOutIndex_-16', 'photometryCenterOutIndex_-15',
#        'photometryCenterOutIndex_-14', 'photometryCenterOutIndex_-13',
#        'photometryCenterOutIndex_-12', 'photometryCenterOutIndex_-11',
#        ...
#        'spnnrOff_11', 'spnnrOff_12', 'spnnrOff_13', 'spnnrOff_14',
#        'spnnrOff_15', 'spnnrOff_16', 'spnnrOff_17', 'spnnrOff_18',
#        'spnnrOff_19', 'spnnrOff_20'],
#       dtype='object', length=246)
# PCA fit in 6.541711091995239 seconds
# > PCA-based Model fit in 5.4431312084198 seconds
# > PCA GLM Built in 12.502405166625977 seconds
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Running multi
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# > cv_mean_score_train: 0.23557141309335056
# > cv_R2_score: 0.23505069349246122
# > cv_mean_score: 0.23501810584746377
# Running multi
# Multirun queue completed
#
# ---
#
# Best Score: 0.23505069349246122
# Best Params: {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Best Model: <sglm.models.sglm.GLM object at 0x7fd670445250>
# Best Model — Intercept: 0.0
# Overall RunTime: 2016.558809041977
#
# Holdout Score: 0.24275533237520863
# 5 dict_keys(['best_score', 'best_score_std', 'best_params', 'best_model', 'full_cv_results'])
# - ['gACH', 'gACH']
# dfr.shape (273339, 389)
# > Included file_nums for y_col gACH: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# X_setup.columns: Index(['photometryCenterInIndex_-20', 'photometryCenterInIndex_-19',
#        'photometryCenterInIndex_-18', 'photometryCenterInIndex_-17',
#        'photometryCenterInIndex_-16', 'photometryCenterInIndex_-15',
#        'photometryCenterInIndex_-14', 'photometryCenterInIndex_-13',
#        'photometryCenterInIndex_-12', 'photometryCenterInIndex_-11',
#        ...
#        'spnnrOff_11', 'spnnrOff_12', 'spnnrOff_13', 'spnnrOff_14',
#        'spnnrOff_15', 'spnnrOff_16', 'spnnrOff_17', 'spnnrOff_18',
#        'spnnrOff_19', 'spnnrOff_20'],
#       dtype='object', length=287)
# PCA fit in 3.0922439098358154 seconds
# > PCA-based Model fit in 2.7901272773742676 seconds
# > PCA GLM Built in 6.322671890258789 seconds
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Running multi
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# > cv_mean_score_train: 0.23976498418579947
# > cv_R2_score: 0.234876047572793
# > cv_mean_score: 0.2348216626168742
# Running multi
# Multirun queue completed
#
# ---
#
# Best Score: 0.234876047572793
# Best Params: {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Best Model: <sglm.models.sglm.GLM object at 0x7fd681f3cf10>
# Best Model — Intercept: 0.0
# Overall RunTime: 2192.089725971222
#
# Holdout Score: 0.23841637761218493
# 5 dict_keys(['best_score', 'best_score_std', 'best_params', 'best_model', 'full_cv_results'])
# dfr.shape (273339, 389)
# > Included file_nums for y_col gACH: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# X_setup.columns: Index(['photometryCenterOutIndex_-20', 'photometryCenterOutIndex_-19',
#        'photometryCenterOutIndex_-18', 'photometryCenterOutIndex_-17',
#        'photometryCenterOutIndex_-16', 'photometryCenterOutIndex_-15',
#        'photometryCenterOutIndex_-14', 'photometryCenterOutIndex_-13',
#        'photometryCenterOutIndex_-12', 'photometryCenterOutIndex_-11',
#        ...
#        'spnnrOff_11', 'spnnrOff_12', 'spnnrOff_13', 'spnnrOff_14',
#        'spnnrOff_15', 'spnnrOff_16', 'spnnrOff_17', 'spnnrOff_18',
#        'spnnrOff_19', 'spnnrOff_20'],
#       dtype='object', length=246)
# PCA fit in 15.02616810798645 seconds
# > PCA-based Model fit in 7.8938210010528564 seconds
# > PCA GLM Built in 23.87066912651062 seconds
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Running multi
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# > cv_mean_score_train: 0.2374492119396598
# > cv_R2_score: 0.23521152591316763
# > cv_mean_score: 0.2352782214856687
# Running multi
# Multirun queue completed
#
# ---
#
# Best Score: 0.23521152591316763
# Best Params: {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Best Model: <sglm.models.sglm.GLM object at 0x7fd681f27c10>
# Best Model — Intercept: 0.0
# Overall RunTime: 2284.182629108429
#
# Holdout Score: 0.23627632887840944
# 5 dict_keys(['best_score', 'best_score_std', 'best_params', 'best_model', 'full_cv_results'])
# - ['gACH', 'gACH']
# dfr.shape (273339, 389)
# > Included file_nums for y_col gACH: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# X_setup.columns: Index(['photometryCenterInIndex_-20', 'photometryCenterInIndex_-19',
#        'photometryCenterInIndex_-18', 'photometryCenterInIndex_-17',
#        'photometryCenterInIndex_-16', 'photometryCenterInIndex_-15',
#        'photometryCenterInIndex_-14', 'photometryCenterInIndex_-13',
#        'photometryCenterInIndex_-12', 'photometryCenterInIndex_-11',
#        ...
#        'spnnrOff_11', 'spnnrOff_12', 'spnnrOff_13', 'spnnrOff_14',
#        'spnnrOff_15', 'spnnrOff_16', 'spnnrOff_17', 'spnnrOff_18',
#        'spnnrOff_19', 'spnnrOff_20'],
#       dtype='object', length=287)
# PCA fit in 10.5379159450531 seconds
# > PCA-based Model fit in 2.7091331481933594 seconds
# > PCA GLM Built in 13.778126001358032 seconds
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Running multi
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# > cv_mean_score_train: 0.2407595769683344
# > cv_R2_score: 0.2363867125308844
# > cv_mean_score: 0.23630009797756352
# Running multi
# Multirun queue completed
#
# ---
#
# Best Score: 0.2363867125308844
# Best Params: {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Best Model: <sglm.models.sglm.GLM object at 0x7fd6b1ea3040>
# Best Model — Intercept: 0.0
# Overall RunTime: 2444.7193500995636
#
# Holdout Score: 0.23359507648259015
# 5 dict_keys(['best_score', 'best_score_std', 'best_params', 'best_model', 'full_cv_results'])
# dfr.shape (273339, 389)
# > Included file_nums for y_col gACH: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# X_setup.columns: Index(['photometryCenterOutIndex_-20', 'photometryCenterOutIndex_-19',
#        'photometryCenterOutIndex_-18', 'photometryCenterOutIndex_-17',
#        'photometryCenterOutIndex_-16', 'photometryCenterOutIndex_-15',
#        'photometryCenterOutIndex_-14', 'photometryCenterOutIndex_-13',
#        'photometryCenterOutIndex_-12', 'photometryCenterOutIndex_-11',
#        ...
#        'spnnrOff_11', 'spnnrOff_12', 'spnnrOff_13', 'spnnrOff_14',
#        'spnnrOff_15', 'spnnrOff_16', 'spnnrOff_17', 'spnnrOff_18',
#        'spnnrOff_19', 'spnnrOff_20'],
#       dtype='object', length=246)
# PCA fit in 3.217573881149292 seconds
# > PCA-based Model fit in 2.766342878341675 seconds
# > PCA GLM Built in 6.384517192840576 seconds
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Running multi
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# > cv_mean_score_train: 0.23925289989496773
# > cv_R2_score: 0.23359427111242592
# > cv_mean_score: 0.23351575654419782
# Running multi
# Multirun queue completed
#
# ---
#
# Best Score: 0.23359427111242592
# Best Params: {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Best Model: <sglm.models.sglm.GLM object at 0x7fd681f27f70>
# Best Model — Intercept: 0.0
# Overall RunTime: 2517.3452599048615
#
# Holdout Score: 0.23156969704801922
# 5 dict_keys(['best_score', 'best_score_std', 'best_params', 'best_model', 'full_cv_results'])
# Created directory: /Users/josh/Documents/Harvard/GLM/sabatinilab-glm/sglm/outputs/fig1/all/nw-anlysis_1-ft/
# Created directory: /Users/josh/Documents/Harvard/GLM/sabatinilab-glm/sglm/outputs/fig1/all/nw-anlysis_1-ft/reports/figures/best_coeffs/
# Created directory: /Users/josh/Documents/Harvard/GLM/sabatinilab-glm/sglm/outputs/fig1/all/nw-anlysis_1-ft/reports/coeffs/best_coeffs/
# Created directory: /Users/josh/Documents/Harvard/GLM/sabatinilab-glm/sglm/outputs/fig1/all/nw-anlysis_1-ft/reports/figures/best_reconstruct/
# Created directory: /Users/josh/Documents/Harvard/GLM/sabatinilab-glm/sglm/outputs/fig1/all/nw-anlysis_1-ft/reports/residuals/best_resids/
# Created directory: /Users/josh/Documents/Harvard/GLM/sabatinilab-glm/sglm/outputs/fig1/all/nw-anlysis_1-ft/reports/coeffs/best_combined_coeffs/
# Created directory: /Users/josh/Documents/Harvard/GLM/sabatinilab-glm/sglm/outputs/fig1/all/nw-anlysis_1-ft/models/coeffs/
# Created directory: /Users/josh/Documents/Harvard/GLM/sabatinilab-glm/sglm/outputs/fig1/all/nw-anlysis_1-ft/models/intercepts/
# Created directory: /Users/josh/Documents/Harvard/GLM/sabatinilab-glm/sglm/outputs/fig1/all/nw-anlysis_1-ft/reports/figures/all_coeffs/
# Created directory: /Users/josh/Documents/Harvard/GLM/sabatinilab-glm/sglm/outputs/fig1/all/nw-anlysis_1-ft/reports/figures/all_reconstruct/
# ['63_64'] 0 63_64
# dfrel_basis (273339, 388)
# FINAL_63_64.csv
# - ['rDA', 'rDA']
# dfr.shape (273339, 388)
# > Included file_nums for y_col rDA: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# X_setup.columns: Index(['photometryCenterInIndex_-20', 'photometryCenterInIndex_-19',
#        'photometryCenterInIndex_-18', 'photometryCenterInIndex_-17',
#        'photometryCenterInIndex_-16', 'photometryCenterInIndex_-15',
#        'photometryCenterInIndex_-14', 'photometryCenterInIndex_-13',
#        'photometryCenterInIndex_-12', 'photometryCenterInIndex_-11',
#        ...
#        'spnnrOff_11', 'spnnrOff_12', 'spnnrOff_13', 'spnnrOff_14',
#        'spnnrOff_15', 'spnnrOff_16', 'spnnrOff_17', 'spnnrOff_18',
#        'spnnrOff_19', 'spnnrOff_20'],
#       dtype='object', length=287)
# PCA fit in 2.6994428634643555 seconds
# > PCA-based Model fit in 2.4318430423736572 seconds
# > PCA GLM Built in 5.514527082443237 seconds
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Running multi
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# > cv_mean_score_train: 0.24735343603543627
# > cv_R2_score: 0.24473223257627374
# > cv_mean_score: 0.2448748017218377
# Running multi
# Multirun queue completed
#
# ---
#
# Best Score: 0.24473223257627374
# Best Params: {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Best Model: <sglm.models.sglm.GLM object at 0x7fd6a37ede50>
# Best Model — Intercept: 0.0
# Overall RunTime: 60.90462779998779
#
# Holdout Score: 0.24441158632432203
# 5 dict_keys(['best_score', 'best_score_std', 'best_params', 'best_model', 'full_cv_results'])
# dfr.shape (273339, 389)
# > Included file_nums for y_col rDA: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# X_setup.columns: Index(['photometryCenterOutIndex_-20', 'photometryCenterOutIndex_-19',
#        'photometryCenterOutIndex_-18', 'photometryCenterOutIndex_-17',
#        'photometryCenterOutIndex_-16', 'photometryCenterOutIndex_-15',
#        'photometryCenterOutIndex_-14', 'photometryCenterOutIndex_-13',
#        'photometryCenterOutIndex_-12', 'photometryCenterOutIndex_-11',
#        ...
#        'spnnrOff_11', 'spnnrOff_12', 'spnnrOff_13', 'spnnrOff_14',
#        'spnnrOff_15', 'spnnrOff_16', 'spnnrOff_17', 'spnnrOff_18',
#        'spnnrOff_19', 'spnnrOff_20'],
#       dtype='object', length=246)
# PCA fit in 2.4574451446533203 seconds
# > PCA-based Model fit in 1.9702651500701904 seconds
# > PCA GLM Built in 4.7792017459869385 seconds
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Running multi
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# > cv_mean_score_train: 0.2396019595705093
# > cv_R2_score: 0.2395327115784167
# > cv_mean_score: 0.23949356187529608
# Running multi
# Multirun queue completed
#
# ---
#
# Best Score: 0.2395327115784167
# Best Params: {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Best Model: <sglm.models.sglm.GLM object at 0x7fd6b1ea34c0>
# Best Model — Intercept: 0.0
# Overall RunTime: 117.94245195388794
#
# Holdout Score: 0.23688732336800655
# 5 dict_keys(['best_score', 'best_score_std', 'best_params', 'best_model', 'full_cv_results'])
# - ['rDA', 'rDA']
# dfr.shape (273339, 389)
# > Included file_nums for y_col rDA: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# X_setup.columns: Index(['photometryCenterInIndex_-20', 'photometryCenterInIndex_-19',
#        'photometryCenterInIndex_-18', 'photometryCenterInIndex_-17',
#        'photometryCenterInIndex_-16', 'photometryCenterInIndex_-15',
#        'photometryCenterInIndex_-14', 'photometryCenterInIndex_-13',
#        'photometryCenterInIndex_-12', 'photometryCenterInIndex_-11',
#        ...
#        'spnnrOff_11', 'spnnrOff_12', 'spnnrOff_13', 'spnnrOff_14',
#        'spnnrOff_15', 'spnnrOff_16', 'spnnrOff_17', 'spnnrOff_18',
#        'spnnrOff_19', 'spnnrOff_20'],
#       dtype='object', length=287)
# PCA fit in 3.036550998687744 seconds
# > PCA-based Model fit in 2.557220697402954 seconds
# > PCA GLM Built in 6.057760953903198 seconds
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Running multi
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# > cv_mean_score_train: 0.24696409837560762
# > cv_R2_score: 0.241525196625743
# > cv_mean_score: 0.2412422001054751
# Running multi
# Multirun queue completed
#
# ---
#
# Best Score: 0.241525196625743
# Best Params: {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Best Model: <sglm.models.sglm.GLM object at 0x7fd681443c10>
# Best Model — Intercept: 0.0
# Overall RunTime: 247.4514558315277
#
# Holdout Score: 0.24904537351484846
# 5 dict_keys(['best_score', 'best_score_std', 'best_params', 'best_model', 'full_cv_results'])
# dfr.shape (273339, 389)
# > Included file_nums for y_col rDA: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# X_setup.columns: Index(['photometryCenterOutIndex_-20', 'photometryCenterOutIndex_-19',
#        'photometryCenterOutIndex_-18', 'photometryCenterOutIndex_-17',
#        'photometryCenterOutIndex_-16', 'photometryCenterOutIndex_-15',
#        'photometryCenterOutIndex_-14', 'photometryCenterOutIndex_-13',
#        'photometryCenterOutIndex_-12', 'photometryCenterOutIndex_-11',
#        ...
#        'spnnrOff_11', 'spnnrOff_12', 'spnnrOff_13', 'spnnrOff_14',
#        'spnnrOff_15', 'spnnrOff_16', 'spnnrOff_17', 'spnnrOff_18',
#        'spnnrOff_19', 'spnnrOff_20'],
#       dtype='object', length=246)
# PCA fit in 3.975999116897583 seconds
# > PCA-based Model fit in 2.064541816711426 seconds
# > PCA GLM Built in 6.476980924606323 seconds
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Running multi
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# > cv_mean_score_train: 0.23932753176138308
# > cv_R2_score: 0.2343726495907691
# > cv_mean_score: 0.23432693690199335
# Running multi
# Multirun queue completed
#
# ---
#
# Best Score: 0.2343726495907691
# Best Params: {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Best Model: <sglm.models.sglm.GLM object at 0x7fd681443280>
# Best Model — Intercept: 0.0
# Overall RunTime: 301.67480993270874
#
# Holdout Score: 0.24323055438979402
# 5 dict_keys(['best_score', 'best_score_std', 'best_params', 'best_model', 'full_cv_results'])
# - ['rDA', 'rDA']
# dfr.shape (273339, 389)
# > Included file_nums for y_col rDA: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# X_setup.columns: Index(['photometryCenterInIndex_-20', 'photometryCenterInIndex_-19',
#        'photometryCenterInIndex_-18', 'photometryCenterInIndex_-17',
#        'photometryCenterInIndex_-16', 'photometryCenterInIndex_-15',
#        'photometryCenterInIndex_-14', 'photometryCenterInIndex_-13',
#        'photometryCenterInIndex_-12', 'photometryCenterInIndex_-11',
#        ...
#        'spnnrOff_11', 'spnnrOff_12', 'spnnrOff_13', 'spnnrOff_14',
#        'spnnrOff_15', 'spnnrOff_16', 'spnnrOff_17', 'spnnrOff_18',
#        'spnnrOff_19', 'spnnrOff_20'],
#       dtype='object', length=287)
# PCA fit in 3.226670026779175 seconds
# > PCA-based Model fit in 3.017545223236084 seconds
# > PCA GLM Built in 6.74968409538269 seconds
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Running multi
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# > cv_mean_score_train: 0.24444224185641628
# > cv_R2_score: 0.24066177062880623
# > cv_mean_score: 0.2407453867817481
# Running multi
# Multirun queue completed
#
# ---
#
# Best Score: 0.24066177062880623
# Best Params: {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Best Model: <sglm.models.sglm.GLM object at 0x7fd681f33850>
# Best Model — Intercept: 0.0
# Overall RunTime: 433.6192080974579
#
# Holdout Score: 0.260301092903633
# 5 dict_keys(['best_score', 'best_score_std', 'best_params', 'best_model', 'full_cv_results'])
# dfr.shape (273339, 389)
# > Included file_nums for y_col rDA: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# X_setup.columns: Index(['photometryCenterOutIndex_-20', 'photometryCenterOutIndex_-19',
#        'photometryCenterOutIndex_-18', 'photometryCenterOutIndex_-17',
#        'photometryCenterOutIndex_-16', 'photometryCenterOutIndex_-15',
#        'photometryCenterOutIndex_-14', 'photometryCenterOutIndex_-13',
#        'photometryCenterOutIndex_-12', 'photometryCenterOutIndex_-11',
#        ...
#        'spnnrOff_11', 'spnnrOff_12', 'spnnrOff_13', 'spnnrOff_14',
#        'spnnrOff_15', 'spnnrOff_16', 'spnnrOff_17', 'spnnrOff_18',
#        'spnnrOff_19', 'spnnrOff_20'],
#       dtype='object', length=246)
# PCA fit in 3.658513307571411 seconds
# > PCA-based Model fit in 2.381527900695801 seconds
# > PCA GLM Built in 6.47765588760376 seconds
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Running multi
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# > cv_mean_score_train: 0.23763262772843485
# > cv_R2_score: 0.2327329732346628
# > cv_mean_score: 0.2324656611594511
# Running multi
# Multirun queue completed
#
# ---
#
# Best Score: 0.2327329732346628
# Best Params: {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Best Model: <sglm.models.sglm.GLM object at 0x7fd6a37d8c40>
# Best Model — Intercept: 0.0
# Overall RunTime: 494.3544900417328
#
# Holdout Score: 0.25151625635661634
# 5 dict_keys(['best_score', 'best_score_std', 'best_params', 'best_model', 'full_cv_results'])
# - ['rDA', 'rDA']
# dfr.shape (273339, 389)
# > Included file_nums for y_col rDA: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# X_setup.columns: Index(['photometryCenterInIndex_-20', 'photometryCenterInIndex_-19',
#        'photometryCenterInIndex_-18', 'photometryCenterInIndex_-17',
#        'photometryCenterInIndex_-16', 'photometryCenterInIndex_-15',
#        'photometryCenterInIndex_-14', 'photometryCenterInIndex_-13',
#        'photometryCenterInIndex_-12', 'photometryCenterInIndex_-11',
#        ...
#        'spnnrOff_11', 'spnnrOff_12', 'spnnrOff_13', 'spnnrOff_14',
#        'spnnrOff_15', 'spnnrOff_16', 'spnnrOff_17', 'spnnrOff_18',
#        'spnnrOff_19', 'spnnrOff_20'],
#       dtype='object', length=287)
# PCA fit in 3.072896957397461 seconds
# > PCA-based Model fit in 2.6834819316864014 seconds
# > PCA GLM Built in 6.241650104522705 seconds
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Running multi
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# > cv_mean_score_train: 0.24596484005967412
# > cv_R2_score: 0.24437512363614444
# > cv_mean_score: 0.24435286408264695
# Running multi
# Multirun queue completed
#
# ---
#
# Best Score: 0.24437512363614444
# Best Params: {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Best Model: <sglm.models.sglm.GLM object at 0x7fd6a3e5d580>
# Best Model — Intercept: 0.0
# Overall RunTime: 623.8298149108887
#
# Holdout Score: 0.24963833889443698
# 5 dict_keys(['best_score', 'best_score_std', 'best_params', 'best_model', 'full_cv_results'])
# dfr.shape (273339, 389)
# > Included file_nums for y_col rDA: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# X_setup.columns: Index(['photometryCenterOutIndex_-20', 'photometryCenterOutIndex_-19',
#        'photometryCenterOutIndex_-18', 'photometryCenterOutIndex_-17',
#        'photometryCenterOutIndex_-16', 'photometryCenterOutIndex_-15',
#        'photometryCenterOutIndex_-14', 'photometryCenterOutIndex_-13',
#        'photometryCenterOutIndex_-12', 'photometryCenterOutIndex_-11',
#        ...
#        'spnnrOff_11', 'spnnrOff_12', 'spnnrOff_13', 'spnnrOff_14',
#        'spnnrOff_15', 'spnnrOff_16', 'spnnrOff_17', 'spnnrOff_18',
#        'spnnrOff_19', 'spnnrOff_20'],
#       dtype='object', length=246)
# PCA fit in 3.4517288208007812 seconds
# > PCA-based Model fit in 2.246151924133301 seconds
# > PCA GLM Built in 6.111965179443359 seconds
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Running multi
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# > cv_mean_score_train: 0.23790532795425773
# > cv_R2_score: 0.23865934888840468
# > cv_mean_score: 0.23873655079723594
# Running multi
# Multirun queue completed
#
# ---
#
# Best Score: 0.23865934888840468
# Best Params: {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Best Model: <sglm.models.sglm.GLM object at 0x7fd6a3e63cd0>
# Best Model — Intercept: 0.0
# Overall RunTime: 696.1494569778442
#
# Holdout Score: 0.24382925703934044
# 5 dict_keys(['best_score', 'best_score_std', 'best_params', 'best_model', 'full_cv_results'])
# - ['rDA', 'rDA']
# dfr.shape (273339, 389)
# > Included file_nums for y_col rDA: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# X_setup.columns: Index(['photometryCenterInIndex_-20', 'photometryCenterInIndex_-19',
#        'photometryCenterInIndex_-18', 'photometryCenterInIndex_-17',
#        'photometryCenterInIndex_-16', 'photometryCenterInIndex_-15',
#        'photometryCenterInIndex_-14', 'photometryCenterInIndex_-13',
#        'photometryCenterInIndex_-12', 'photometryCenterInIndex_-11',
#        ...
#        'spnnrOff_11', 'spnnrOff_12', 'spnnrOff_13', 'spnnrOff_14',
#        'spnnrOff_15', 'spnnrOff_16', 'spnnrOff_17', 'spnnrOff_18',
#        'spnnrOff_19', 'spnnrOff_20'],
#       dtype='object', length=287)
# PCA fit in 3.0829548835754395 seconds
# > PCA-based Model fit in 2.4008638858795166 seconds
# > PCA GLM Built in 5.9332451820373535 seconds
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Running multi
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# > cv_mean_score_train: 0.24281149205319097
# > cv_R2_score: 0.2393885225737582
# > cv_mean_score: 0.239112717726805
# Running multi
# Multirun queue completed
#
# ---
#
# Best Score: 0.2393885225737582
# Best Params: {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Best Model: <sglm.models.sglm.GLM object at 0x7fd6a3e63880>
# Best Model — Intercept: 0.0
# Overall RunTime: 828.9714050292969
#
# Holdout Score: 0.2636064622042261
# 5 dict_keys(['best_score', 'best_score_std', 'best_params', 'best_model', 'full_cv_results'])
# dfr.shape (273339, 389)
# > Included file_nums for y_col rDA: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# X_setup.columns: Index(['photometryCenterOutIndex_-20', 'photometryCenterOutIndex_-19',
#        'photometryCenterOutIndex_-18', 'photometryCenterOutIndex_-17',
#        'photometryCenterOutIndex_-16', 'photometryCenterOutIndex_-15',
#        'photometryCenterOutIndex_-14', 'photometryCenterOutIndex_-13',
#        'photometryCenterOutIndex_-12', 'photometryCenterOutIndex_-11',
#        ...
#        'spnnrOff_11', 'spnnrOff_12', 'spnnrOff_13', 'spnnrOff_14',
#        'spnnrOff_15', 'spnnrOff_16', 'spnnrOff_17', 'spnnrOff_18',
#        'spnnrOff_19', 'spnnrOff_20'],
#       dtype='object', length=246)
# PCA fit in 4.104140758514404 seconds
# > PCA-based Model fit in 2.4310810565948486 seconds
# > PCA GLM Built in 6.9968719482421875 seconds
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Running multi
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# > cv_mean_score_train: 0.23562575832826754
# > cv_R2_score: 0.22958794801503357
# > cv_mean_score: 0.22949918589375357
# Running multi
# Multirun queue completed
#
# ---
#
# Best Score: 0.22958794801503357
# Best Params: {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Best Model: <sglm.models.sglm.GLM object at 0x7fd681123700>
# Best Model — Intercept: 0.0
# Overall RunTime: 881.7564430236816
#
# Holdout Score: 0.2581298042663571
# 5 dict_keys(['best_score', 'best_score_std', 'best_params', 'best_model', 'full_cv_results'])
# - ['rDA', 'rDA']
# dfr.shape (273339, 389)
# > Included file_nums for y_col rDA: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# X_setup.columns: Index(['photometryCenterInIndex_-20', 'photometryCenterInIndex_-19',
#        'photometryCenterInIndex_-18', 'photometryCenterInIndex_-17',
#        'photometryCenterInIndex_-16', 'photometryCenterInIndex_-15',
#        'photometryCenterInIndex_-14', 'photometryCenterInIndex_-13',
#        'photometryCenterInIndex_-12', 'photometryCenterInIndex_-11',
#        ...
#        'spnnrOff_11', 'spnnrOff_12', 'spnnrOff_13', 'spnnrOff_14',
#        'spnnrOff_15', 'spnnrOff_16', 'spnnrOff_17', 'spnnrOff_18',
#        'spnnrOff_19', 'spnnrOff_20'],
#       dtype='object', length=287)
# PCA fit in 3.093384027481079 seconds
# > PCA-based Model fit in 2.5501821041107178 seconds
# > PCA GLM Built in 6.122138738632202 seconds
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Running multi
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# > cv_mean_score_train: 0.2469126425979881
# > cv_R2_score: 0.24635415022719942
# > cv_mean_score: 0.24623465908412473
# Running multi
# Multirun queue completed
#
# ---
#
# Best Score: 0.24635415022719942
# Best Params: {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Best Model: <sglm.models.sglm.GLM object at 0x7fd66055fc70>
# Best Model — Intercept: 0.0
# Overall RunTime: 1022.4608681201935
#
# Holdout Score: 0.24448082214074152
# 5 dict_keys(['best_score', 'best_score_std', 'best_params', 'best_model', 'full_cv_results'])
# dfr.shape (273339, 389)
# > Included file_nums for y_col rDA: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# X_setup.columns: Index(['photometryCenterOutIndex_-20', 'photometryCenterOutIndex_-19',
#        'photometryCenterOutIndex_-18', 'photometryCenterOutIndex_-17',
#        'photometryCenterOutIndex_-16', 'photometryCenterOutIndex_-15',
#        'photometryCenterOutIndex_-14', 'photometryCenterOutIndex_-13',
#        'photometryCenterOutIndex_-12', 'photometryCenterOutIndex_-11',
#        ...
#        'spnnrOff_11', 'spnnrOff_12', 'spnnrOff_13', 'spnnrOff_14',
#        'spnnrOff_15', 'spnnrOff_16', 'spnnrOff_17', 'spnnrOff_18',
#        'spnnrOff_19', 'spnnrOff_20'],
#       dtype='object', length=246)
# PCA fit in 5.649791955947876 seconds
# > PCA-based Model fit in 2.3371641635894775 seconds
# > PCA GLM Built in 8.502216100692749 seconds
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Running multi
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# > cv_mean_score_train: 0.2400643660937997
# > cv_R2_score: 0.23600225791150087
# > cv_mean_score: 0.23575583961036792
# Running multi
# Multirun queue completed
#
# ---
#
# Best Score: 0.23600225791150087
# Best Params: {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Best Model: <sglm.models.sglm.GLM object at 0x7fd66055f2b0>
# Best Model — Intercept: 0.0
# Overall RunTime: 1075.012013912201
#
# Holdout Score: 0.23857493613708303
# 5 dict_keys(['best_score', 'best_score_std', 'best_params', 'best_model', 'full_cv_results'])
# - ['rDA', 'rDA']
# dfr.shape (273339, 389)
# > Included file_nums for y_col rDA: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# X_setup.columns: Index(['photometryCenterInIndex_-20', 'photometryCenterInIndex_-19',
#        'photometryCenterInIndex_-18', 'photometryCenterInIndex_-17',
#        'photometryCenterInIndex_-16', 'photometryCenterInIndex_-15',
#        'photometryCenterInIndex_-14', 'photometryCenterInIndex_-13',
#        'photometryCenterInIndex_-12', 'photometryCenterInIndex_-11',
#        ...
#        'spnnrOff_11', 'spnnrOff_12', 'spnnrOff_13', 'spnnrOff_14',
#        'spnnrOff_15', 'spnnrOff_16', 'spnnrOff_17', 'spnnrOff_18',
#        'spnnrOff_19', 'spnnrOff_20'],
#       dtype='object', length=287)
# PCA fit in 6.0831780433654785 seconds
# > PCA-based Model fit in 2.7700421810150146 seconds
# > PCA GLM Built in 9.502549171447754 seconds
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Running multi
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# > cv_mean_score_train: 0.24821792129067877
# > cv_R2_score: 0.2475869309537143
# > cv_mean_score: 0.24751370735295963
# Running multi
# Multirun queue completed
#
# ---
#
# Best Score: 0.2475869309537143
# Best Params: {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Best Model: <sglm.models.sglm.GLM object at 0x7fd68afab880>
# Best Model — Intercept: 0.0
# Overall RunTime: 1208.8064329624176
#
# Holdout Score: 0.23839328664411863
# 5 dict_keys(['best_score', 'best_score_std', 'best_params', 'best_model', 'full_cv_results'])
# dfr.shape (273339, 389)
# > Included file_nums for y_col rDA: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# X_setup.columns: Index(['photometryCenterOutIndex_-20', 'photometryCenterOutIndex_-19',
#        'photometryCenterOutIndex_-18', 'photometryCenterOutIndex_-17',
#        'photometryCenterOutIndex_-16', 'photometryCenterOutIndex_-15',
#        'photometryCenterOutIndex_-14', 'photometryCenterOutIndex_-13',
#        'photometryCenterOutIndex_-12', 'photometryCenterOutIndex_-11',
#        ...
#        'spnnrOff_11', 'spnnrOff_12', 'spnnrOff_13', 'spnnrOff_14',
#        'spnnrOff_15', 'spnnrOff_16', 'spnnrOff_17', 'spnnrOff_18',
#        'spnnrOff_19', 'spnnrOff_20'],
#       dtype='object', length=246)
# PCA fit in 6.142580032348633 seconds
# > PCA-based Model fit in 5.277338981628418 seconds
# > PCA GLM Built in 12.036164045333862 seconds
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Running multi
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# > cv_mean_score_train: 0.23915032397762062
# > cv_R2_score: 0.24315036038128235
# > cv_mean_score: 0.24313609013782278
# Running multi
# Multirun queue completed
#
# ---
#
# Best Score: 0.24315036038128235
# Best Params: {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Best Model: <sglm.models.sglm.GLM object at 0x7fd6a3e5aa00>
# Best Model — Intercept: 0.0
# Overall RunTime: 1265.0759279727936
#
# Holdout Score: 0.2352854448489372
# 5 dict_keys(['best_score', 'best_score_std', 'best_params', 'best_model', 'full_cv_results'])
# - ['rDA', 'rDA']
# dfr.shape (273339, 389)
# > Included file_nums for y_col rDA: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# X_setup.columns: Index(['photometryCenterInIndex_-20', 'photometryCenterInIndex_-19',
#        'photometryCenterInIndex_-18', 'photometryCenterInIndex_-17',
#        'photometryCenterInIndex_-16', 'photometryCenterInIndex_-15',
#        'photometryCenterInIndex_-14', 'photometryCenterInIndex_-13',
#        'photometryCenterInIndex_-12', 'photometryCenterInIndex_-11',
#        ...
#        'spnnrOff_11', 'spnnrOff_12', 'spnnrOff_13', 'spnnrOff_14',
#        'spnnrOff_15', 'spnnrOff_16', 'spnnrOff_17', 'spnnrOff_18',
#        'spnnrOff_19', 'spnnrOff_20'],
#       dtype='object', length=287)
# PCA fit in 3.26481294631958 seconds
# > PCA-based Model fit in 2.825622081756592 seconds
# > PCA GLM Built in 6.5924072265625 seconds
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Running multi
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# > cv_mean_score_train: 0.2496231462556333
# > cv_R2_score: 0.2419549443486383
# > cv_mean_score: 0.24188982657311323
# Running multi
# Multirun queue completed
#
# ---
#
# Best Score: 0.2419549443486383
# Best Params: {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Best Model: <sglm.models.sglm.GLM object at 0x7fd6a3e5abe0>
# Best Model — Intercept: 0.0
# Overall RunTime: 1427.2095668315887
#
# Holdout Score: 0.23832827637531362
# 5 dict_keys(['best_score', 'best_score_std', 'best_params', 'best_model', 'full_cv_results'])
# dfr.shape (273339, 389)
# > Included file_nums for y_col rDA: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# X_setup.columns: Index(['photometryCenterOutIndex_-20', 'photometryCenterOutIndex_-19',
#        'photometryCenterOutIndex_-18', 'photometryCenterOutIndex_-17',
#        'photometryCenterOutIndex_-16', 'photometryCenterOutIndex_-15',
#        'photometryCenterOutIndex_-14', 'photometryCenterOutIndex_-13',
#        'photometryCenterOutIndex_-12', 'photometryCenterOutIndex_-11',
#        ...
#        'spnnrOff_11', 'spnnrOff_12', 'spnnrOff_13', 'spnnrOff_14',
#        'spnnrOff_15', 'spnnrOff_16', 'spnnrOff_17', 'spnnrOff_18',
#        'spnnrOff_19', 'spnnrOff_20'],
#       dtype='object', length=246)
# PCA fit in 4.343258857727051 seconds
# > PCA-based Model fit in 2.1635122299194336 seconds
# > PCA GLM Built in 6.9468159675598145 seconds
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Running multi
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# > cv_mean_score_train: 0.24055329392778627
# > cv_R2_score: 0.24194265034946272
# > cv_mean_score: 0.24187399090225475
# Running multi
# Multirun queue completed
#
# ---
#
# Best Score: 0.24194265034946272
# Best Params: {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Best Model: <sglm.models.sglm.GLM object at 0x7fd6a3e3de20>
# Best Model — Intercept: 0.0
# Overall RunTime: 1482.9452970027924
#
# Holdout Score: 0.23109966933439663
# 5 dict_keys(['best_score', 'best_score_std', 'best_params', 'best_model', 'full_cv_results'])
# - ['rDA', 'rDA']
# dfr.shape (273339, 389)
# > Included file_nums for y_col rDA: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# X_setup.columns: Index(['photometryCenterInIndex_-20', 'photometryCenterInIndex_-19',
#        'photometryCenterInIndex_-18', 'photometryCenterInIndex_-17',
#        'photometryCenterInIndex_-16', 'photometryCenterInIndex_-15',
#        'photometryCenterInIndex_-14', 'photometryCenterInIndex_-13',
#        'photometryCenterInIndex_-12', 'photometryCenterInIndex_-11',
#        ...
#        'spnnrOff_11', 'spnnrOff_12', 'spnnrOff_13', 'spnnrOff_14',
#        'spnnrOff_15', 'spnnrOff_16', 'spnnrOff_17', 'spnnrOff_18',
#        'spnnrOff_19', 'spnnrOff_20'],
#       dtype='object', length=287)
# PCA fit in 6.706061840057373 seconds
# > PCA-based Model fit in 3.757896900177002 seconds
# > PCA GLM Built in 11.203755140304565 seconds
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Running multi
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# > cv_mean_score_train: 0.2517187905815793
# > cv_R2_score: 0.25343970938120974
# > cv_mean_score: 0.2533544863654919
# Running multi
# Multirun queue completed
#
# ---
#
# Best Score: 0.25343970938120974
# Best Params: {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Best Model: <sglm.models.sglm.GLM object at 0x7fd6a3e3deb0>
# Best Model — Intercept: 0.0
# Overall RunTime: 1669.0977020263672
#
# Holdout Score: 0.21715977514150553
# 5 dict_keys(['best_score', 'best_score_std', 'best_params', 'best_model', 'full_cv_results'])
# dfr.shape (273339, 389)
# > Included file_nums for y_col rDA: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# X_setup.columns: Index(['photometryCenterOutIndex_-20', 'photometryCenterOutIndex_-19',
#        'photometryCenterOutIndex_-18', 'photometryCenterOutIndex_-17',
#        'photometryCenterOutIndex_-16', 'photometryCenterOutIndex_-15',
#        'photometryCenterOutIndex_-14', 'photometryCenterOutIndex_-13',
#        'photometryCenterOutIndex_-12', 'photometryCenterOutIndex_-11',
#        ...
#        'spnnrOff_11', 'spnnrOff_12', 'spnnrOff_13', 'spnnrOff_14',
#        'spnnrOff_15', 'spnnrOff_16', 'spnnrOff_17', 'spnnrOff_18',
#        'spnnrOff_19', 'spnnrOff_20'],
#       dtype='object', length=246)
# PCA fit in 3.6561501026153564 seconds
# > PCA-based Model fit in 2.150087833404541 seconds
# > PCA GLM Built in 6.225146055221558 seconds
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Running multi
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# > cv_mean_score_train: 0.24565023915141984
# > cv_R2_score: 0.24128004036355022
# > cv_mean_score: 0.24126271582135478
# Running multi
# Multirun queue completed
#
# ---
#
# Best Score: 0.24128004036355022
# Best Params: {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Best Model: <sglm.models.sglm.GLM object at 0x7fd681f2a460>
# Best Model — Intercept: 0.0
# Overall RunTime: 1721.7440948486328
#
# Holdout Score: 0.2098775714166965
# 5 dict_keys(['best_score', 'best_score_std', 'best_params', 'best_model', 'full_cv_results'])
# - ['rDA', 'rDA']
# dfr.shape (273339, 389)
# > Included file_nums for y_col rDA: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# X_setup.columns: Index(['photometryCenterInIndex_-20', 'photometryCenterInIndex_-19',
#        'photometryCenterInIndex_-18', 'photometryCenterInIndex_-17',
#        'photometryCenterInIndex_-16', 'photometryCenterInIndex_-15',
#        'photometryCenterInIndex_-14', 'photometryCenterInIndex_-13',
#        'photometryCenterInIndex_-12', 'photometryCenterInIndex_-11',
#        ...
#        'spnnrOff_11', 'spnnrOff_12', 'spnnrOff_13', 'spnnrOff_14',
#        'spnnrOff_15', 'spnnrOff_16', 'spnnrOff_17', 'spnnrOff_18',
#        'spnnrOff_19', 'spnnrOff_20'],
#       dtype='object', length=287)
# PCA fit in 5.163035154342651 seconds
# > PCA-based Model fit in 14.87008810043335 seconds
# > PCA GLM Built in 20.88329005241394 seconds
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Running multi
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# > cv_mean_score_train: 0.24834068816424698
# > cv_R2_score: 0.23304532874764416
# > cv_mean_score: 0.23330089734109344
# Running multi
# Multirun queue completed
#
# ---
#
# Best Score: 0.23304532874764416
# Best Params: {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Best Model: <sglm.models.sglm.GLM object at 0x7fd630f65040>
# Best Model — Intercept: 0.0
# Overall RunTime: 1869.7091538906097
#
# Holdout Score: 0.25099339272021204
# 5 dict_keys(['best_score', 'best_score_std', 'best_params', 'best_model', 'full_cv_results'])
# dfr.shape (273339, 389)
# > Included file_nums for y_col rDA: [0, 1, 2, 3, 4, 5, 6, 7, 8]
# X_setup.columns: Index(['photometryCenterOutIndex_-20', 'photometryCenterOutIndex_-19',
#        'photometryCenterOutIndex_-18', 'photometryCenterOutIndex_-17',
#        'photometryCenterOutIndex_-16', 'photometryCenterOutIndex_-15',
#        'photometryCenterOutIndex_-14', 'photometryCenterOutIndex_-13',
#        'photometryCenterOutIndex_-12', 'photometryCenterOutIndex_-11',
#        ...
#        'spnnrOff_11', 'spnnrOff_12', 'spnnrOff_13', 'spnnrOff_14',
#        'spnnrOff_15', 'spnnrOff_16', 'spnnrOff_17', 'spnnrOff_18',
#        'spnnrOff_19', 'spnnrOff_20'],
#       dtype='object', length=246)
# PCA fit in 3.642957925796509 seconds
# > PCA-based Model fit in 1.922482967376709 seconds
# > PCA GLM Built in 5.945892095565796 seconds
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Running multi
# {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# > cv_mean_score_train: 0.23852546862657248
# > cv_R2_score: 0.23553348191142276
# > cv_mean_score: 0.23522513141065096
# Running multi
# Multirun queue completed
#
# ---
#
# Best Score: 0.23553348191142276
# Best Params: {'max_iter': 10000, 'fit_intercept': False, 'alpha': 0, 'l1_ratio': 0}
# Best Model: <sglm.models.sglm.GLM object at 0x7fd630f65b80>
# Best Model — Intercept: 0.0
# Overall RunTime: 1919.6996531486511
#
# Holdout Score: 0.24387089987157884
# 5 dict_keys(['best_score', 'best_score_std', 'best_params', 'best_model', 'full_cv_results'])
