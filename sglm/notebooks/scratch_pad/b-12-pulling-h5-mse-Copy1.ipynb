# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import glob
import pandas as pd
import numpy as np
from sglm.helpers import filehelpers as fh, dfhelpers as dfh
from pathlib import Path

# %%
base_location = Path(r'/Users/Josh/Documents/GitHub/sabatinilab-glm/sglm/outputs')


# load_folder = base_location / Path(r'Figure_1_2')
# h5_beta_locations = str((load_folder / Path(r'all/hs2-w*-ft/coefs/*_best_coeffs.h5')).resolve())
# h5_beta_locations = str((load_folder / Path(r'all/hypswp-50_*-ft/coefs/*_best_coeffs.h5')).resolve())

# load_folder = base_location / Path(r'Figure_1_2')
# h5_beta_locations = str((load_folder / Path(r'all/hypswp-50-wds*-ft/coefs/*_best_coeffs.h5')).resolve())

# load_folder = base_location / Path(r'Figure_1_2')
# h5_beta_locations = str((load_folder / Path(r'all\f1*-ft\coefs\*_best_coeffs.h5')).resolve())
# load_folder = base_location / Path(r'Figure_3')
# h5_beta_locations = str((load_folder / Path(r'all\f3*-ft\coefs\*_best_coeffs.h5')).resolve())
# load_folder = base_location / Path(r'Figure_4_g1')
# h5_beta_locations = str((load_folder / Path(r'all\f4*-ft\coefs\*_best_coeffs.h5')).resolve())
# load_folder = base_location / Path(r'Figure_4_g2')
# h5_beta_locations = str((load_folder / Path(r'all\f4*-ft\coefs\*_best_coeffs.h5')).resolve())
# load_folder = base_location / Path(r'Figure_5_g1')
# h5_beta_locations = str((load_folder / Path(r'all\f5*-ft\coefs\*_best_coeffs.h5')).resolve())
# load_folder = base_location / Path(r'Figure_5_g2')
# h5_beta_locations = str((load_folder / Path(r'all\f5*-ft\coefs\*_best_coeffs.h5')).resolve())
# load_folder = base_location / Path(r'Figure_5_g5')
# h5_beta_locations = str((load_folder / Path(r'all\f5*-ft\coefs\*_best_coeffs.h5')).resolve())


load_folder = base_location / Path(r'Figure_6_g1')
# h5_beta_locations = str((load_folder / Path(r'all/glu_run_*/coefs/*_best_coeffs.h5')).resolve())
# h5_beta_locations = str((load_folder / Path(r'all/glu_run_20221202-no-CO*/coefs/*_best_coeffs.h5')).resolve())
# h5_beta_locations = str((load_folder / Path(r'all/glu_run_20221202-30sft_0*/coefs/*_best_coeffs.h5')).resolve())
h5_beta_locations = str((load_folder / Path(r'all/glu_run_20221202-30sft-reduc_0*/coefs/*_best_coeffs.h5')).resolve())


# out_folder = base_location / Path(r'final_outputs_glu_run-no-CO')
# out_folder = base_location / Path(r'final_outputs_glu_run-30sft')
out_folder = base_location / Path(r'final_outputs_glu_run_20221202-30sft-reduc')


# h5_beta_locations = Path('/Users/josh/Dropbox (HMS)/jz/Tetanus/1194_1195_1214_1258_1259_2_best_coeffs.h5')
out_loc = str((out_folder).resolve())
h5_beta_locations = glob.glob(h5_beta_locations)

# %%
h5_lst = []
for h5_coef_fn in h5_beta_locations:
    h5f = pd.HDFStore(h5_coef_fn)
    h5fk = h5f.keys()
    for key in h5fk:
        h5_df = pd.read_hdf(h5f, key).reset_index()
        h5_df['fn'] = h5_coef_fn
        h5_df['key'] = key
        h5_df = h5_df.set_index(['fn','key'])
        
        
        h5_df = h5_df.sort_values('channel_name')
        h5_df['channel'] = h5_df['channel_name'].str.split('_').apply(lambda x: x[0])
        h5_df['run_num'] = h5_df['channel_name'].str.split('_').apply(lambda x: x[-1])
        
        h5_df['model_version'] = '_'.join(key.split('_')[3:]).split('_run_num')[0]
        
        h5_lst.append(h5_df)
concat = pd.concat(h5_lst, axis=0)

# %%
concat
# Out:
#                                                                                                                      level_0  \
# fn                                                 key
# C:\Users\Josh\Documents\GitHub\sabatinilab-glm\... /gGLUr_0_0_base_simple_max_iter10000__fit_inter...  1299_1300_1301_1302_0
#                                                    /gGLUr_0_0_base_simple_max_iter10000__fit_inter...  1299_1300_1301_1302_0
#                                                    /gGLUr_0_0_base_simple_max_iter10000__fit_inter...  1299_1300_1301_1302_0
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...  1299_1300_1301_1302_0
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...  1299_1300_1301_1302_0
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...  1299_1300_1301_1302_0
#
#                                                                                                                   mouse_id  \
# fn                                                 key
# C:\Users\Josh\Documents\GitHub\sabatinilab-glm\... /gGLUr_0_0_base_simple_max_iter10000__fit_inter...  1299_1300_1301_1302
#                                                    /gGLUr_0_0_base_simple_max_iter10000__fit_inter...  1299_1300_1301_1302
#                                                    /gGLUr_0_0_base_simple_max_iter10000__fit_inter...  1299_1300_1301_1302
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...  1299_1300_1301_1302
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...  1299_1300_1301_1302
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...  1299_1300_1301_1302
#
#                                                                                                             channel_name  \
# fn                                                 key
# C:\Users\Josh\Documents\GitHub\sabatinilab-glm\... /gGLUr_0_0_base_simple_max_iter10000__fit_inter...  gGLUr_0_run_num=0
#                                                    /gGLUr_0_0_base_simple_max_iter10000__fit_inter...  gGLUr_0_run_num=1
#                                                    /gGLUr_0_0_base_simple_max_iter10000__fit_inter...  gGLUr_0_run_num=2
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...  gGLUr_1_run_num=0
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...  gGLUr_1_run_num=1
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...  gGLUr_1_run_num=2
#
#                                                                                                               name  \
# fn                                                 key
# C:\Users\Josh\Documents\GitHub\sabatinilab-glm\... /gGLUr_0_0_base_simple_max_iter10000__fit_inter...  base_simple
#                                                    /gGLUr_0_0_base_simple_max_iter10000__fit_inter...  base_simple
#                                                    /gGLUr_0_0_base_simple_max_iter10000__fit_inter...  base_simple
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...   base_words
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...   base_words
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...   base_words
#
#                                                                                                                   timestamp  \
# fn                                                 key
# C:\Users\Josh\Documents\GitHub\sabatinilab-glm\... /gGLUr_0_0_base_simple_max_iter10000__fit_inter...  25.522228717803955 s
#                                                    /gGLUr_0_0_base_simple_max_iter10000__fit_inter...   70.37039017677307 s
#                                                    /gGLUr_0_0_base_simple_max_iter10000__fit_inter...  115.22396087646484 s
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...  53.961803674697876 s
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...   98.98404383659363 s
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...   143.1752073764801 s
#
#                                                                                                          mse_tr  \
# fn                                                 key
# C:\Users\Josh\Documents\GitHub\sabatinilab-glm\... /gGLUr_0_0_base_simple_max_iter10000__fit_inter...  0.670556
#                                                    /gGLUr_0_0_base_simple_max_iter10000__fit_inter...  0.676014
#                                                    /gGLUr_0_0_base_simple_max_iter10000__fit_inter...  0.662620
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...  0.663131
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...  0.668679
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...  0.655426
#
#                                                                                                          mse_cv  \
# fn                                                 key
# C:\Users\Josh\Documents\GitHub\sabatinilab-glm\... /gGLUr_0_0_base_simple_max_iter10000__fit_inter...  0.676244
#                                                    /gGLUr_0_0_base_simple_max_iter10000__fit_inter...  0.673360
#                                                    /gGLUr_0_0_base_simple_max_iter10000__fit_inter...  0.663011
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...  0.674850
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...  0.676331
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...  0.672194
#
#                                                                                                          mse_te  \
# fn                                                 key
# C:\Users\Josh\Documents\GitHub\sabatinilab-glm\... /gGLUr_0_0_base_simple_max_iter10000__fit_inter...  0.686750
#                                                    /gGLUr_0_0_base_simple_max_iter10000__fit_inter...  0.681069
#                                                    /gGLUr_0_0_base_simple_max_iter10000__fit_inter...  0.694318
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...  0.683102
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...  0.677713
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...  0.690095
#
#                                                                                                           r2_tr  \
# fn                                                 key
# C:\Users\Josh\Documents\GitHub\sabatinilab-glm\... /gGLUr_0_0_base_simple_max_iter10000__fit_inter...  0.351731
#                                                    /gGLUr_0_0_base_simple_max_iter10000__fit_inter...  0.347408
#                                                    /gGLUr_0_0_base_simple_max_iter10000__fit_inter...  0.352917
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...  0.358910
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...  0.354490
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...  0.359943
#
#                                                                                                           r2_cv  \
# fn                                                 key
# C:\Users\Josh\Documents\GitHub\sabatinilab-glm\... /gGLUr_0_0_base_simple_max_iter10000__fit_inter...  0.348780
#                                                    /gGLUr_0_0_base_simple_max_iter10000__fit_inter...  0.349919
#                                                    /gGLUr_0_0_base_simple_max_iter10000__fit_inter...  0.343659
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...  0.358062
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...  0.349970
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...  0.347053
#
#                                                                                                        ...  \
# fn                                                 key                                                 ...
# C:\Users\Josh\Documents\GitHub\sabatinilab-glm\... /gGLUr_0_0_base_simple_max_iter10000__fit_inter...  ...
#                                                    /gGLUr_0_0_base_simple_max_iter10000__fit_inter...  ...
#                                                    /gGLUr_0_0_base_simple_max_iter10000__fit_inter...  ...
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...  ...
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...  ...
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...  ...
#
#                                                                                                        photometrySideInIndexab_21  \
# fn                                                 key
# C:\Users\Josh\Documents\GitHub\sabatinilab-glm\... /gGLUr_0_0_base_simple_max_iter10000__fit_inter...                         NaN
#                                                    /gGLUr_0_0_base_simple_max_iter10000__fit_inter...                         NaN
#                                                    /gGLUr_0_0_base_simple_max_iter10000__fit_inter...                         NaN
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...                   -0.358078
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...                   -0.342137
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...                   -0.534996
#
#                                                                                                        photometrySideInIndexab_22  \
# fn                                                 key
# C:\Users\Josh\Documents\GitHub\sabatinilab-glm\... /gGLUr_0_0_base_simple_max_iter10000__fit_inter...                         NaN
#                                                    /gGLUr_0_0_base_simple_max_iter10000__fit_inter...                         NaN
#                                                    /gGLUr_0_0_base_simple_max_iter10000__fit_inter...                         NaN
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...                   -0.248728
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...                   -0.108053
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...                   -0.161380
#
#                                                                                                        photometrySideInIndexab_23  \
# fn                                                 key
# C:\Users\Josh\Documents\GitHub\sabatinilab-glm\... /gGLUr_0_0_base_simple_max_iter10000__fit_inter...                         NaN
#                                                    /gGLUr_0_0_base_simple_max_iter10000__fit_inter...                         NaN
#                                                    /gGLUr_0_0_base_simple_max_iter10000__fit_inter...                         NaN
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...                   -0.432583
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...                   -0.406895
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...                   -0.439282
#
#                                                                                                        photometrySideInIndexab_24  \
# fn                                                 key
# C:\Users\Josh\Documents\GitHub\sabatinilab-glm\... /gGLUr_0_0_base_simple_max_iter10000__fit_inter...                         NaN
#                                                    /gGLUr_0_0_base_simple_max_iter10000__fit_inter...                         NaN
#                                                    /gGLUr_0_0_base_simple_max_iter10000__fit_inter...                         NaN
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...                   -0.208008
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...                   -0.333676
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...                   -0.440876
#
#                                                                                                        photometrySideInIndexab_25  \
# fn                                                 key
# C:\Users\Josh\Documents\GitHub\sabatinilab-glm\... /gGLUr_0_0_base_simple_max_iter10000__fit_inter...                         NaN
#                                                    /gGLUr_0_0_base_simple_max_iter10000__fit_inter...                         NaN
#                                                    /gGLUr_0_0_base_simple_max_iter10000__fit_inter...                         NaN
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...                   -0.220160
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...                   -0.212886
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...                   -0.451665
#
#                                                                                                        photometrySideInIndexab_26  \
# fn                                                 key
# C:\Users\Josh\Documents\GitHub\sabatinilab-glm\... /gGLUr_0_0_base_simple_max_iter10000__fit_inter...                         NaN
#                                                    /gGLUr_0_0_base_simple_max_iter10000__fit_inter...                         NaN
#                                                    /gGLUr_0_0_base_simple_max_iter10000__fit_inter...                         NaN
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...                   -0.151782
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...                   -0.158447
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...                   -0.322458
#
#                                                                                                        photometrySideInIndexab_27  \
# fn                                                 key
# C:\Users\Josh\Documents\GitHub\sabatinilab-glm\... /gGLUr_0_0_base_simple_max_iter10000__fit_inter...                         NaN
#                                                    /gGLUr_0_0_base_simple_max_iter10000__fit_inter...                         NaN
#                                                    /gGLUr_0_0_base_simple_max_iter10000__fit_inter...                         NaN
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...                   -0.066476
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...                   -0.013292
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...                   -0.278863
#
#                                                                                                        photometrySideInIndexab_28  \
# fn                                                 key
# C:\Users\Josh\Documents\GitHub\sabatinilab-glm\... /gGLUr_0_0_base_simple_max_iter10000__fit_inter...                         NaN
#                                                    /gGLUr_0_0_base_simple_max_iter10000__fit_inter...                         NaN
#                                                    /gGLUr_0_0_base_simple_max_iter10000__fit_inter...                         NaN
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...                   -0.003705
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...                   -0.035032
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...                   -0.088499
#
#                                                                                                        photometrySideInIndexab_29  \
# fn                                                 key
# C:\Users\Josh\Documents\GitHub\sabatinilab-glm\... /gGLUr_0_0_base_simple_max_iter10000__fit_inter...                         NaN
#                                                    /gGLUr_0_0_base_simple_max_iter10000__fit_inter...                         NaN
#                                                    /gGLUr_0_0_base_simple_max_iter10000__fit_inter...                         NaN
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...                   -0.074328
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...                   -0.043594
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...                   -0.202785
#
#                                                                                                        photometrySideInIndexab_30
# fn                                                 key
# C:\Users\Josh\Documents\GitHub\sabatinilab-glm\... /gGLUr_0_0_base_simple_max_iter10000__fit_inter...                         NaN
#                                                    /gGLUr_0_0_base_simple_max_iter10000__fit_inter...                         NaN
#                                                    /gGLUr_0_0_base_simple_max_iter10000__fit_inter...                         NaN
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...                   -0.026489
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...                   -0.086066
#                                                    /gGLUr_0_1_base_words_max_iter10000__fit_interc...                   -0.311656
#
# [6 rows x 765 columns]

# %%
fh.create_folder_if_not_exists(out_loc)

# %%
base_keys = list({
                # 'gACH':(0,0),
                # 'rDA':(0,0),
                # 'gDA':(0,0),
                'photometryCenterInIndex':(0,0),
                'photometryCenterOutIndex':(0,0),
                'photometrySideInIndex':(0,0),
                'photometrySideInIndexr':(0,0),
                'photometrySideOutIndex':(0,0),
                'sl': (0,0),
                'spnnrOff': (0,0),
                'photometryCenterInIndex':(0,0),
                'photometryCenterOutIndex':(0,0),
                'photometrySideInIndexAA':(0,0),
                'photometrySideInIndexAa':(0,0),
                'photometrySideInIndexaA':(0,0),
                'photometrySideInIndexaa':(0,0),
                'photometrySideInIndexAB':(0,0),
                'photometrySideInIndexAb':(0,0),
                'photometrySideInIndexaB':(0,0),
                'photometrySideInIndexab':(0,0),
                'photometrySideOutIndex':(0,0),
                'sl': (0,0),
                'spnnrOff': (0,0),
                }.keys())
# base_keys

# %%
save_mse_scatter = concat.reset_index().set_index(['mouse_id', 'channel', 'name', 'model_version', 'run_num'])[['mse_tr', 'mse_cv', 'mse_te']]
save_mse_scatter.to_csv(str((Path(out_loc) / f'{load_folder.parts[-1]}-mse_sctr.csv').resolve()))

save_r2_scatter = concat.reset_index().set_index(['mouse_id', 'channel', 'name', 'model_version', 'run_num'])[['r2_tr', 'r2_cv', 'r2_te']]
save_r2_scatter.to_csv(str((Path(out_loc) / f'{load_folder.parts[-1]}-r2_sctr.csv').resolve()))

# %%
agg = concat.drop(['channel_name', 'timestamp', 'run_num'], axis=1).groupby(['channel', 'name']).agg([np.size, np.mean, np.std])
stk = agg[['mse_tr', 'mse_cv', 'mse_te']].rename({'mse_tr':'01_mse_tr', 'mse_cv':'02_mse_cv', 'mse_te':'03_mse_te'}, axis=1).swaplevel(axis=1).stack()

stk['lb'] = stk['mean'] - 1.96*stk['std']/np.sqrt(stk['size'])
stk['mn'] = stk['mean']
stk['ub'] = stk['mean'] + 1.96*stk['std']/np.sqrt(stk['size'])

plt_df = stk[['lb', 'mn', 'ub']].unstack().swaplevel(axis=1)

gACH = plt_df.loc['gACH'] if 'gACH' in plt_df.reset_index()['channel'].unique() else plt_df.iloc[0:0]
rDA = plt_df.loc['rDA'] if 'rDA' in plt_df.reset_index()['channel'].unique() else plt_df.iloc[0:0]
gDA = plt_df.loc['gDA'] if 'gDA' in plt_df.reset_index()['channel'].unique() else plt_df.iloc[0:0]

save_ci = stk[['mean', 'size', 'std']].unstack().swaplevel(axis=1).sort_index(axis=1)
save_ci.to_csv(str((Path(out_loc) / f'{load_folder.parts[-1]}-mse_ci.csv').resolve()))
# Out:
# C:\Users\Josh\AppData\Local\Temp\ipykernel_23532\2044627354.py:1: FutureWarning: ['model_version'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   agg = concat.drop(['channel_name', 'timestamp', 'run_num'], axis=1).groupby(['channel', 'name']).agg([np.size, np.mean, np.std])

# %%
stk
# Out:
#                                    mean  size       std        lb        mn  \
# channel name
# gGLUr   base_simple 01_mse_tr  0.669730     3  0.006735  0.662109  0.669730
#                     02_mse_cv  0.670872     3  0.006959  0.662997  0.670872
#                     03_mse_te  0.687379     3  0.006647  0.679858  0.687379
#         base_words  01_mse_tr  0.662412     3  0.006656  0.654880  0.662412
#                     02_mse_cv  0.674458     3  0.002096  0.672086  0.674458
#                     03_mse_te  0.683637     3  0.006209  0.676611  0.683637
#
#                                      ub
# channel name
# gGLUr   base_simple 01_mse_tr  0.677352
#                     02_mse_cv  0.678746
#                     03_mse_te  0.694901
#         base_words  01_mse_tr  0.669943
#                     02_mse_cv  0.676830
#                     03_mse_te  0.690663

# %%
import matplotlib.pyplot as plt

# %%
rot = 15

fig,axes=plt.subplots(3,1,figsize=(10,20))
fig.set_facecolor('w')

if len(gACH) > 0:
    ax = axes[0]
    ax.plot(gACH.index, gACH['01_mse_tr']['mn'], label='mse_tr')
    ax.fill_between(gACH.index, gACH['01_mse_tr']['lb'], gACH['01_mse_tr']['ub'], alpha=0.2, label='mse_tr - CI')
    ax.plot(gACH.index, gACH['02_mse_cv']['mn'], label='mse_cv')
    ax.fill_between(gACH.index, gACH['02_mse_cv']['lb'], gACH['02_mse_cv']['ub'], alpha=0.2, label='mse_cv - CI')
    ax.plot(gACH.index, gACH['03_mse_te']['mn'], label='mse_te')
    ax.fill_between(gACH.index, gACH['03_mse_te']['lb'], gACH['03_mse_te']['ub'], alpha=0.2, label='mse_te - CI')
    print([_.get_text() for _ in ax.xaxis.get_ticklabels()])
    ax.set_title('gACH - GLM MSEs')
    ax.legend()
    ax.grid(True)
    for tick in ax.get_xticklabels():
        tick.set_rotation(rot)

if len(gDA) > 0:
    ax = axes[1]
    ax.plot(gDA.index, gDA['01_mse_tr']['mn'], label='mse_tr')
    ax.fill_between(gDA.index, gDA['01_mse_tr']['lb'], gDA['01_mse_tr']['ub'], alpha=0.2, label='mse_tr - CI')
    ax.plot(gDA.index, gDA['02_mse_cv']['mn'], label='mse_cv')
    ax.fill_between(gDA.index, gDA['02_mse_cv']['lb'], gDA['02_mse_cv']['ub'], alpha=0.2, label='mse_cv - CI')
    ax.plot(gDA.index, gDA['03_mse_te']['mn'], label='mse_te')
    ax.fill_between(gDA.index, gDA['03_mse_te']['lb'], gDA['03_mse_te']['ub'], alpha=0.2, label='mse_te - CI')
    ax.set_title('gDA - GLM MSEs')
    ax.legend()
    ax.grid(True)
    for tick in ax.get_xticklabels():
        tick.set_rotation(rot)

if len(rDA) > 0:
    ax = axes[2]
    ax.plot(rDA.index, rDA['01_mse_tr']['mn'], label='mse_tr')
    ax.fill_between(rDA.index, rDA['01_mse_tr']['lb'], rDA['01_mse_tr']['ub'], alpha=0.2, label='mse_tr - CI')
    ax.plot(rDA.index, rDA['02_mse_cv']['mn'], label='mse_cv')
    ax.fill_between(rDA.index, rDA['02_mse_cv']['lb'], rDA['02_mse_cv']['ub'], alpha=0.2, label='mse_cv - CI')
    ax.plot(rDA.index, rDA['03_mse_te']['mn'], label='mse_te')
    ax.fill_between(rDA.index, rDA['03_mse_te']['lb'], rDA['03_mse_te']['ub'], alpha=0.2, label='mse_te - CI')
    ax.set_title('rDA - GLM MSEs')
    ax.legend()
    ax.grid(True)

    for tick in ax.get_xticklabels():
        tick.set_rotation(rot)

plt.show()
